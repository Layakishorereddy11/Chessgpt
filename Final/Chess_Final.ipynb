# %% [markdown]
# # Model-1 (Base Gpt2)

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments
from torch.utils.data import Dataset
import pandas as pd
import re

# Enable GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load and preprocess data
def parse_chess_games(file_path, limit=25000):
    data = []
    with open(file_path, "r") as file:
        lines = file.readlines()
    for count, line in enumerate(lines):
        if "###" in line:
            if count >= limit:
                break
            raw_moves = line.split("###")[1].strip()
            moves = re.findall(r"\.\s*([^\s]+)", raw_moves)
            if moves:
                game_sequence = " ".join(moves).strip()
                data.append(game_sequence)
    return pd.DataFrame(data, columns=["text"])

# Custom dataset class
class ChessDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=128):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data.iloc[idx]["text"]
        # Tokenize the entire sequence
        tokenized = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_length,
            return_tensors="pt",
        )
        input_ids = tokenized.input_ids.squeeze()  # Remove batch dimension
        attention_mask = tokenized.attention_mask.squeeze()
        return {"input_ids": input_ids, "attention_mask": attention_mask, "labels": input_ids}

# Load the dataset
file_path = "/content/all_with_filtered_anotations_since1998 copy.txt"
parsed_data = parse_chess_games(file_path)


# Initialize tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
# Add the following line to define the padding token
tokenizer.pad_token = tokenizer.eos_token
model = GPT2LMHeadModel.from_pretrained("gpt2").to(device)

# Prepare dataset
dataset = ChessDataset(parsed_data, tokenizer)

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=1,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=8,
    evaluation_strategy="no",
    save_steps=10_000,
    save_total_limit=2,
    logging_dir="./logs",
)

# Train the model
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='778' max='778' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [778/778 16:21, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.634500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=778, training_loss=1.5694689517768918, metrics={'train_runtime': 983.8371, 'train_samples_per_second': 25.331, 'train_steps_per_second': 0.791, 'total_flos': 1626281607168000.0, 'train_loss': 1.5694689517768918, 'epoch': 0.9988765848178462})

# %%
model.save_pretrained("./fine_tuned_model_BaseModel")
tokenizer.save_pretrained("./fine_tuned_model_BaseModel")

# %%
# Predict the next move
def predict_next_move(model, tokenizer, prompt, max_length=50):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    outputs = model.generate(
        inputs["input_ids"], max_length=max_length, num_return_sequences=1, pad_token_id=tokenizer.eos_token_id
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Example prediction
prompt = "e4 e5 Nf3"
next_move = predict_next_move(model, tokenizer, prompt)
print("Next Move:", next_move)

# %% [markdown]
# #Model-2 (LoRA)

# %%
import pandas as pd
import re
from transformers import AutoTokenizer, AutoModelForCausalLM, Trainer, TrainingArguments
from peft import LoraConfig, get_peft_model
import torch
from torch.utils.data import Dataset
from accelerate import Accelerator
# Dataset Preparation - Parse Chess Game Moves as Sequences
def parse_chess_games(file_path, limit=25000):
    data = []
    with open(file_path, "r") as file:
        lines = file.readlines()
    for count, line in enumerate(lines):
        if "###" in line:
            if count >= limit:
                break
            raw_moves = line.split("###")[1].strip()
            # Extract moves without prefixes like W1. and B1.
            moves = re.findall(r"\.\s*([^\s]+)", raw_moves)  # Matches moves after a dot
            if not moves:  # Skip if no moves found
                continue
            # Combine all moves into a single sequence
            game_sequence = " ".join(moves).strip()
            if game_sequence:  # Ensure non-empty
                data.append(game_sequence)
    return pd.DataFrame(data, columns=["text"])





# Dataset Class for Language Modeling
class ChessDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=128):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data.iloc[idx]["text"]
        # Tokenize the entire sequence
        tokenized = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_length,
            return_tensors="pt",
        )
        input_ids = tokenized.input_ids.squeeze()  # Remove batch dimension
        attention_mask = tokenized.attention_mask.squeeze()
        return {"input_ids": input_ids, "attention_mask": attention_mask, "labels": input_ids}

# Load and Prepare Data
file_path = "/content/all_with_filtered_anotations_since1998 copy.txt"
raw_data = parse_chess_games(file_path)
train_data = raw_data.sample(frac=0.8, random_state=42)
val_data = raw_data.drop(train_data.index)
print(f"Dataset Size: {len(train_data)} training samples")
print("Example Data:", train_data.iloc[0])

# Model and Tokenizer Setup
model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Add padding token if not already present
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

base_model = AutoModelForCausalLM.from_pretrained(model_name)

# LoRA Configuration for Efficient Fine-Tuning
lora_config = LoraConfig(
    r=8, lora_alpha=32, target_modules=["c_attn"], lora_dropout=0.1
)
model = get_peft_model(base_model, lora_config)

# Create Datasets
train_dataset = ChessDataset(train_data, tokenizer)
val_dataset = ChessDataset(val_data, tokenizer)

# Accelerator setup (optional)
accelerator = Accelerator()

# Training Arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=7,
    learning_rate=5e-5,
    weight_decay=0.01,
    logging_dir="./logs",
    save_strategy="epoch",
    save_total_limit=2,
    # Enable mixed precision for T4 GPU
    fp16=True,
)

# Initialize Trainer (without the accelerator argument)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
)

# Use accelerator to prepare model and datasets for multi-device/multi-GPU setups
model, train_dataset, val_dataset = accelerator.prepare(
    model, train_dataset, val_dataset
)

# Fine-Tune the Model
trainer.train()

# Save the Fine-Tuned Model
model.save_pretrained("./fine_tuned_model_unsupe")
tokenizer.save_pretrained("./fine_tuned_model_unsupe")
# Out:
# Dataset Size: 19938 training samples
# Example Data: text    d4 e6 e4 d5 Nc3 dxe4 Nxe4 Bd7 Nf3 Bc6 Bd3 Nd7 ...
# Name: 18780, dtype: object

# %% [markdown]
# Prediction with Cuda

# %%
def predict_next_move(model, tokenizer, input_moves, max_new_tokens=100):
    # Move model to the GPU
    device = model.device

    # Tokenize the input moves
    inputs = tokenizer(input_moves, return_tensors="pt", padding=True, truncation=True)

    # Move the input tensors to the same device as the model
    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)  # Ensure attention mask is also on the correct device

    # Ensure pad_token_id is set correctly for open-ended generation
    pad_token_id = tokenizer.pad_token_id if tokenizer.pad_token_id is not None else tokenizer.eos_token_id

    # Generate the next tokens
    outputs = model.generate(
        input_ids=input_ids,
        attention_mask=attention_mask,
        max_new_tokens=max_new_tokens,
        pad_token_id=pad_token_id  # Set pad_token_id
    )

    # Decode and return the predicted moves
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Example Usage
input_moves = "W1.e4 B1.c5 W2.Nf3 B2.e6 W3.Nc3 B3.a6 W4.d4 B4.cxd4 W5.Nxd4 B5.Nf6"
predicted_moves = predict_next_move(model, tokenizer, input_moves)
print(f"Predicted moves: {predicted_moves}")

# %% [markdown]
# # Loading Saved Model and predicting

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# Path to the saved model directory
model_path = "/content/fine_tuned_model_unsupe"

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path)

# Ensure pad_token_id is correctly set for open-ended generation
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = tokenizer.eos_token_id

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2SdpaAttention(
#           (c_attn): lora.Linear(
#             (base_layer): Conv1D(nf=2304, nx=768)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=768, out_features=8, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=8, out_features=2304, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (c_proj): Conv1D(nf=768, nx=768)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=3072, nx=768)
#           (c_proj): Conv1D(nf=768, nx=3072)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
# Function to predict the next move
def predict_next_move(model, tokenizer, input_moves, max_new_tokens=3):
    # Move model to the GPU
    device = model.device

    # Tokenize the input moves
    inputs = tokenizer(input_moves, return_tensors="pt", padding=True, truncation=True)

    # Move the input tensors to the same device as the model
    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)  # Ensure attention mask is also on the correct device

    # Ensure pad_token_id is set correctly for open-ended generation
    pad_token_id = tokenizer.pad_token_id if tokenizer.pad_token_id is not None else tokenizer.eos_token_id

    # Generate the next tokens
    outputs = model.generate(
        input_ids=input_ids,
        attention_mask=attention_mask,
        max_new_tokens=max_new_tokens,
        pad_token_id=pad_token_id  # Set pad_token_id
    )

    # Decode and return the predicted moves
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Example Usage
input_moves = "e4 c5 Nf3 d6 Ne5 dxe5"
predicted_moves = predict_next_move(model, tokenizer, input_moves)
print(f"Predicted moves: {predicted_moves}")
# Out:
# Predicted moves: W1.e4 B1.c5 W2.Nf3 B2.d6 W3.Ne5 B3.dxe5 W4.Nxe5

# %% [markdown]
# #Model-3 (LoRa, Illeagal move penalization)

# %% [markdown]
# # Illegal move penalization

# %%
pip install python-chess
# Out:
# Collecting python-chess
#   Downloading python_chess-1.999-py3-none-any.whl.metadata (776 bytes)
# Collecting chess<2,>=1 (from python-chess)
#   Downloading chess-1.11.1.tar.gz (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Downloading python_chess-1.999-py3-none-any.whl (1.4 kB)
# Building wheels for collected packages: chess
#   Building wheel for chess (setup.py) ... done
#   Created wheel for chess: filename=chess-1.11.1-py3-none-any.whl size=148497 sha256=4d8a3784c75aae37150c361a7f058af7d7c2bc2be4ff49267b635c874c5ea0ba
#   Stored in directory: /root/.cache/pip/wheels/2e/2d/23/1bfc95db984ed3ecbf6764167dc7526d0ab521cf9a9852544e
# Successfully built chess
# Installing collected packages: chess, python-chess
# Successfully installed chess-1.11.1 python-chess-1.999

# %%
import chess
import chess.pgn
import pandas as pd
import re
from transformers import AutoTokenizer, AutoModelForCausalLM, Trainer, TrainingArguments
from peft import LoraConfig, get_peft_model
import torch
from torch.utils.data import Dataset
from accelerate import Accelerator

# Dataset Preparation - Parse Chess Game Moves as Sequences
def parse_chess_games(file_path, limit=50000):
    data = []
    with open(file_path, "r") as file:
        lines = file.readlines()
    for count, line in enumerate(lines):
        if "###" in line:
            if count >= limit:
                break

            # Extract Elo ratings from the metadata
            metadata = line.split("###")[0].strip()
            try:
                welo, belo = metadata.split()[3:5]  # Assuming Elo ratings are the 4th and 5th items
                welo = int(welo) if welo != "None" else 0
                belo = int(belo) if belo != "None" else 0
            except (IndexError, ValueError):
                continue  # Skip if parsing fails

            # Filter based on Elo ratings
            if welo < 2500 or belo < 2500:
                continue

            # Extract moves
            raw_moves = line.split("###")[1].strip()
            moves = re.findall(r"\.\s*([^\s]+)", raw_moves)  # Matches moves after a dot
            if not moves:  # Skip if no moves found
                continue

            # Combine all moves into a single sequence
            game_sequence = " ".join(moves).strip()
            if game_sequence:  # Ensure non-empty
                data.append(game_sequence)

    return pd.DataFrame(data, columns=["text"])


# Dataset Class for Language Modeling
class ChessDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=128):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data.iloc[idx]["text"]
        tokenized = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_length,
            return_tensors="pt",
        )
        input_ids = tokenized.input_ids.squeeze()
        attention_mask = tokenized.attention_mask.squeeze()
        return {"input_ids": input_ids, "attention_mask": attention_mask, "labels": input_ids}

# Function to check legality of moves
def is_legal_move(board, move):
    try:
        board.push_san(move)
        board.pop()
        return True
    except ValueError:
        return False

# Custom Trainer with Modified Loss
class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, num_items_in_batch=None):  # Add num_items_in_batch argument
        # Get model outputs
        outputs = model(**inputs)
        logits = outputs.logits  # Shape: (batch_size, seq_len, vocab_size)
        labels = inputs["labels"]  # Shape: (batch_size, seq_len)

        # Shift logits and labels for causal language modeling
        shift_logits = logits[..., :-1, :].contiguous()
        shift_labels = labels[..., 1:].contiguous()

        # Calculate loss
        loss_fct = torch.nn.CrossEntropyLoss(reduction="none")
        loss = loss_fct(shift_logits.view(-1, shift_logits.size(-1)), shift_labels.view(-1))

        # Penalize illegal moves
        batch_size, seq_len = shift_labels.shape
        board = chess.Board()
        for i in range(batch_size):
            move_sequence = []
            for j in range(seq_len):
                token = shift_labels[i, j].item()
                if token == -100:  # Skip padding
                    continue
                move = tokenizer.decode([token]).strip()
                if not is_legal_move(board, move):
                    loss[i * seq_len + j] *= 2  # Increase penalty for illegal moves
                else:
                    board.push_san(move)  # Apply the move to the board

        return (loss.mean(), outputs) if return_outputs else loss.mean()

# Load and Prepare Data
file_path = "/content/all_with_filtered_anotations_since1998 copy.txt"
raw_data = parse_chess_games(file_path)
train_data = raw_data.sample(frac=0.8, random_state=42)
val_data = raw_data.drop(train_data.index)
print(f"Dataset Size: {len(train_data)} training samples")
print("Example Data:", train_data.iloc[0])

# Model and Tokenizer Setup
model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = tokenizer.eos_token_id

base_model = AutoModelForCausalLM.from_pretrained(model_name)

# LoRA Configuration for Efficient Fine-Tuning
lora_config = LoraConfig(
    r=8, lora_alpha=32, target_modules=["c_attn"], lora_dropout=0.1
)
model = get_peft_model(base_model, lora_config)

# Create Datasets
train_dataset = ChessDataset(train_data, tokenizer)
val_dataset = ChessDataset(val_data, tokenizer)

# Accelerator setup
accelerator = Accelerator()

# Training Arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=4,
    learning_rate=5e-5,
    weight_decay=0.01,
    logging_dir="./logs",
    save_strategy="epoch",
    save_total_limit=2,
    fp16=True,  # Enable mixed precision for GPU
)

# Initialize Custom Trainer
trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
)

# Move model and data to GPU using Accelerator
model, train_dataset, val_dataset = accelerator.prepare(
    model, train_dataset, val_dataset
)

# Fine-Tune the Model
trainer.train()

# Save the Fine-Tuned Model
model.save_pretrained("./fine_tuned_model_unsupe")
tokenizer.save_pretrained("./fine_tuned_model_unsupe")
# Out:
# Dataset Size: 29587 training samples
# Example Data: text    d4 d5 c4 e6 Nc3 Nf6 cxd5 exd5 Bg5 Be7 e3 c6 Qc...
# Name: 3593, dtype: object
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora/layer.py:1150: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# <ipython-input-3-83ee13ca1467>:158: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `CustomTrainer.__init__`. Use `processing_class` instead.
#   trainer = CustomTrainer(
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241203_021107-t1lf0h7h</code>
# Syncing run <strong><a href='https://wandb.ai/ld786-rutgers-university/huggingface/runs/t1lf0h7h' target="_blank">./results</a></strong> to <a href='https://wandb.ai/ld786-rutgers-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ld786-rutgers-university/huggingface' target="_blank">https://wandb.ai/ld786-rutgers-university/huggingface</a>
#  View run at <a href='https://wandb.ai/ld786-rutgers-university/huggingface/runs/t1lf0h7h' target="_blank">https://wandb.ai/ld786-rutgers-university/huggingface/runs/t1lf0h7h</a>
#     <div>
#
#       <progress value='14796' max='14796' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14796/14796 1:29:57, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.566200</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.394400</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.330200</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.294300</td>
#       <td>No log</td>
#     </tr>
#   </tbody>
# </table><p>
# ('./fine_tuned_model_unsupe/tokenizer_config.json',
#  './fine_tuned_model_unsupe/special_tokens_map.json',
#  './fine_tuned_model_unsupe/vocab.json',
#  './fine_tuned_model_unsupe/merges.txt',
#  './fine_tuned_model_unsupe/added_tokens.json',
#  './fine_tuned_model_unsupe/tokenizer.json')

# %%
def predict_next_move(model, tokenizer, input_moves, max_new_tokens=3):
    # Move model to the GPU
    device = model.device

    # Tokenize the input moves
    inputs = tokenizer(input_moves, return_tensors="pt", padding=True, truncation=True)

    # Move the input tensors to the same device as the model
    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)  # Ensure attention mask is also on the correct device

    # Ensure pad_token_id is set correctly for open-ended generation
    pad_token_id = tokenizer.pad_token_id if tokenizer.pad_token_id is not None else tokenizer.eos_token_id

    # Generate the next tokens
    outputs = model.generate(
        input_ids=input_ids,
        attention_mask=attention_mask,
        max_new_tokens=max_new_tokens,
        pad_token_id=pad_token_id  # Set pad_token_id
    )

    # Decode and return the predicted moves
    return tokenizer.decode(outputs[0], skip_special_tokens=True)
#e4 c5
# Example Usage
input_moves = "e4 e5 Nf3 Nf6 Bb5 Nxe4"
predicted_moves = predict_next_move(model, tokenizer, input_moves)
print(f"Predicted moves: {predicted_moves}")
# Out:
# Predicted moves: e4 e5 Nf3 Nf6 Bb5 Nxe4 Nxe4

# %% [markdown]
# #Model-4 ChessGpt(Scratch)

# %%
# prompt: install chess
# !pip install python-chess
# Out:
# Collecting python-chess
#   Using cached python_chess-1.999-py3-none-any.whl.metadata (776 bytes)
# Collecting chess<2,>=1 (from python-chess)
#   Downloading chess-1.11.1.tar.gz (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Downloading python_chess-1.999-py3-none-any.whl (1.4 kB)
# Building wheels for collected packages: chess
#   Building wheel for chess (setup.py) ... done
#   Created wheel for chess: filename=chess-1.11.1-py3-none-any.whl size=148497 sha256=741e84dcb3b64e0f56dbfd9fe17f393925e9c4769ec97c3179d03080e31051ca
#   Stored in directory: /root/.cache/pip/wheels/2e/2d/23/1bfc95db984ed3ecbf6764167dc7526d0ab521cf9a9852544e
# Successfully built chess
# Installing collected packages: chess, python-chess
# Successfully installed chess-1.11.1 python-chess-1.999

# %%
# !pip install python-chess~=0.26
# !pip install livelossplot==0.3.4
# !wget https://www.dropbox.com/sh/75gzfgu7qo94pvh/AACk_w5M94GTwwhSItCqsemoa/Stockfish%205/stockfish-5-linux.zip
# !unzip stockfish-5-linux.zip
# Out:
# Collecting python-chess~=0.26
#   Downloading python_chess-0.31.4-py3-none-any.whl.metadata (12 kB)
# Downloading python_chess-0.31.4-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: python-chess
# Successfully installed python-chess-0.31.4
# Collecting livelossplot==0.3.4
#   Downloading livelossplot-0.3.4-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from livelossplot==0.3.4) (3.8.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from livelossplot==0.3.4) (6.5.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot==0.3.4) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot==0.3.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot==0.3.4) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot==0.3.4) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot==0.3.4) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot==0.3.4) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot==0.3.4) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot==0.3.4) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot==0.3.4) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (3.1.4)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (6.3.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (23.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (5.7.2)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (6.1.12)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (7.16.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (5.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->livelossplot==0.3.4) (1.1.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook->livelossplot==0.3.4) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->livelossplot==0.3.4) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->livelossplot==0.3.4) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->livelossplot==0.3.4) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->livelossplot==0.3.4) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->livelossplot==0.3.4) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->livelossplot==0.3.4) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->livelossplot==0.3.4) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->livelossplot==0.3.4) (0.10.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->livelossplot==0.3.4) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->livelossplot==0.3.4) (2.18.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook->livelossplot==0.3.4) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->livelossplot==0.3.4) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->livelossplot==0.3.4) (4.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->livelossplot==0.3.4) (1.16.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook->livelossplot==0.3.4) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->livelossplot==0.3.4) (21.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->notebook->livelossplot==0.3.4) (7.34.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert>=5->notebook->livelossplot==0.3.4) (0.5.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook->livelossplot==0.3.4) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel->notebook->livelossplot==0.3.4)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook->livelossplot==0.3.4) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook->livelossplot==0.3.4) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook->livelossplot==0.3.4) (3.0.48)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook->livelossplot==0.3.4) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook->livelossplot==0.3.4) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook->livelossplot==0.3.4) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->livelossplot==0.3.4) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->livelossplot==0.3.4) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->livelossplot==0.3.4) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->livelossplot==0.3.4) (0.22.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->livelossplot==0.3.4) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->livelossplot==0.3.4) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook->livelossplot==0.3.4) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->livelossplot==0.3.4) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->notebook->livelossplot==0.3.4) (0.8.4)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->livelossplot==0.3.4) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->livelossplot==0.3.4) (1.8.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook->livelossplot==0.3.4) (0.2.13)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->livelossplot==0.3.4) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->livelossplot==0.3.4) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->livelossplot==0.3.4) (1.2.2)
# Downloading livelossplot-0.3.4-py3-none-any.whl (12 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.3 MB/s eta 0:00:00
# Installing collected packages: jedi, livelossplot
# Successfully installed jedi-0.19.2 livelossplot-0.3.4
# --2024-12-10 01:56:36--  https://www.dropbox.com/sh/75gzfgu7qo94pvh/AACk_w5M94GTwwhSItCqsemoa/Stockfish%205/stockfish-5-linux.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fo/m04ovd7a2mmasyx4ck2lm/ACAgMCinsKi39VS5oqAncok/Stockfish%205/stockfish-5-linux.zip?rlkey=1k1zbqg4slns4p89lw5zkj93h [following]
# --2024-12-10 01:56:36--  https://www.dropbox.com/scl/fo/m04ovd7a2mmasyx4ck2lm/ACAgMCinsKi39VS5oqAncok/Stockfish%205/stockfish-5-linux.zip?rlkey=1k1zbqg4slns4p89lw5zkj93h
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc591ff20ea930ffe8d981fab4ba.dl.dropboxusercontent.com/cd/0/inline/Cf81laUWv80635J7tjs3w-ywhUFzmVPrjBv9kU0ve1Wk-L5s7XhcIWBjd5raCfzpt5CJ50uOsl8hIc_DQ_uVK4EovJUNQn5fSZ_z7NS2U-7uomN5Yv3MDSPOCY-PyIdqmVI/file# [following]
# --2024-12-10 01:56:37--  https://uc591ff20ea930ffe8d981fab4ba.dl.dropboxusercontent.com/cd/0/inline/Cf81laUWv80635J7tjs3w-ywhUFzmVPrjBv9kU0ve1Wk-L5s7XhcIWBjd5raCfzpt5CJ50uOsl8hIc_DQ_uVK4EovJUNQn5fSZ_z7NS2U-7uomN5Yv3MDSPOCY-PyIdqmVI/file
# Resolving uc591ff20ea930ffe8d981fab4ba.dl.dropboxusercontent.com (uc591ff20ea930ffe8d981fab4ba.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:601b:15::a27d:80f
# Connecting to uc591ff20ea930ffe8d981fab4ba.dl.dropboxusercontent.com (uc591ff20ea930ffe8d981fab4ba.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Cf8AjWJWUvVXlLMfbytW8w9j1567L30Pd3FVgY1goP9u5T1H92syRs965Ph0bCh4e9ghrY4I7VoqBEb8qWF1oOb9lDtzD645nq6X0-Y4X44ZUe22jZBzMdtDXDu3hu3rxbNqlpWxT34TMzdZSEEu9Kyk4e1dl1uVyGRLdCKDMXw1xzq_ViGwboGVHERbrPjZ1B6MyyD0DUeXXtMfbaH_3HHWF2bKzA9G06LmVBx1GIl_mXYzAEdb8a2jYJ6cfGolA5MrN-w8_GH7nSm4BCioRNmrLzEiom2ulaCTRRcr0px4jEGQc3bksqPn6MBSA4SnNNINN1HZPKo7z9ZbbHq9jlGj4mgnlwL3rfDUiMXjcdmzJw/file [following]
# --2024-12-10 01:56:38--  https://uc591ff20ea930ffe8d981fab4ba.dl.dropboxusercontent.com/cd/0/inline2/Cf8AjWJWUvVXlLMfbytW8w9j1567L30Pd3FVgY1goP9u5T1H92syRs965Ph0bCh4e9ghrY4I7VoqBEb8qWF1oOb9lDtzD645nq6X0-Y4X44ZUe22jZBzMdtDXDu3hu3rxbNqlpWxT34TMzdZSEEu9Kyk4e1dl1uVyGRLdCKDMXw1xzq_ViGwboGVHERbrPjZ1B6MyyD0DUeXXtMfbaH_3HHWF2bKzA9G06LmVBx1GIl_mXYzAEdb8a2jYJ6cfGolA5MrN-w8_GH7nSm4BCioRNmrLzEiom2ulaCTRRcr0px4jEGQc3bksqPn6MBSA4SnNNINN1HZPKo7z9ZbbHq9jlGj4mgnlwL3rfDUiMXjcdmzJw/file
# Reusing existing connection to uc591ff20ea930ffe8d981fab4ba.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 594229 (580K) [application/zip]
# Saving to: ‘stockfish-5-linux.zip’
#
# stockfish-5-linux.z 100%[===================>] 580.30K  3.01MB/s    in 0.2s
#
# 2024-12-10 01:56:38 (3.01 MB/s) - ‘stockfish-5-linux.zip’ saved [594229/594229]
#
# Archive:  stockfish-5-linux.zip
#    creating: stockfish-5-linux/
#   inflating: stockfish-5-linux/Readme.md
#   inflating: stockfish-5-linux/polyglot.ini
#   inflating: stockfish-5-linux/logo.bmp
#   inflating: stockfish-5-linux/Copying.txt
#    creating: stockfish-5-linux/src_c++11/
#   inflating: stockfish-5-linux/src_c++11/ucioption.h
#   inflating: stockfish-5-linux/src_c++11/ucioption.cpp
#   inflating: stockfish-5-linux/src_c++11/uci.cpp
#   inflating: stockfish-5-linux/src_c++11/types.h
#   inflating: stockfish-5-linux/src_c++11/tt.h
#   inflating: stockfish-5-linux/src_c++11/tt.cpp
#   inflating: stockfish-5-linux/src_c++11/timeman.h
#   inflating: stockfish-5-linux/src_c++11/timeman.cpp
#   inflating: stockfish-5-linux/src_c++11/thread.h
#   inflating: stockfish-5-linux/src_c++11/thread.cpp
#   inflating: stockfish-5-linux/src_c++11/search.h
#   inflating: stockfish-5-linux/src_c++11/search.cpp
#   inflating: stockfish-5-linux/src_c++11/rkiss.h
#   inflating: stockfish-5-linux/src_c++11/psqtab.h
#   inflating: stockfish-5-linux/src_c++11/position.h
#   inflating: stockfish-5-linux/src_c++11/position.cpp
#   inflating: stockfish-5-linux/src_c++11/pawns.h
#   inflating: stockfish-5-linux/src_c++11/pawns.cpp
#   inflating: stockfish-5-linux/src_c++11/notation.h
#   inflating: stockfish-5-linux/src_c++11/notation.cpp
#   inflating: stockfish-5-linux/src_c++11/movepick.h
#   inflating: stockfish-5-linux/src_c++11/movepick.cpp
#   inflating: stockfish-5-linux/src_c++11/movegen.h
#   inflating: stockfish-5-linux/src_c++11/movegen.cpp
#   inflating: stockfish-5-linux/src_c++11/misc.h
#   inflating: stockfish-5-linux/src_c++11/misc.cpp
#   inflating: stockfish-5-linux/src_c++11/material.h
#   inflating: stockfish-5-linux/src_c++11/material.cpp
#   inflating: stockfish-5-linux/src_c++11/Makefile
#   inflating: stockfish-5-linux/src_c++11/main.cpp
#   inflating: stockfish-5-linux/src_c++11/evaluate.h
#   inflating: stockfish-5-linux/src_c++11/evaluate.cpp
#   inflating: stockfish-5-linux/src_c++11/endgame.h
#   inflating: stockfish-5-linux/src_c++11/endgame.cpp
#   inflating: stockfish-5-linux/src_c++11/book.h
#   inflating: stockfish-5-linux/src_c++11/book.cpp
#   inflating: stockfish-5-linux/src_c++11/bitcount.h
#   inflating: stockfish-5-linux/src_c++11/bitboard.h
#   inflating: stockfish-5-linux/src_c++11/bitboard.cpp
#   inflating: stockfish-5-linux/src_c++11/bitbase.cpp
#   inflating: stockfish-5-linux/src_c++11/benchmark.cpp
#    creating: stockfish-5-linux/src/
#   inflating: stockfish-5-linux/src/ucioption.h
#   inflating: stockfish-5-linux/src/ucioption.cpp
#   inflating: stockfish-5-linux/src/uci.cpp
#   inflating: stockfish-5-linux/src/types.h
#   inflating: stockfish-5-linux/src/tt.h
#   inflating: stockfish-5-linux/src/tt.cpp
#   inflating: stockfish-5-linux/src/timeman.h
#   inflating: stockfish-5-linux/src/timeman.cpp
#   inflating: stockfish-5-linux/src/thread.h
#   inflating: stockfish-5-linux/src/thread.cpp
#   inflating: stockfish-5-linux/src/search.h
#   inflating: stockfish-5-linux/src/search.cpp
#   inflating: stockfish-5-linux/src/rkiss.h
#   inflating: stockfish-5-linux/src/psqtab.h
#   inflating: stockfish-5-linux/src/position.h
#   inflating: stockfish-5-linux/src/position.cpp
#   inflating: stockfish-5-linux/src/platform.h
#   inflating: stockfish-5-linux/src/pawns.h
#   inflating: stockfish-5-linux/src/pawns.cpp
#   inflating: stockfish-5-linux/src/notation.h
#   inflating: stockfish-5-linux/src/notation.cpp
#   inflating: stockfish-5-linux/src/movepick.h
#   inflating: stockfish-5-linux/src/movepick.cpp
#   inflating: stockfish-5-linux/src/movegen.h
#   inflating: stockfish-5-linux/src/movegen.cpp
#   inflating: stockfish-5-linux/src/misc.h
#   inflating: stockfish-5-linux/src/misc.cpp
#   inflating: stockfish-5-linux/src/material.h
#   inflating: stockfish-5-linux/src/material.cpp
#   inflating: stockfish-5-linux/src/Makefile
#   inflating: stockfish-5-linux/src/main.cpp
#   inflating: stockfish-5-linux/src/evaluate.h
#   inflating: stockfish-5-linux/src/evaluate.cpp
#   inflating: stockfish-5-linux/src/endgame.h
#   inflating: stockfish-5-linux/src/endgame.cpp
#   inflating: stockfish-5-linux/src/book.h
#   inflating: stockfish-5-linux/src/book.cpp
#   inflating: stockfish-5-linux/src/bitcount.h
#   inflating: stockfish-5-linux/src/bitboard.h
#   inflating: stockfish-5-linux/src/bitboard.cpp
#   inflating: stockfish-5-linux/src/bitbase.cpp
#   inflating: stockfish-5-linux/src/benchmark.cpp
#    creating: stockfish-5-linux/Linux/
#   inflating: stockfish-5-linux/Linux/stockfish_14053109_x64_modern
#   inflating: stockfish-5-linux/Linux/stockfish_14053109_x64

# %%
# !chmod +x stockfish-5-linux/Linux/stockfish_14053109_x64

# %%
import chess
import chess.engine

# %%
# Cell 1: Imports
import os
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torch.nn.modules.transformer import TransformerEncoder, TransformerEncoderLayer
from tqdm import tqdm
import numpy as np
import re
from pathlib import Path

# %%
import os
import re


if __name__ == "__main__":
    vocab_counter = set()

    with open(f"dataset/processed_kaggle2.txt", "w", encoding="utf-8") as outf:
        with open("/content/dataset/all_with_filtered_anotations_since1998 copy (1).txt", "r", encoding="utf-8") as inpf:
            for line in inpf:
                try:
                    ostr = line.split("###")[1].strip()
                    ostr = re.sub("W\d+.", "", ostr)
                    ostr = re.sub("B\d+.", "", ostr)

                    if len(ostr) > 0:
                        if ostr[-1] != '\n':
                            ostr = ostr + '\n'

                        outf.write(ostr)

                        for move in ostr.split(" "):
                            move = move.replace("\n", "")

                            if move != "":
                                vocab_counter.add(move)
                    else:
                        a = 0
                except:
                    pass

        os.makedirs("vocabs", exist_ok=True)

        with open(f"vocabs/kaggle2.txt", "w", encoding="utf-8") as f:
            for v in vocab_counter:
                f.write(v + "\n")

# %%
import os


VOCAB_DIR = "vocabs"


class Tokenizer:
    pad_token_index: int = 0
    bos_token_index: int = 1
    eos_token_index: int = 2
    unk_token_index: int = 3

    pad_token: str = "<pad>"
    bos_token: str = "<bos>"
    eos_token: str = "<eos>"
    unk_token: str = "<unk>"

    def __init__(self, vocab_path: str = f"{VOCAB_DIR}/kaggle2_vocab.txt") -> None:
        self.vocab_dict = {
            self.pad_token: self.pad_token_index,
            self.bos_token: self.bos_token_index,
            self.eos_token: self.eos_token_index,
            self.unk_token: self.unk_token_index,
        }

        with open(vocab_path, "r", encoding="utf-8") as f:
            for i, token in enumerate(f):
                self.vocab_dict[token.replace("\n", "")] = i + 4

    def encode(self, token_str: str, add_bos_token=True):
        encoded = []

        if add_bos_token:
            encoded.append(self.bos_token_index)

        for token in token_str.split():
            if token in self.vocab_dict:
                encoded.append(self.vocab_dict[token])
            else:
                encoded.append(self.unk_token_index)

        return encoded

    def decode(self, token_ids: list):
        decoded = []

        for token_id in token_ids:
            for token, index in self.vocab_dict.items():
                if index == token_id:
                    decoded.append(token)

        return " ".join(decoded)


    def vocab_size(self) -> int:
        return len(self.vocab_dict)


    @classmethod
    def generate_vocab(cls, dataset_path: str):
        from pathlib import Path
        from tqdm import tqdm

        vocab_counter = set()

        for game in tqdm(Path(dataset_path).glob("*.txt")):
            game = game.read_text(encoding="utf-8")
            for move in game.split(" "):
                move = move.replace("\n", "")

                if move != "":
                    vocab_counter.add(move)

        os.makedirs(VOCAB_DIR, exist_ok=True)

        with open(f"{VOCAB_DIR}/kaggle2.txt", "w", encoding="utf-8") as f:
            for v in vocab_counter:
                f.write(v + "\n")


if __name__ == "__main__":
    # Tokenizer.generate_vocab("dataset/kaggle2/")
    tokenizer = Tokenizer("/content/kaggle2_vocab.txt")
    encoded = tokenizer.encode("d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 pepe Bb4+ Nc3 Ba5 Bf4 <eos>")
    decoded = tokenizer.decode(encoded)
    print(encoded)
    print(decoded)
# Out:
# [1, 7868, 3527, 6882, 5263, 8288, 7190, 9989, 7788, 463, 3, 365, 3589, 7400, 5293, 2]
# <bos> d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 <unk> Bb4+ Nc3 Ba5 Bf4 <eos>

# %%
# Cell 2: PGNDataset Class
class PGNDataset(Dataset):
    def __init__(self, tokenizer: Tokenizer, path: str, n_positions=512):
        self.n_positions = n_positions
        self.tokenizer = tokenizer
        self.games = []

        with open(path, "r", encoding="utf-8") as f:
            for line in f:
                self.games.append(line)

        print("Dataset read.")

    def __pad(self, sample: list):
        while len(sample) < self.n_positions:
            sample.append(self.tokenizer.pad_token_index)
        return sample[:self.n_positions]

    def __len__(self):
        return len(self.games)

    def __getitem__(self, i):
        game = self.games[i]
        encoded = self.tokenizer.encode(game, add_bos_token=True)

        if len(encoded) < self.n_positions:
            encoded.append(self.tokenizer.eos_token_index)

        data = self.__pad(encoded)
        return torch.tensor(data)

# %%
import os
import math

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.modules.transformer import TransformerEncoder, TransformerEncoderLayer




# DIR = os.path.dirname(os.path.realpath(__file__))
DEVICE = "cuda"


class PositionalEncoding(nn.Module):
    def __init__(self, dim_model, dropout_p, max_len):
        super().__init__()
        # Modified version from: https://pytorch.org/tutorials/beginner/transformer_tutorial.html
        # max_len determines how far the position can have an effect on a token (window)

        # Info
        self.dropout = nn.Dropout(dropout_p)

        # Encoding - From formula
        pos_encoding = torch.zeros(max_len, dim_model)
        positions_list = torch.arange(
            0, max_len, dtype=torch.float).view(-1, 1)  # 0, 1, 2, 3, 4, 5
        division_term = torch.exp(torch.arange(0, dim_model, 2).float(
        ) * (-math.log(10000.0)) / dim_model)  # 1000^(2i/dim_model)

        # PE(pos, 2i) = sin(pos/1000^(2i/dim_model))
        pos_encoding[:, 0::2] = torch.sin(positions_list * division_term)

        # PE(pos, 2i + 1) = cos(pos/1000^(2i/dim_model))
        pos_encoding[:, 1::2] = torch.cos(positions_list * division_term)

        # Saving buffer (same as parameter without gradients needed)
        pos_encoding = pos_encoding.unsqueeze(0).transpose(0, 1)
        self.register_buffer("pos_encoding", pos_encoding)

    def forward(self, token_embedding: torch.Tensor) -> torch.Tensor:
        # Residual connection + pos encoding
        return self.dropout(token_embedding + self.pos_encoding[:token_embedding.size(0), :])


class Transformer(nn.Module):

    def __init__(
        self,
        tokenizer: Tokenizer,
        num_tokens: int,
        dim_model: int,
        num_heads: int,
        d_hid: int,
        num_layers: int,
        dropout_p: float,
        n_positions: int,
    ):
        super().__init__()

        self.tokenizer = tokenizer

        # INFO
        self.model_type = "Transformer"
        self.dim_model = dim_model
        self.n_positions = n_positions

        # LAYERS
        self.positional_encoder = PositionalEncoding(
            dim_model=dim_model, dropout_p=dropout_p, max_len=n_positions
        )
        self.embedding = nn.Embedding(
            num_tokens, dim_model, padding_idx=self.tokenizer.pad_token_index)

        encoder_layers = TransformerEncoderLayer(
            dim_model,
            num_heads,
            d_hid,
            dropout_p,
            batch_first=False,
            activation=F.gelu,
            norm_first=True,
        )
        self.transformer_encoder = TransformerEncoder(
            encoder_layers, num_layers)

        self.out = nn.Linear(dim_model, num_tokens)

        self.init_weights()

    def init_weights(self) -> None:
        nn.init.xavier_uniform_(self.embedding.weight)
        nn.init.xavier_uniform_(self.out.weight)

    def forward(self, src, src_mask=None, src_pad_mask=None) -> torch.Tensor:
        # Embedding + positional encoding - Out size = (batch_size, sequence length, dim_model)
        src = self.embedding(src) * math.sqrt(self.dim_model)
        src = self.positional_encoder(src)

        # Transformer blocks - Out size = (sequence length, batch_size, num_tokens)
        transformer_out = self.transformer_encoder(
            src,
            src_mask,
            src_pad_mask,
        )

        out = self.out(transformer_out)

        return F.log_softmax(out, dim=-1)

    def get_src_mask(self, sz) -> torch.Tensor:
        return torch.triu(torch.ones(sz, sz) * float('-inf'), diagonal=1)

    def get_pad_mask(self, matrix: torch.Tensor, pad_token: int) -> torch.Tensor:
        return (matrix == pad_token).t()

    def predict(
        self,
        input_string: str = "<bos>",
        max_length=80,
        stop_at_next_move=False,
        temperature=0.5
    ) -> str:
        import chess

        board = chess.Board()
        self.eval()

        input_sequence = self.tokenizer.encode(
            input_string, add_bos_token=False)

        for token in input_string.split(" ")[1:]:
            board.push_san(token)

        if board.is_checkmate():
            input_string += " <eos>"

        y_input = torch.tensor(
            [input_sequence], dtype=torch.long, device="cpu").t()

        if stop_at_next_move:
            max_length = 1
        else:
            max_length -= len(input_sequence)

        for _ in range(max_length):
            y_size = y_input.size(0)
            begin_loc = max(y_size - self.n_positions, 0)

            if y_size > self.n_positions and begin_loc % 2 != 0:
                # Let's help the model know what turn it is
                begin_loc += 1

            end_loc = min(begin_loc + self.n_positions, y_size)
            input_ids = y_input[begin_loc:end_loc]

            src_mask = self.get_src_mask(input_ids.size(0)).to("cpu")
            pad_mask = self.get_pad_mask(
                input_ids, self.tokenizer.pad_token_index).to("cpu")

            pred = self.forward(input_ids, src_mask, pad_mask)

            word_weights = pred[-1].squeeze().div(temperature).exp()
            word_idx = torch.multinomial(word_weights, 10)

            for wi in word_idx:
                decoded = self.tokenizer.decode([wi])
                try:
                    board.parse_san(decoded)
                    word_idx = wi
                    break
                except:
                    continue

            if word_idx.ndim > 0:
                # If the model doesn't know what to move, surrenders
                next_item = torch.tensor([[self.tokenizer.eos_token_index]], device="cpu")
                y_input = torch.cat((y_input, next_item), dim=0)
                break

            next_item = torch.tensor([[word_idx]], device="cpu")
            board.push_san(self.tokenizer.decode([next_item]))

            # Concatenate previous input with predicted best word
            y_input = torch.cat((y_input, next_item), dim=0)

            if board.is_checkmate():
                # If it checkmates the opponent, return with <eos>
                next_item = torch.tensor([[self.tokenizer.eos_token_index]], device="cpu")
                y_input = torch.cat((y_input, next_item), dim=0)
                break

            # Stop if model predicts end of sentence
            if next_item.view(-1).item() == self.tokenizer.eos_token_index:
                break

        return self.tokenizer.decode(y_input.view(-1).tolist())

# %%
# Configuration Constants
n_positions = 80
dim_model = 768
d_hid = 3072
num_heads = 12
num_layers = 12
dropout_p = 0.1

import os
import argparse
from tqdm import tqdm
import numpy as np
import torch
from torch.utils.data import DataLoader, random_split



def _parse_args():
    parser = argparse.ArgumentParser(description='Chessformers trainer parser')

    # Providing default values for arguments
    parser.add_argument('--tokenizer', type=str, default="vocabs/kaggle2_vocab.txt", help='location of the tokenizer file')
    parser.add_argument('--dataset', type=str, default="dataset/processed_kaggle2.txt", help='location of the dataset')
    parser.add_argument('--batch_size', type=int, default=64, help='training batch size')
    parser.add_argument('--epochs', type=int, default=1, help='number of training epochs')
    parser.add_argument('--lr', type=float, default=0.00025, help='learning rate')
    parser.add_argument('--beta1', type=float, default=0.9, help='adam beta')
    parser.add_argument('--save_dir', type=str, default='./model', help='save model directory')
    parser.add_argument('--load_model', type=str, default=None, help='model to load and resume training')

    # Use parse_known_args to handle unknown arguments in Jupyter Notebook
    args, unknown = parser.parse_known_args()
    return args


class Trainer:
    def __init__(self, model, train_loader, val_loader, loss_fn, save_dir, learning_rate, num_epochs, adam_beta):
        self.save_dir = save_dir
        self.model = model
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.lr = learning_rate
        self.loss_fn = loss_fn
        self.num_epochs = num_epochs

        self.optimizer = torch.optim.Adam(
            self.model.parameters(), lr=self.lr, betas=(adam_beta, 0.999))

        self.device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
        print(f'Selected device: {self.device}.')

        self.model.to(self.device)

    def train_epoch(self):
        self.model.train()
        train_loss = []
        for local_batch in tqdm(self.train_loader):
            X = local_batch.to(self.device).t().contiguous()
            y_input = X[:-1]
            y_expected = X[1:].reshape(-1)

            src_mask = self.model.get_src_mask(y_input.size(0)).to(self.device)
            pad_mask = self.model.get_pad_mask(
                y_input, self.model.tokenizer.pad_token_index).to(self.device)

            pred = self.model(y_input, src_mask, pad_mask)
            loss = self.loss_fn(pred.view(-1, self.model.tokenizer.vocab_size()), y_expected)

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
            train_loss.append(loss.detach().cpu().numpy())
        return np.mean(train_loss)

    def test_epoch(self):
        self.model.eval()
        total_loss = 0.0
        with torch.no_grad():
            for local_batch in self.val_loader:
                X = local_batch.to(self.device).t().contiguous()
                y_input = X[:-1]
                y_expected = X[1:].reshape(-1)

                src_mask = self.model.get_src_mask(y_input.size(0)).to(self.device)
                pad_mask = self.model.get_pad_mask(
                    y_input, self.model.tokenizer.pad_token_index).to(self.device)

                pred = self.model(y_input, src_mask, pad_mask)
                loss = self.loss_fn(pred.view(-1, self.model.tokenizer.vocab_size()), y_expected)
                total_loss += loss
        return total_loss / len(self.val_loader)

    def train(self):
        best_val_loss = float('inf')
        for epoch in range(self.num_epochs):
            print(f"\n -------- EPOCH {epoch + 1}/{self.num_epochs} --------")
            train_loss = self.train_epoch()
            val_loss = self.test_epoch()

            print(f"Train Loss: {train_loss:.4f} | Validation Loss: {val_loss:.4f}")

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                torch.save(self.model.state_dict(), os.path.join(self.save_dir, f"model_epoch_{epoch + 1}.pth"))

        torch.save(self.model.state_dict(), os.path.join(self.save_dir, "final_model.pth"))


def main(args):
    os.makedirs(args.save_dir, exist_ok=True)
    tokenizer = Tokenizer(args.tokenizer)

    # Prepare the data
    dataset = PGNDataset(tokenizer, args.dataset, n_positions=n_positions)
    train_len = int(0.8 * len(dataset))
    train_data, val_data = random_split(dataset, [train_len, len(dataset) - train_len])

    train_loader = DataLoader(train_data, batch_size=args.batch_size, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=args.batch_size, shuffle=False)

    # Define the model
    model = Transformer(
        tokenizer=tokenizer,
        num_tokens=tokenizer.vocab_size(),
        dim_model=dim_model,
        d_hid=d_hid,
        num_heads=num_heads,
        num_layers=num_layers,
        dropout_p=dropout_p,
        n_positions=n_positions
    )

    if args.load_model:
        print("Loading pre-trained model...")
        model.load_state_dict(torch.load(args.load_model))

    loss_fn = torch.nn.NLLLoss(ignore_index=tokenizer.pad_token_index)
    trainer = Trainer(model, train_loader, val_loader, loss_fn, args.save_dir, args.lr, args.epochs, args.beta1)
    trainer.train()


if __name__ == "__main__":
    args = _parse_args()
    main(args)

# %%
"""
Script used to play against the chessformers.
Human plays as white.
"""

import argparse
import torch


n_positions = 80
dim_model = 768
d_hid = 3072
num_heads = 12
num_layers = 12
dropout_p = 0.1

def _parse_args():
    parser = argparse.ArgumentParser(
        description='Chessformers inference parser')

    parser.add_argument('--load_model', type=str, default="/content/ChessGpt_Scratch.pth",
                        help='model to load and do inference')

    parser.add_argument('--tokenizer', type=str, default="/content/kaggle2_vocab.txt",
                        help='location of the tokenizer file')

    args, unknown = parser.parse_known_args()
    return args


def main(args) -> None:
    tokenizer = Tokenizer(args.tokenizer)
    model = Transformer(tokenizer,
                        num_tokens=tokenizer.vocab_size(),
                        dim_model=dim_model,
                        d_hid=d_hid,
                        num_heads=num_heads,
                        num_layers=num_layers,
                        dropout_p=dropout_p,
                        n_positions=n_positions,
                        )
    # model.load_state_dict(torch.load(args.load_model))
    model.load_state_dict(torch.load(args.load_model, map_location=torch.device('cpu')))

    print(
        "===== CHESSFORMERS ENGINE =====\n"
    + "    Enter valid moves in PGN format.\n"
    + "    Enter \\b to undo a move.\n"
    + "    Enter \\m to show all moves\n"
    )

    input_string = "<bos>"
    boards = [input_string]

    while (len(input_string.split(" ")) < n_positions
           and input_string.split(" ")[-1] != tokenizer.eos_token):
        next_move = input("WHITE MOVE: ")

        if next_move == "\\m":
            print(input_string)
            continue
        elif next_move == "\\b":
            if len(boards) > 1:
                boards.pop()

            input_string = boards[-1]
            continue

        prev_input_string = input_string
        input_string += " " + next_move
        print(input_string)
        try:
            input_string = model.predict(
                input_string,
                stop_at_next_move=True,
                temperature=0.2,
                )
            boards.append(input_string)
            print("BLACK MOVE:", input_string.split(" ")[-1])
        except ValueError:
            input_string = prev_input_string
            print("ILLEGAL MOVE. Please, try again.")
        except Exception as e:
            print("UNHANDLED EXCEPTION. Please, try again.")

    print("--- Final board ---")
    print(input_string)


if __name__ == "__main__":
    args = _parse_args()
    main(args)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# <ipython-input-9-0821558b0749>:43: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(args.load_model, map_location=torch.device('cpu')))
# ===== CHESSFORMERS ENGINE =====
#     Enter valid moves in PGN format.
#     Enter \b to undo a move.
#     Enter \m to show all moves
#
# WHITE MOVE: e4
# <bos> e4
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5849: UserWarning: Support for mismatched src_key_padding_mask and mask is deprecated. Use same type for both instead.
#   warnings.warn(
# BLACK MOVE: c5
# WHITE MOVE: c4
# <bos> e4 c5 c4
# BLACK MOVE: Nc6
# WHITE MOVE: Nf3
# <bos> e4 c5 c4 Nc6 Nf3
# BLACK MOVE: g6
# WHITE MOVE: Nc3
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3
# BLACK MOVE: Bg7
# WHITE MOVE: Bd3
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3
# BLACK MOVE: d6
# WHITE MOVE: O-O
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O
# BLACK MOVE: Nf6
# WHITE MOVE: h3
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3
# BLACK MOVE: O-O
# WHITE MOVE: a3
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3
# BLACK MOVE: a6
# WHITE MOVE: Bd5
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Bd5
# ILLEGAL MOVE. Please, try again.
# WHITE MOVE: Nd5
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5
# BLACK MOVE: e6
# WHITE MOVE: Nxf6+
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+
# BLACK MOVE: Bxf6
# WHITE MOVE: Rb1
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1
# BLACK MOVE: Rb8
# WHITE MOVE: b3
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3
# BLACK MOVE: b5
# WHITE MOVE: Bb2
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2
# BLACK MOVE: Bxb2
# WHITE MOVE: Rxb2
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2
# BLACK MOVE: Qf6
# WHITE MOVE: Rb1
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1
# BLACK MOVE: b4
# WHITE MOVE: axb4
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4
# BLACK MOVE: Nxb4
# WHITE MOVE: Bc2
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2
# BLACK MOVE: Bb7
# WHITE MOVE: Re1
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1
# BLACK MOVE: Rfd8
# WHITE MOVE: e5
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5
# BLACK MOVE: dxe5
# WHITE MOVE: Nxe5
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5
# BLACK MOVE: Rxd2
# WHITE MOVE: Qxd2
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2
# BLACK MOVE: Nxc2
# WHITE MOVE: Qxc2
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2
# BLACK MOVE: Qg5
# WHITE MOVE: g3
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3
# BLACK MOVE: Qf5
# WHITE MOVE: Qxf5
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5
# BLACK MOVE: exf5
# WHITE MOVE: Nd7
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7
# BLACK MOVE: Rd8
# WHITE MOVE: Nxc5
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5
# BLACK MOVE: Bc8
# WHITE MOVE: Rbd1
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1
# BLACK MOVE: Rxd1
# WHITE MOVE: Rxd1
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1
# BLACK MOVE: Kg7
# WHITE MOVE: Rd8
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8
# BLACK MOVE: Be6
# WHITE MOVE: Nxa6
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6
# BLACK MOVE: Kf6
# WHITE MOVE: c5
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6 Kf6 c5
# BLACK MOVE: Ke7
# WHITE MOVE: Rd4
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6 Kf6 c5 Ke7 Rd4
# BLACK MOVE: Bc8
# WHITE MOVE: Nb4
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6 Kf6 c5 Ke7 Rd4 Bc8 Nb4
# BLACK MOVE: Be6
# WHITE MOVE: c6
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6 Kf6 c5 Ke7 Rd4 Bc8 Nb4 Be6 c6
# BLACK MOVE: Bc8
# WHITE MOVE: Nxd5+
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6 Kf6 c5 Ke7 Rd4 Bc8 Nb4 Be6 c6 Bc8 Nxd5+
# BLACK MOVE: Kd6
# WHITE MOVE: Nb4+
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6 Kf6 c5 Ke7 Rd4 Bc8 Nb4 Be6 c6 Bc8 Nxd5+ Kd6 Nb4+
# BLACK MOVE: Kc5
# WHITE MOVE: Rd8
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6 Kf6 c5 Ke7 Rd4 Bc8 Nb4 Be6 c6 Bc8 Nxd5+ Kd6 Nb4+ Kc5 Rd8
# BLACK MOVE: Be6
# WHITE MOVE: c7
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6 Kf6 c5 Ke7 Rd4 Bc8 Nb4 Be6 c6 Bc8 Nxd5+ Kd6 Nb4+ Kc5 Rd8 Be6 c7
# BLACK MOVE: Kxb4
# WHITE MOVE: c8=Q
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6 Kf6 c5 Ke7 Rd4 Bc8 Nb4 Be6 c6 Bc8 Nxd5+ Kd6 Nb4+ Kc5 Rd8 Be6 c7 Kxb4 c8=Q
# BLACK MOVE: Bxc8
# WHITE MOVE: Rxc8
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6 Kf6 c5 Ke7 Rd4 Bc8 Nb4 Be6 c6 Bc8 Nxd5+ Kd6 Nb4+ Kc5 Rd8 Be6 c7 Kxb4 c8=Q Bxc8 Rxc8
# BLACK MOVE: <eos>
# --- Final board ---
# <bos> e4 c5 c4 Nc6 Nf3 g6 Nc3 Bg7 Bd3 d6 O-O Nf6 h3 O-O a3 a6 Nd5 e6 Nxf6+ Bxf6 Rb1 Rb8 b3 b5 Bb2 Bxb2 Rxb2 Qf6 Rb1 b4 axb4 Nxb4 Bc2 Bb7 Re1 Rfd8 e5 dxe5 Nxe5 Rxd2 Qxd2 Nxc2 Qxc2 Qg5 g3 Qf5 Qxf5 exf5 Nd7 Rd8 Nxc5 Bc8 Rbd1 Rxd1 Rxd1 Kg7 Rd8 Be6 Nxa6 Kf6 c5 Ke7 Rd4 Bc8 Nb4 Be6 c6 Bc8 Nxd5+ Kd6 Nb4+ Kc5 Rd8 Be6 c7 Kxb4 c8=Q Bxc8 Rxc8 <eos>

# %%
import chess#https://github.com/niklasf/python-chess

board = chess.Board()
board

# %% [markdown]
# # Evaluation code(Playing against Chess engine)

# %%
import chess
import chess.engine
import argparse
import torch

n_positions = 80
dim_model = 768
d_hid = 3072
num_heads = 12
num_layers = 12
dropout_p = 0.1

def _parse_args():
    parser = argparse.ArgumentParser(
        description='Chessformers inference parser')

    parser.add_argument('--load_model', type=str, default="/content/chessformer_epoch_13.pth",
                        help='model to load and do inference')
    parser.add_argument('--tokenizer', type=str, default="/content/vocabs/kaggle2_vocab.txt",
                        help='location of the tokenizer file')
    parser.add_argument('--engine_path', type=str, default="/content/stockfish-5-linux/Linux/stockfish_14053109_x64",
                        help='Path to the chess engine executable')
    parser.add_argument('--games', type=int, default=1000,
                        help='Number of games to simulate')

    args, _ = parser.parse_known_args()
    return args


def play_game(model, tokenizer, engine, results, game_number):
    board = chess.Board()
    input_string = "<bos>"
    print(f"\nGame {game_number} Start")
    engine.configure({"Skill Level": 1})
    # engine.configure({"UCI_LimitStrength": True, "UCI_Elo": 800})

    while not board.is_game_over() and len(input_string.split(" ")) < n_positions:
        try:
            if board.turn:  # White's turn (Model)
                lastmove = input_string.split(" ")[-1]
                input_string = model.predict(
                    input_string,
                    stop_at_next_move=True,
                    temperature=0.2,
                )
                # print(input_string)

                move = input_string.split(" ")[-1]
                if(move=="<eos>"):

                  if(lastmove==move):
                    if not board.is_game_over():
                        print("Unknown error")
                        print(f"debug: {input_string}")
                        results["Unknown"]["Unknown"] += 1
                        return "Unknown Result"
                    else:
                      print("Result: Checkmate")
                      if board.turn == chess.BLACK:
                          results["White Wins"]["Checkmate"] += 1
                          return "White Wins (Checkmate)"
                      else:
                          results["Black Wins"]["Checkmate"] += 1
                          return "Black Wins (Checkmate)"
                  else:
                    print("Game Over <eos>")
                    results['EOS']['EOS'] += 1
                    move = input_string.split(" ")[-2]
                    if not board.is_game_over():
                        print("Unknown error")
                        print(f"debug: {input_string}")

                    else:
                      print(f"EOS: {input_string}")
                      print("Result: Checkmate")
                      if board.turn == chess.BLACK:
                          results["White Wins"]["Checkmate"] += 1
                          return "White Wins (Checkmate)"
                      else:
                          results["Black Wins"]["Checkmate"] += 1
                          return "Black Wins (Checkmate)"


                # print(f"Predicted move (SAN): {move}")

                try:
                    # Parse SAN move and check legality
                    san_move_obj = board.parse_san(move)
                    # print(f"Predicted move (obj): {san_move_obj}")
                    if san_move_obj in board.legal_moves:
                        board.push(san_move_obj)
                        # print(f"White (Model): {move}")
                    else:
                        raise ValueError(f"Illegal move: {move}")
                except (chess.IllegalMoveError, ValueError) as e:
                    print(f"Model predicted an invalid move: {e}")
                    break
            else:  # Black's turn (Engine)
                result = engine.play(board, chess.engine.Limit(time=0.005))
                san_move = board.san(result.move)
                input_string = input_string + " " + san_move
                # print(f"Black (Engine): {san_move}")
                board.push(result.move)

        except Exception as e:
            print(f"An error occurred during the game loop: {e}")
            break
        if board.is_repetition():
            print("Result: Draw (Threefold Repetition)")
            results["Draw"]["Threefold Repetition"] += 1
            return "Draw (Threefold Repetition)"

    # Print the final board state
    print("\nFinal Board Position:")
    print(board)
    if(len(input_string.split(" ")) >= n_positions):
      results["Draw"]["80-move Rule"] += 1
      return "Draw (80+ moves)"

    # Determine result
    if board.is_checkmate():
        print("Result: Checkmate")
        if board.turn == chess.BLACK:
            results["White Wins"]["Checkmate"] += 1
            return "White Wins (Checkmate)"
        else:
            results["Black Wins"]["Checkmate"] += 1
            return "Black Wins (Checkmate)"
    elif board.is_stalemate():
        print("Result: Stalemate")
        results["Draw"]["Stalemate"] += 1
        return "Draw (Stalemate)"
    elif board.is_insufficient_material():
        print("Result: Draw (Insufficient Material)")
        results["Draw"]["Insufficient Material"] += 1
        return "Draw (Insufficient Material)"
    elif board.is_seventyfive_moves():
        print("Result: Draw (80-move Rule)")
        results["Draw"]["80-move Rule"] += 1
        return "Draw (80-move Rule)"

    results["Unknown"]["Unknown"] += 1
    print(f"UNKnown: {input_string}")
    return "Unknown Result"


def main(args):
    # Load the tokenizer and model
    tokenizer = Tokenizer(args.tokenizer)
    model = Transformer(
        tokenizer,
        num_tokens=tokenizer.vocab_size(),
        dim_model=dim_model,
        d_hid=d_hid,
        num_heads=num_heads,
        num_layers=num_layers,
        dropout_p=dropout_p,
        n_positions=n_positions,
    )
    model.load_state_dict(torch.load(args.load_model, map_location=torch.device('cpu')))

    # Initialize results tracker
    results = {
        "White Wins": {"Checkmate": 0},
        "Black Wins": {"Checkmate": 0},
        "Draw": {"Stalemate": 0, "Insufficient Material": 0, "80-move Rule": 0, "Threefold Repetition": 0},
        "Unknown":{"Unknown": 0},
        "EOS":{"EOS":0},
    }

    # Load the chess engine
    with chess.engine.SimpleEngine.popen_uci(args.engine_path) as engine:
        for game_number in range(1, args.games + 1):
            result = play_game(model, tokenizer, engine, results, game_number)

            # Print results after each game
            print(f"\nGame {game_number} Result: {result}")
            print("\nCumulative Results:")
            print(f"  White Wins: {results['White Wins']['Checkmate']}")
            print(f"  Black Wins: {results['Black Wins']['Checkmate']}")
            print(f"  Draws: {sum(results['Draw'].values())}")
            print(f"  Unknown: {results['Unknown']['Unknown']}")
            print(f"EOS: {results['EOS']['EOS']}")
            print("\nDetailed Draw Breakdown:")
            for reason, count in results["Draw"].items():
                print(f"    {reason}: {count}")


    # Calculate final statistics
    total_games = sum(
        [results["White Wins"]["Checkmate"], results["Black Wins"]["Checkmate"]] +
        list(results["Draw"].values())
    )
    white_wins = results["White Wins"]["Checkmate"]
    black_wins = results["Black Wins"]["Checkmate"]
    draws = sum(results["Draw"].values())

    print("\nFinal Game Statistics:")
    print(f"Total Games: {total_games}")
    print(f"White Wins: {white_wins}")
    print(f"Black Wins: {black_wins}")
    print(f"Draws: {draws}")
    print(f"  Unknown: {results['Unknown']['Unknown']}")
    print("\nDetailed Draw Breakdown:")
    for reason, count in results["Draw"].items():
        print(f"  {reason}: {count}")

    win_percentage = (white_wins / total_games) * 100
    draw_percentage = (draws / total_games) * 100
    loss_percentage = (black_wins / total_games) * 100

    print(f"\nWin Percentage: {win_percentage:.2f}%")
    print(f"Draw Percentage: {draw_percentage:.2f}%")
    print(f"Loss Percentage: {loss_percentage:.2f}%")


if __name__ == "__main__":
    args = _parse_args()
    main(args)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# <ipython-input-12-f5c277e4079e>:160: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(args.load_model, map_location=torch.device('cpu')))
# Game 1 Start
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5849: UserWarning: Support for mismatched src_key_padding_mask and mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
#   Unknown: 24
# EOS: 57
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 514
#     Threefold Repetition: 60
#
# Game 814 Start
#
# Final Board Position:
# . . . . r . . k
# . . . . . . p .
# . p . . . . B .
# . . p . . . . Q
# p . . . . . . .
# P . . . . . . .
# . P . . . P P P
# . . . . . . K .
#
# Game 814 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 28
#   Black Wins: 185
#   Draws: 577
#   Unknown: 24
# EOS: 57
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 515
#     Threefold Repetition: 60
#
# Game 815 Start
#
# Final Board Position:
# r . . . . k . .
# . p p . . p . .
# p . . . . . . .
# . . . . . . . .
# . . P P . P . .
# . . . . P . . .
# P . . . . . . r
# R . . . K . q .
# Result: Checkmate
#
# Game 815 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 28
#   Black Wins: 186
#   Draws: 577
#   Unknown: 24
# EOS: 57
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 515
#     Threefold Repetition: 60
#
# Game 816 Start
#
# Final Board Position:
# . . . . . . . .
# . . r . k . . .
# . . . . p . . p
# p . . . . p . P
# . . . . . P . .
# P . N . . K . .
# . P . . . . . .
# . . . . . . . .
#
# Game 816 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 28
#   Black Wins: 186
#   Draws: 578
#   Unknown: 24
# EOS: 57
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 516
#     Threefold Repetition: 60
#
# Game 817 Start
#
# Final Board Position:
# . . . . . . . .
# . p . k . q . p
# p . . . . . . .
# . . p . . . K .
# . . P . . . . .
# . . . . . . . .
# P . . . . . P P
# . . . . . . . .
#
# Game 817 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 28
#   Black Wins: 186
#   Draws: 579
#   Unknown: 24
# EOS: 57
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 517
#     Threefold Repetition: 60
#
# Game 818 Start
# Game Over <eos>
# Unknown error
# debug: <bos> d4 c5 d5 f5 c4 d6 Nc3 Nf6 Nf3 Bd7 g3 e5 dxe6 Bxe6 Ng5 Bd7 Bg2 h6 Nh3 Qb6 O-O g5 f4 g4 Nf2 h5 e4 Nxe4 Ncxe4 fxe4 Nxe4 Be7 Re1 Kf7 Ng5+ Bxg5 fxg5 Kg7 Re7+ Kf8 g6 Kxe7 Bg5+ Ke6 Qd5+ <eos>
#
# Final Board Position:
# r n . . . . . r
# p p . b . . . .
# . q . p k . P .
# . . p Q . . B p
# . . P . . . p .
# . . . . . . P .
# P P . . . . B P
# R . . . . . K .
# Result: Checkmate
#
# Game 818 Result: White Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 29
#   Black Wins: 186
#   Draws: 579
#   Unknown: 24
# EOS: 58
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 517
#     Threefold Repetition: 60
#
# Game 819 Start
#
# Final Board Position:
# . . . r . . . k
# . . . P . . . p
# p . . . . . . .
# P . N . . . . .
# . P p . . . . .
# . . q . . . P .
# . . . . . r . .
# . . . R . . K .
#
# Game 819 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 29
#   Black Wins: 186
#   Draws: 580
#   Unknown: 24
# EOS: 58
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 518
#     Threefold Repetition: 60
#
# Game 820 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# . . . k . . . .
# . . . . n . N .
# . . . . . . . .
# . . P . . . . .
# P . . . . . P P
# . . . . . . K .
#
# Game 820 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 29
#   Black Wins: 186
#   Draws: 581
#   Unknown: 24
# EOS: 58
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 519
#     Threefold Repetition: 60
#
# Game 821 Start
#
# Final Board Position:
# . . . . . . . .
# . R . . b . p p
# p . . . . . . .
# . . . n . r . K
# . P . . r . . .
# P . k . . . B .
# . . . . . P P P
# . . . . . . . .
# Result: Checkmate
#
# Game 821 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 29
#   Black Wins: 187
#   Draws: 581
#   Unknown: 24
# EOS: 58
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 519
#     Threefold Repetition: 60
#
# Game 822 Start
# Game Over <eos>
# Unknown error
# debug: <bos> d4 Nc6 Nf3 e6 c4 Nf6 Nc3 Bb4 Qc2 d6 Bd2 e5 d5 Bxc3 Bxc3 Ne7 e4 O-O Be2 Bg4 h3 Bxf3 Bxf3 g6 g4 a6 Bd2 Nd7 Bh6 Nc5 h4 Qd7 h5 Rfc8 hxg6 Nxg6 O-O-O Rd8 Bg5 Rdc8 Bf6 c6 Qd2 Nf4 Kb1 a5 Rh6 Ncd3 Rdh1 Kf8 Rxh7 Qxg4 Bxg4 Ng6 Qh6+ Ke8 Rh8# Nxh8 Qxh8+ <eos>
#
# Final Board Position:
# r . r . k . . Q
# . p . . . p . .
# . . p p . B . .
# p . . P p . . .
# . . P . P . B .
# . . . n . . . .
# P P . . . P . .
# . K . . . . . R
# Result: Checkmate
#
# Game 822 Result: White Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 187
#   Draws: 581
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 519
#     Threefold Repetition: 60
#
# Game 823 Start
#
# Final Board Position:
# . . . . R . . .
# . . . . . . . r
# . . p . . . . .
# . . P . p . . .
# . . . . . . . P
# . P . . . P K .
# P . . . k P . .
# . . . . . . . .
#
# Game 823 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 187
#   Draws: 582
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 520
#     Threefold Repetition: 60
#
# Game 824 Start
#
# Final Board Position:
# . . . . . . . .
# p . . . . . . .
# r . . . k . . .
# . . . . . p . p
# . . . . . . . .
# P . . . . K . .
# . P . . . P r P
# . . . . . . . .
#
# Game 824 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 187
#   Draws: 583
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 521
#     Threefold Repetition: 60
#
# Game 825 Start
#
# Final Board Position:
# . R . . . . . k
# p . . . . . . p
# . . p . q . . .
# . . . . . . . .
# . . n P . . . .
# . . P . . . N .
# P P . . . . P P
# . . . . . . K .
#
# Game 825 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 187
#   Draws: 584
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 522
#     Threefold Repetition: 60
#
# Game 826 Start
#
# Final Board Position:
# . . . . . . . R
# . p p . r . P .
# p . n . . . . .
# . . . . . . k .
# . . r . . . . .
# . . P . . K . .
# P . . . . . . .
# . . . . . . . .
#
# Game 826 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 187
#   Draws: 585
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 523
#     Threefold Repetition: 60
#
# Game 827 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . b . .
# . . . b . k p .
# p . . . . . . .
# . . P N K P . P
# . . . . . . P .
# P P . . . . . .
# . . . . . . . .
#
# Game 827 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 187
#   Draws: 586
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 524
#     Threefold Repetition: 60
#
# Game 828 Start
# Result: Draw (Threefold Repetition)
#
# Game 828 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 187
#   Draws: 587
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 524
#     Threefold Repetition: 61
#
# Game 829 Start
#
# Final Board Position:
# . k . . . . . .
# . r . n . . . .
# b P R . . . p .
# . . . B . . Q .
# . . . P . . . .
# . . . . . . P p
# . . . . . . . P
# . . . . . q K .
# Result: Checkmate
#
# Game 829 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 587
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 524
#     Threefold Repetition: 61
#
# Game 830 Start
#
# Final Board Position:
# . . . . . . R .
# . . q . . . . r
# . . . p . . . .
# . P . . p . . k
# . . . . . n R .
# . . . . . . . P
# . . . Q . P P .
# . . . . . . K .
#
# Game 830 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 588
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 525
#     Threefold Repetition: 61
#
# Game 831 Start
#
# Final Board Position:
# . . . . . . r .
# p . . . . k . .
# K p . . . . . .
# . . . . b . . .
# . . . . . . . .
# . . P . . . . .
# P P . . . . P .
# . . . . . . . .
#
# Game 831 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 589
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 526
#     Threefold Repetition: 61
#
# Game 832 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# . . p . . . p .
# . p . k P . P .
# . . . . . B . .
# . P . . . K . .
# . . . . . . . .
# . r . . . . . .
#
# Game 832 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 590
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 527
#     Threefold Repetition: 61
#
# Game 833 Start
#
# Final Board Position:
# . . . R . . . .
# . . Q . . p k .
# . . . . . . p .
# . . p P p . b .
# . . P . P . . .
# q P . . . . P .
# . . B . . P . P
# . . . . . . K .
#
# Game 833 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 591
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 528
#     Threefold Repetition: 61
#
# Game 834 Start
# Result: Draw (Threefold Repetition)
#
# Game 834 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 592
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 528
#     Threefold Repetition: 62
#
# Game 835 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# . . P . . k . .
# p . . P . . p .
# . . . K . . P .
# P r . . . . B P
# . . . . . . P .
# . . . . . . . .
#
# Game 835 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 593
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 529
#     Threefold Repetition: 62
#
# Game 836 Start
#
# Final Board Position:
# . . . . . . k .
# . r . . . p . .
# . . . . p . . p
# . . . . . . . .
# . . . . . . p .
# . . . . . . P .
# . . . q . P . P
# R . . . . . K .
#
# Game 836 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 594
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 530
#     Threefold Repetition: 62
#
# Game 837 Start
#
# Final Board Position:
# . . . . . . r .
# . P . . . . . R
# p . . . . . . .
# k . . . . p . .
# . . . b . K . .
# . . . . . . . .
# . . . . . . P P
# . . . . . . . .
#
# Game 837 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 595
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 531
#     Threefold Repetition: 62
#
# Game 838 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . r k . .
# . . R . . . . .
# . . . . . . P .
# . P . . . . . .
# P . . B . . . .
# . . . . . P K P
# . . . . . . . .
#
# Game 838 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 596
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 532
#     Threefold Repetition: 62
#
# Game 839 Start
#
# Final Board Position:
# . . . . . n k .
# . . . . . . p .
# . . . . p . . p
# . . . . P p . b
# . P . . . P . .
# . . . B . . . .
# P . . . . . P K
# . . r . . . . .
#
# Game 839 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 597
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 533
#     Threefold Repetition: 62
#
# Game 840 Start
#
# Final Board Position:
# . . . . . . . .
# p . . . b . . p
# P . . . . . p k
# . . . . . . . .
# . . p n . . . .
# r . . . . . . .
# . . . N . P K P
# . . . . . . . .
#
# Game 840 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 598
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 534
#     Threefold Repetition: 62
#
# Game 841 Start
# Result: Draw (Threefold Repetition)
#
# Game 841 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 599
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 534
#     Threefold Repetition: 63
#
# Game 842 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . n .
# . . . . b N k p
# r . . . P . p .
# . P P . . . P .
# . . . . . P K .
# . . . . . . . P
# . . . . . . . .
#
# Game 842 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 600
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 535
#     Threefold Repetition: 63
#
# Game 843 Start
# Result: Draw (Threefold Repetition)
#
# Game 843 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 188
#   Draws: 601
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 535
#     Threefold Repetition: 64
#
# Game 844 Start
#
# Final Board Position:
# r . . . . . k .
# . . . . . p . .
# p p . . . . . .
# . . . . p . . .
# . P . . P . . q
# P . . . . . . .
# . . . . . . P .
# . . . r . . K .
# Result: Checkmate
#
# Game 844 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 189
#   Draws: 601
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 535
#     Threefold Repetition: 64
#
# Game 845 Start
# Result: Draw (Threefold Repetition)
#
# Game 845 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 189
#   Draws: 602
#   Unknown: 24
# EOS: 59
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 535
#     Threefold Repetition: 65
#
# Game 846 Start
# Game Over <eos>
# Unknown error
# debug: <bos> d4 Nf6 c4 e6 Nf3 Be7 Nc3 Nc6 e4 Bb4 Bd3 d5 cxd5 Nxd5 Bd2 Nf6 Bg5 h6 Bh4 O-O O-O Bd7 e5 Bxc3 bxc3 g5 Nxg5 hxg5 Bxg5 Ne7 Bxf6 Qb8 Qh5 Ng6 Qh7# Kxh7 Bg5+ Bc6 Bf6+ Kg8 Bxg6 fxg6 <eos>
# An error occurred during the game loop: module 'chess' has no attribute 'IllegalMoveError'
#
# Final Board Position:
# r q . . . r k .
# p p p . . . . .
# . . b . p B p .
# . . . . P . . .
# . . . P . . . .
# . . P . . . . .
# P . . . . P P P
# R . . . . R K .
# UNKnown: <bos> d4 Nf6 c4 e6 Nf3 Be7 Nc3 Nc6 e4 Bb4 Bd3 d5 cxd5 Nxd5 Bd2 Nf6 Bg5 h6 Bh4 O-O O-O Bd7 e5 Bxc3 bxc3 g5 Nxg5 hxg5 Bxg5 Ne7 Bxf6 Qb8 Qh5 Ng6 Qh7# Kxh7 Bg5+ Bc6 Bf6+ Kg8 Bxg6 fxg6 <eos>
#
# Game 846 Result: Unknown Result
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 189
#   Draws: 602
#   Unknown: 25
# EOS: 60
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 535
#     Threefold Repetition: 65
#
# Game 847 Start
#
# Final Board Position:
# . k . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . b . R .
# . . . . . . . .
# . . . . . P . .
# . . P . . . P .
# . K . . . . . .
#
# Game 847 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 30
#   Black Wins: 189
#   Draws: 603
#   Unknown: 25
# EOS: 60
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 536
#     Threefold Repetition: 65
#
# Game 848 Start
# Game Over <eos>
# Unknown error
# debug: <bos> d4 Nf6 c4 d5 Nc3 e6 Bg5 Nbd7 e3 h6 Bh4 Be7 Nf3 b6 cxd5 Nxd5 Bxe7 Nxc3 bxc3 Kxe7 Bb5 c6 Bxc6 Ba6 Bxa8 Nc5 dxc5 Qc7 cxb6 Qxc3+ Nd2 Qb2 Rb1 Qxa2 Ra1 Qb2 Rxa6 axb6 Ra7+ Kf6 Qf3+ Kg5 h4+ Kg6 h5+ Kh7 Be4+ f5 Bxf5+ exf5 Qxf5+ Kg8 Ra8+ <eos>
#
# Final Board Position:
# R . . . . . k r
# . . . . . . p .
# . p . . . . . p
# . . . . . Q . P
# . . . . . . . .
# . . . . P . . .
# . q . N . P P .
# . . . . K . . R
# Result: Checkmate
#
# Game 848 Result: White Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 189
#   Draws: 603
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 536
#     Threefold Repetition: 65
#
# Game 849 Start
#
# Final Board Position:
# . . . r . . . .
# . . . P . p p p
# . . . . . k . .
# . . . . . R . .
# . . . . P p . .
# P . . . . P . .
# . r . . . . P P
# . . . R . . K .
#
# Game 849 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 189
#   Draws: 604
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 537
#     Threefold Repetition: 65
#
# Game 850 Start
#
# Final Board Position:
# . . . . . . . k
# p . . P . . . .
# . p . . B . . R
# . . . b . P . .
# . . p . . . . .
# . . . . . . P .
# P P . . . P . P
# . . . . . . K .
#
# Game 850 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 189
#   Draws: 605
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 538
#     Threefold Repetition: 65
#
# Game 851 Start
#
# Final Board Position:
# . . . . . . k .
# . . . . . p . .
# p . . . . b P .
# . p . . . . . p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . r
# . K . . . . . .
#
# Game 851 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 189
#   Draws: 606
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 539
#     Threefold Repetition: 65
#
# Game 852 Start
#
# Final Board Position:
# r . b . . . . .
# . p . . . . p .
# p . . . . . k .
# . . p . P . . .
# . . . . . . . .
# . . q . R . n .
# P . . . . P P .
# . . . . . . K r
# Result: Checkmate
#
# Game 852 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 190
#   Draws: 606
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 539
#     Threefold Repetition: 65
#
# Game 853 Start
#
# Final Board Position:
# . . . . r . . .
# . . k . . b . .
# . . . p . p . .
# . . p . . P p p
# . . P K . . . .
# r . . . N . P .
# . . . . . . . P
# . . . . . . . .
# Result: Checkmate
#
# Game 853 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 191
#   Draws: 606
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 539
#     Threefold Repetition: 65
#
# Game 854 Start
#
# Final Board Position:
# . . . . . . . r
# . r . . k . . p
# . . . . . . . R
# . . . . . . . .
# . P n . P . . .
# . . . . . . . .
# . . . . . . P P
# . R . . . . K .
#
# Game 854 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 191
#   Draws: 607
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 540
#     Threefold Repetition: 65
#
# Game 855 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# . . k . p . . .
# . . P p . . p p
# . . . . . . . .
# . . . . . . . P
# r . . . . . P .
# . . . K . q . .
# Result: Checkmate
#
# Game 855 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 192
#   Draws: 607
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 540
#     Threefold Repetition: 65
#
# Game 856 Start
#
# Final Board Position:
# . . . . . . . .
# . p . . R . k .
# . . p . . . . .
# . . . p R . . .
# . . . P . . . .
# . P P . . . . P
# . . r . . . P .
# . . . . . . K .
#
# Game 856 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 192
#   Draws: 608
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 541
#     Threefold Repetition: 65
#
# Game 857 Start
#
# Final Board Position:
# r . . . . . . k
# . . p . . . . p
# p . Q . R . . .
# . p . . . . . .
# . P . . . . . .
# N . P . . . . .
# . P . . . . P P
# . . . . . r . K
# Result: Checkmate
#
# Game 857 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 193
#   Draws: 608
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 541
#     Threefold Repetition: 65
#
# Game 858 Start
# Result: Draw (Threefold Repetition)
#
# Game 858 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 193
#   Draws: 609
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 541
#     Threefold Repetition: 66
#
# Game 859 Start
#
# Final Board Position:
# . . . . . . . r
# . . . . . . . k
# . . p . . . p p
# . p . . . . . .
# . . . . b . P K
# . P . . . P . P
# . . P . . q . .
# . . . . . . r .
# Result: Checkmate
#
# Game 859 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 194
#   Draws: 609
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 541
#     Threefold Repetition: 66
#
# Game 860 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . Q . .
# R . . . . . . p
# . N . b . k p .
# . . . . . . . .
# . . . . . . . .
# . K . . . P P P
# . . . . . . . .
#
# Game 860 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 194
#   Draws: 610
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 542
#     Threefold Repetition: 66
#
# Game 861 Start
#
# Final Board Position:
# . . . . . . . .
# p p . . . k p p
# . . . . . . . .
# . . n . . . . .
# . . . . . . . .
# . P . . . . . .
# P . P . . P P P
# R N . . r . K .
# Result: Checkmate
#
# Game 861 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 195
#   Draws: 610
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 542
#     Threefold Repetition: 66
#
# Game 862 Start
# Result: Draw (Threefold Repetition)
#
# Game 862 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 195
#   Draws: 611
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 542
#     Threefold Repetition: 67
#
# Game 863 Start
# Result: Draw (Threefold Repetition)
#
# Game 863 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 195
#   Draws: 612
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 542
#     Threefold Repetition: 68
#
# Game 864 Start
#
# Final Board Position:
# . . . . . . . .
# P . . . k . . .
# . . . . . . p .
# . R . . . . . .
# . . . . . . . .
# . . P . . P . .
# . . . . . . P P
# . . . . . . K .
#
# Game 864 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 195
#   Draws: 613
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 543
#     Threefold Repetition: 68
#
# Game 865 Start
#
# Final Board Position:
# R . . . . . . .
# . p k . . . . p
# p . . . . . p .
# . . P N . . . .
# . . r . . . . .
# . . . . . P . .
# . . . . . P K P
# . . . . . . . .
#
# Game 865 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 195
#   Draws: 614
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 544
#     Threefold Repetition: 68
#
# Game 866 Start
#
# Final Board Position:
# . . . . . . . r
# . . . . . . . p
# . . . . . . . .
# p . . p . . . .
# . k . . . . . .
# . P . . . . . P
# P . N . . . P .
# . . . . . . K .
#
# Game 866 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 195
#   Draws: 615
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 545
#     Threefold Repetition: 68
#
# Game 867 Start
#
# Final Board Position:
# . . r . . . . .
# . . . . . . . .
# . . . . . p . p
# p p . . . P . .
# . . p R . . k .
# P . P . K . . .
# . P . . . . . P
# . . . . . . . .
#
# Game 867 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 195
#   Draws: 616
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 546
#     Threefold Repetition: 68
#
# Game 868 Start
#
# Final Board Position:
# . . . . . . . .
# p . . . . . p .
# . . . k . p . p
# . b . . . . . P
# . p . . P P P .
# . B b . K . . .
# P . . . . . . .
# . . . . . . . .
#
# Game 868 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 195
#   Draws: 617
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 547
#     Threefold Repetition: 68
#
# Game 869 Start
#
# Final Board Position:
# r . . . . . . .
# . . p . . . k p
# p . . . . . . .
# . . . . . . . .
# . P . . . . . .
# P . . . . . . .
# . . . . . P P P
# . . . . q . K .
# Result: Checkmate
#
# Game 869 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 617
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 547
#     Threefold Repetition: 68
#
# Game 870 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# . N . . . . . .
# . N . . k . p p
# . K . . P . . .
# . P . . . P . .
# . . . . . . P P
# . . . . . . . .
#
# Game 870 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 618
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 548
#     Threefold Repetition: 68
#
# Game 871 Start
#
# Final Board Position:
# . . . . . . . k
# . . . . . R . .
# . r . . . . p p
# . . . . . . . .
# . . . . K . . .
# . B . . P . P .
# P . . . . P . P
# . . . . . . . .
#
# Game 871 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 619
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 549
#     Threefold Repetition: 68
#
# Game 872 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# . . . . k . K .
# . . . . . p . .
# . . . . . . . P
# . . . . . . P .
# r . p . . P . .
# . . . . . . . .
#
# Game 872 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 620
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 550
#     Threefold Repetition: 68
#
# Game 873 Start
#
# Final Board Position:
# . . . . . . . .
# . p . . . . . .
# p . . . . . k .
# P . B . . p . .
# . P b . . K . P
# . . . . . P . .
# . r . . . . . .
# . . . . . . . .
#
# Game 873 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 621
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 551
#     Threefold Repetition: 68
#
# Game 874 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . k
# p . n . . K . .
# . . . . . P . P
# . P . . . . P .
# . P . . . . . .
# . P . . . . . .
# . . . . . . . .
#
# Game 874 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 622
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 552
#     Threefold Repetition: 68
#
# Game 875 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . R k b .
# . . N . . p p .
# . . . P . . . p
# . . . . . . . .
# . . r . P . P .
# . . . . . P . P
# . . . . . . K .
#
# Game 875 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 623
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 553
#     Threefold Repetition: 68
#
# Game 876 Start
#
# Final Board Position:
# . . . r . . . .
# . . . . . . k .
# p . . . q p p .
# . . . . . r . p
# . . N P . . . .
# . P . . P . P .
# P . . . R P K P
# . . . . . . . .
#
# Game 876 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 624
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 554
#     Threefold Repetition: 68
#
# Game 877 Start
#
# Final Board Position:
# . . . . . k . .
# . . P . . . . .
# . . . R . . . .
# . . . . . . . p
# p . . . P . . .
# P . . . . . . .
# . . K . . . . P
# . . . . . . . .
#
# Game 877 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 625
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 555
#     Threefold Repetition: 68
#
# Game 878 Start
#
# Final Board Position:
# . . . . n . . .
# . . p k . . . .
# p p . . . . . p
# . . . p P . p .
# . . . . . P P .
# . . P . . K B .
# P P . . . . . P
# . . . . . . . .
#
# Game 878 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 626
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 556
#     Threefold Repetition: 68
#
# Game 879 Start
#
# Final Board Position:
# . . . . . . . r
# . . p . . . . .
# . . n . . . k .
# p . . p . . . .
# . p . P . . P .
# . P P R . . P n
# P . . . . . K P
# . . . . . . . .
#
# Game 879 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 627
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 557
#     Threefold Repetition: 68
#
# Game 880 Start
#
# Final Board Position:
# . . . . . . . .
# P k . . . . . .
# . . . . . . . .
# P . . . . . . .
# . . . . . . . .
# . . . . . . . P
# . . . . . P P .
# . . . . . . K .
#
# Game 880 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 31
#   Black Wins: 196
#   Draws: 628
#   Unknown: 25
# EOS: 61
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 558
#     Threefold Repetition: 68
#
# Game 881 Start
# Game Over <eos>
# Unknown error
# debug: <bos> d4 e6 c4 Nf6 Nf3 c5 d5 b6 Nc3 exd5 cxd5 d6 e4 Bd7 a4 h5 Bg5 Qe7 Bd3 h4 h3 a5 O-O Qd8 e5 dxe5 Nxe5 Be7 d6 Bxd6 Nxd7 Bh2+ Kxh2 Qe7 Nxf6+ gxf6 Bxf6 Qd6+ Kg1 Qxf6 Bb5+ Nc6 Re1+ Kf8 Bxc6 Qxc6 Nd5 Qb7 Qf3 Rh7 Rad1 f5 Qxf5+ Kg8 Re7 Rxe7 Nxe7+ Qxe7 Rd7 Qe1+ Kh2 Qe5+ Qxe5 c4 Qd5+ Kh8 Qxa8+ <eos>
#
# Final Board Position:
# Q . . . . . . k
# . . . R . . . .
# . p . . . . . .
# p . . . . . . .
# P . p . . . . p
# . . . . . . . P
# . P . . . P P K
# . . . . . . . .
# Result: Checkmate
#
# Game 881 Result: White Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 32
#   Black Wins: 196
#   Draws: 628
#   Unknown: 25
# EOS: 62
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 558
#     Threefold Repetition: 68
#
# Game 882 Start
#
# Final Board Position:
# . . k . . . . .
# . p p . . p . .
# p . . . . . r .
# . . . p . n . .
# . . . P . . . K
# . . P . P q . .
# P . . . . . . P
# . . . . . . . .
# Result: Checkmate
#
# Game 882 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 32
#   Black Wins: 197
#   Draws: 628
#   Unknown: 25
# EOS: 62
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 558
#     Threefold Repetition: 68
#
# Game 883 Start
#
# Final Board Position:
# . . . . . . . .
# p . . k . . . .
# . . . . . N p .
# . . . . . . . .
# . p . . . K . p
# . B . . P . . .
# P P . . . . P P
# . . . . . . . .
#
# Game 883 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 32
#   Black Wins: 197
#   Draws: 629
#   Unknown: 25
# EOS: 62
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 559
#     Threefold Repetition: 68
#
# Game 884 Start
# Game Over <eos>
# Unknown error
# debug: <bos> e4 e5 Nf3 Qe7 Nc3 Nc6 Bc4 Qc5 d3 d6 Be3 Qa5 O-O Qb4 Bb3 Nf6 a3 Qa5 h3 Be7 Nd5 h5 Bd2 Nb4 axb4 Qxd5 Bxd5 h4 Ng5 Nxd5 exd5 Bf5 Qf3 f6 Qxf5 fxg5 Bxg5 Kd8 Bxe7+ Kxe7 Qg5+ Ke8 Qxg7 Rf8 Qxc7 Rf6 Qxb7 Rd8 Rxa7 Rd7 Ra8+ Rd8 Rxd8+ Kxd8 Ra1 e4 Ra8+ <eos>
#
# Final Board Position:
# R . . k . . . .
# . Q . . . . . .
# . . . p . r . .
# . . . P . . . .
# . P . . p . . p
# . . . P . . . P
# . P P . . P P .
# . . . . . . K .
# Result: Checkmate
#
# Game 884 Result: White Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 197
#   Draws: 629
#   Unknown: 25
# EOS: 63
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 559
#     Threefold Repetition: 68
#
# Game 885 Start
#
# Final Board Position:
# . . . . . k . r
# p . . . . . . .
# . . . . . . . .
# . p . N . . p p
# . P P . . . . .
# . . . . . . . .
# P . . . . P P P
# . . . . q . K .
# Result: Checkmate
#
# Game 885 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 198
#   Draws: 629
#   Unknown: 25
# EOS: 63
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 559
#     Threefold Repetition: 68
#
# Game 886 Start
#
# Final Board Position:
# r . r . k . . .
# . R . . B . . .
# . . p . p K . .
# p . . . . . . .
# . p . . . . . .
# . . . . . . . .
# P . . . b . . P
# . . . . R . . .
#
# Game 886 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 198
#   Draws: 630
#   Unknown: 25
# EOS: 63
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 560
#     Threefold Repetition: 68
#
# Game 887 Start
# Result: Draw (Threefold Repetition)
#
# Game 887 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 198
#   Draws: 631
#   Unknown: 25
# EOS: 63
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 560
#     Threefold Repetition: 69
#
# Game 888 Start
#
# Final Board Position:
# . . . . . . k .
# . . . . . P . .
# p . . . . . . .
# B p . . K . . p
# . . p . . . . .
# . . . . . . . .
# P P . . . . P P
# . . . . . . . .
#
# Game 888 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 198
#   Draws: 632
#   Unknown: 25
# EOS: 63
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 561
#     Threefold Repetition: 69
#
# Game 889 Start
#
# Final Board Position:
# . r . . . . . .
# . . . . . . . .
# . . . . k . p .
# . P K . . . . p
# . . . . . P . .
# . . B . . . . .
# . P . . . . P P
# . . . . . . . .
#
# Game 889 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 198
#   Draws: 633
#   Unknown: 25
# EOS: 63
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 562
#     Threefold Repetition: 69
#
# Game 890 Start
#
# Final Board Position:
# . . . . . b . .
# . . . . . . . .
# p . p . . . . .
# . . . . . . k .
# . . P . p . N .
# P . . . K . . P
# . P . . . . P .
# . . . . . . . .
#
# Game 890 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 198
#   Draws: 634
#   Unknown: 25
# EOS: 63
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 563
#     Threefold Repetition: 69
#
# Game 891 Start
#
# Final Board Position:
# r . b . . r k .
# p p p . . . p .
# . . . . p p . p
# . q P . . . . .
# . . . P . . . .
# . . . R . P . .
# P . . . K . . P
# . . . . B . . .
#
# Game 891 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 198
#   Draws: 635
#   Unknown: 25
# EOS: 63
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 564
#     Threefold Repetition: 69
#
# Game 892 Start
#
# Final Board Position:
# . . . . . . Q .
# . . . . k . . .
# . . . . . R . .
# . . p . p . . .
# . p K . P . . .
# . P . . . . . r
# . P P . . P . .
# . . . . . . . .
#
# Game 892 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 198
#   Draws: 636
#   Unknown: 25
# EOS: 63
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 565
#     Threefold Repetition: 69
#
# Game 893 Start
#
# Final Board Position:
# . . r . . . . .
# . . . k . . . .
# . . . P b p . p
# p p . . . . p .
# . . . . . . P .
# P . . . . K . P
# . . P R . B . .
# . . . . . . . .
#
# Game 893 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 198
#   Draws: 637
#   Unknown: 25
# EOS: 63
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 566
#     Threefold Repetition: 69
#
# Game 894 Start
# Game Over <eos>
# Unknown error
# debug: <bos> d4 Nf6 c4 e6 Nf3 Be7 Nc3 Nc6 e4 d5 e5 Ng4 h3 Nh6 Bxh6 gxh6 Qd2 Bg5 Nxg5 hxg5 cxd5 Ne7 d6 Nc6 Bb5 O-O Bxc6 bxc6 Ne4 Bb7 Nf6+ Kh8 Qxg5 cxd6 Qh6 Qa5+ Kf1 Qa6+ Kg1 Qd3 Qxh7# Qxh7 Nd7# Rg8 <eos>
# An error occurred during the game loop: module 'chess' has no attribute 'IllegalMoveError'
#
# Final Board Position:
# r . . . . . r k
# p b . N . p . q
# . . p p p . . .
# . . . . P . . .
# . . . P . . . .
# . . . . . . . P
# P P . . . P P .
# R . . . . . K R
# UNKnown: <bos> d4 Nf6 c4 e6 Nf3 Be7 Nc3 Nc6 e4 d5 e5 Ng4 h3 Nh6 Bxh6 gxh6 Qd2 Bg5 Nxg5 hxg5 cxd5 Ne7 d6 Nc6 Bb5 O-O Bxc6 bxc6 Ne4 Bb7 Nf6+ Kh8 Qxg5 cxd6 Qh6 Qa5+ Kf1 Qa6+ Kg1 Qd3 Qxh7# Qxh7 Nd7# Rg8 <eos>
#
# Game 894 Result: Unknown Result
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 198
#   Draws: 637
#   Unknown: 26
# EOS: 64
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 566
#     Threefold Repetition: 69
#
# Game 895 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . R
# . . . . . k . p
# . . . p . . . .
# . . . . . . . .
# . . . . . . . P
# . r . . . . . P
# . . r . . K . .
# Result: Checkmate
#
# Game 895 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 199
#   Draws: 637
#   Unknown: 26
# EOS: 64
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 566
#     Threefold Repetition: 69
#
# Game 896 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . k . .
# . . . . . . . .
# . . . . P . . .
# R . . . K . . .
# P . . . . . . r
# . P P . . . . .
# . . . . . . . .
#
# Game 896 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 33
#   Black Wins: 199
#   Draws: 638
#   Unknown: 26
# EOS: 64
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 567
#     Threefold Repetition: 69
#
# Game 897 Start
# Game Over <eos>
# Unknown error
# debug: <bos> e4 e5 Nf3 Qe7 Nc3 Nc6 Bc4 Nf6 O-O d6 h3 h5 d4 g6 Bg5 exd4 Nd5 Nxd5 Bxe7 Ndxe7 Nxd4 f5 exf5 d5 Nxc6 bxc6 Qd4 Bxf5 Qxh8 dxc4 Rfe1 Bxc2 Rac1 Bd3 Re3 O-O-O Rce1 Nf5 Re8 Rxe8 Rxe8+ Kb7 Rxf8 a6 Rb8+ Ka7 Qd8 a5 Qxc7+ Ka6 Qb6# <eos>
#
# Final Board Position:
# . R . . . . . .
# . . . . . . . .
# k Q p . . . p .
# p . . . . n . p
# . . p . . . . .
# . . . b . . . P
# P P . . . P P .
# . . . . . . K .
# Result: Checkmate
#
# Game 897 Result: White Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 199
#   Draws: 638
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 567
#     Threefold Repetition: 69
#
# Game 898 Start
#
# Final Board Position:
# . . . . . . r .
# . p . . k b . .
# p . . . . . . .
# . . . . P K . .
# . P . R . . P .
# P . . . . N . P
# . . . . . . . .
# . . q . . . . .
#
# Game 898 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 199
#   Draws: 639
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 568
#     Threefold Repetition: 69
#
# Game 899 Start
#
# Final Board Position:
# . . . . . . . .
# . . p k . . . p
# . . . . . p . .
# p . . . . . . .
# P . . . P . . .
# K r P . . . . .
# . r . . . . . P
# . . . . . . . .
# Result: Checkmate
#
# Game 899 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 200
#   Draws: 639
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 568
#     Threefold Repetition: 69
#
# Game 900 Start
#
# Final Board Position:
# . . . r . . . .
# . . . P k . . .
# . . b . P . . p
# . . . . . . . .
# . . . . . p p .
# . . . . . . . .
# . R . . . P P P
# . . . R . . K .
#
# Game 900 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 200
#   Draws: 640
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 569
#     Threefold Repetition: 69
#
# Game 901 Start
#
# Final Board Position:
# . . . . R . . .
# . R . . . . . .
# . . . . . . k .
# . . . . . . p .
# . . . . . . . .
# . . . . . . . .
# . P . . . . P P
# . . . . . . . K
#
# Game 901 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 200
#   Draws: 641
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 570
#     Threefold Repetition: 69
#
# Game 902 Start
# Result: Draw (Threefold Repetition)
#
# Game 902 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 200
#   Draws: 642
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 570
#     Threefold Repetition: 70
#
# Game 903 Start
#
# Final Board Position:
# . . . . . . . r
# . p . . k . . p
# p . . . . p . K
# P . . r N . q .
# . . p . . . . .
# . . . . . . . P
# . P . . . P P .
# . . . . . . . .
# Result: Checkmate
#
# Game 903 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 201
#   Draws: 642
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 570
#     Threefold Repetition: 70
#
# Game 904 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# . . . . . . p p
# . . k . . p . .
# r . . . . . . P
# . . . . P K P .
# . . . . . . . .
# . . . . . . . .
#
# Game 904 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 201
#   Draws: 643
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 571
#     Threefold Repetition: 70
#
# Game 905 Start
#
# Final Board Position:
# . r . . . . k .
# . . . . . P p .
# . . . q . . . .
# . . . . . . . .
# . . p . P . . p
# P . B . . . . P
# . P . N K . P .
# . . . . . . . .
#
# Game 905 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 201
#   Draws: 644
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 572
#     Threefold Repetition: 70
#
# Game 906 Start
#
# Final Board Position:
# . . . . . . . .
# . . k . . p . .
# . . . . . . . .
# P P P . . . p .
# . . P . . . . p
# . . . . . . . P
# . . . . . P P .
# . . . . . . K .
#
# Game 906 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 201
#   Draws: 645
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 573
#     Threefold Repetition: 70
#
# Game 907 Start
#
# Final Board Position:
# . . b . . . . .
# . . P . . . . .
# p . . . p . . .
# . . . . K . . .
# B . . . . . k .
# P . . . . p . .
# . . P . . P . P
# . . . . . . . .
#
# Game 907 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 201
#   Draws: 646
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 574
#     Threefold Repetition: 70
#
# Game 908 Start
#
# Final Board Position:
# r . . . . . . .
# p p p k . . . .
# . . . . . . . .
# b . . . . b . .
# . . n P . . . .
# . . P . . . . .
# P P . K . . . .
# R . . . . q . .
# Result: Checkmate
#
# Game 908 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 202
#   Draws: 646
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 574
#     Threefold Repetition: 70
#
# Game 909 Start
#
# Final Board Position:
# . . . . r . . .
# . r . . . . . p
# p . . . q . p .
# P . . R Q p . k
# . . p . . B . .
# . . . . P . P P
# . . . . . . . .
# . . . R . . K .
#
# Game 909 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 34
#   Black Wins: 202
#   Draws: 647
#   Unknown: 26
# EOS: 65
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 575
#     Threefold Repetition: 70
#
# Game 910 Start
# Game Over <eos>
# Unknown error
# debug: <bos> d4 d5 c4 Nf6 Nc3 c6 Nf3 dxc4 a4 e6 e3 Nbd7 Bxc4 Nb6 Bd3 Nbd5 O-O a5 e4 Nb6 Bg5 Bb4 e5 Bxc3 bxc3 h6 Bh4 g5 Nxg5 hxg5 Bxg5 Nbd5 c4 Rg8 h4 Nc3 Qf3 Qxd4 Bxf6 Rb8 Bh7 Rg4 Rad1 Nxd1 Rxd1 Rxh4 Rxd4 Rxd4 Qh5 Rxc4 Bg8 Rc1+ Kh2 Rh1+ Kxh1 c5 Qxf7+ <eos>
#
# Final Board Position:
# . r b . k . B .
# . p . . . Q . .
# . . . . p B . .
# p . p . P . . .
# P . . . . . . .
# . . . . . . . .
# . . . . . P P .
# . . . . . . . K
# Result: Checkmate
#
# Game 910 Result: White Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 202
#   Draws: 647
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 575
#     Threefold Repetition: 70
#
# Game 911 Start
#
# Final Board Position:
# . . . . . . r .
# p . . . . p . .
# . . . . k p . .
# . . . . . . . .
# P . . . . . . .
# . . . . . . P q
# . . . . . P . P
# . r . . . . K .
# Result: Checkmate
#
# Game 911 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 203
#   Draws: 647
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 575
#     Threefold Repetition: 70
#
# Game 912 Start
#
# Final Board Position:
# . . . . . . . .
# . p . . . . . .
# p . p . . p p .
# . . . k . P . p
# r . . b . . P P
# . . . . . . . .
# . P . . . . . .
# . K . R . . . .
#
# Game 912 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 203
#   Draws: 648
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 576
#     Threefold Repetition: 70
#
# Game 913 Start
# Result: Draw (Threefold Repetition)
#
# Game 913 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 203
#   Draws: 649
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 576
#     Threefold Repetition: 71
#
# Game 914 Start
#
# Final Board Position:
# . . . . . . k .
# p p p . . . . p
# . . . . . r . .
# . . . . . . N .
# . . . . . . n .
# . . P . . . . P
# P . P . . P P .
# . . . q . . K .
# Result: Checkmate
#
# Game 914 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 204
#   Draws: 649
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 576
#     Threefold Repetition: 71
#
# Game 915 Start
#
# Final Board Position:
# . . . . . . . .
# . . p n . . P .
# p . . k . . q .
# . . . . . . . .
# . p P P . . . K
# . . . . . . . .
# P . . . . . . .
# . . . . . . . r
# Result: Checkmate
#
# Game 915 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 205
#   Draws: 649
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 576
#     Threefold Repetition: 71
#
# Game 916 Start
#
# Final Board Position:
# . . . . . . . .
# . . . k . . . .
# . . p . . . p .
# . . P . . . . p
# . R . . . . . .
# . . . . . . . .
# P P P . . P P .
# . K . . r . . .
# Result: Checkmate
#
# Game 916 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 206
#   Draws: 649
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 576
#     Threefold Repetition: 71
#
# Game 917 Start
# Result: Draw (Threefold Repetition)
#
# Game 917 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 206
#   Draws: 650
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 576
#     Threefold Repetition: 72
#
# Game 918 Start
#
# Final Board Position:
# . . . . . k . .
# . . . P . p . .
# . . . . n . . p
# . . P . . B p .
# . P . . . . . .
# . . . . K . . .
# r . . . . . . P
# . . . . . . . .
#
# Game 918 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 206
#   Draws: 651
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 2
#     Insufficient Material: 0
#     80-move Rule: 577
#     Threefold Repetition: 72
#
# Game 919 Start
#
# Final Board Position:
# . . . . . . . .
# p . k . . . . .
# . . b . r . . p
# . p P . . . p .
# . . r . . . . .
# . . . R . P . .
# . K . R . . P P
# . . . . . . . .
#
# Game 919 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 206
#   Draws: 652
# ...
# Result: Draw (Threefold Repetition)
#
# Game 965 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 218
#   Draws: 686
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 606
#     Threefold Repetition: 77
#
# Game 966 Start
#
# Final Board Position:
# r . . . . . . k
# p . p . . . p b
# . p . . Q . . .
# . . . . . . . N
# . . P . . . . .
# . . B . P . . .
# P P . . . . P P
# . . . . . q . K
# Result: Checkmate
#
# Game 966 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 219
#   Draws: 686
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 606
#     Threefold Repetition: 77
#
# Game 967 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# p . . . . . . K
# . . p . n . . P
# . . . . k . . .
# . . P . . . . .
# P P . . . r . .
# . . B . . . . .
#
# Game 967 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 219
#   Draws: 687
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 607
#     Threefold Repetition: 77
#
# Game 968 Start
#
# Final Board Position:
# . . . . R . . .
# . . . . . . p k
# p . . P . . . p
# . . p . . . p .
# . . P q . . . .
# . . . K . P . P
# . r . . . . P .
# . . . . . . . .
# Result: Checkmate
#
# Game 968 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 220
#   Draws: 687
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 607
#     Threefold Repetition: 77
#
# Game 969 Start
#
# Final Board Position:
# . . . . . . . .
# R . . . . p . .
# P . . . . . k .
# . . r . . . p .
# . K . . . . . p
# . . . . . P . P
# . . . . . . P .
# . . . . . . . .
#
# Game 969 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 220
#   Draws: 688
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 608
#     Threefold Repetition: 77
#
# Game 970 Start
#
# Final Board Position:
# . . . . . . k .
# . . . . . . . .
# . . p . . . N .
# . . . b . . N p
# . . . P . . . .
# B . . . . . . .
# . P . . . P P P
# r . . . . . K .
# Result: Checkmate
#
# Game 970 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 221
#   Draws: 688
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 608
#     Threefold Repetition: 77
#
# Game 971 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# p . . . . k . .
# . p . . R . . p
# . . . K . . . P
# P b P . . . . .
# . . . . . P . .
# . . . . . . . .
#
# Game 971 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 221
#   Draws: 689
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 609
#     Threefold Repetition: 77
#
# Game 972 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . p .
# . . . . . . . k
# . . . P p Q N p
# P . . . . . . .
# . . . . . . . .
# . . . . . P P P
# . . . . q . K .
# Result: Checkmate
#
# Game 972 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 222
#   Draws: 689
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 609
#     Threefold Repetition: 77
#
# Game 973 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . k . p
# . . . . . p . .
# N . . P . n . .
# P . P . . . p .
# . P . . . . . .
# . . . . . K P P
# . . . . r . . .
#
# Game 973 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 222
#   Draws: 690
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 610
#     Threefold Repetition: 77
#
# Game 974 Start
#
# Final Board Position:
# . . k . . b . N
# p . p . . . p p
# . . Q . p n . .
# . . . . . . . .
# . . . . . . b .
# . . . . . . . .
# P P . . . P P P
# R . B N q . K .
# Result: Checkmate
#
# Game 974 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 223
#   Draws: 690
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 610
#     Threefold Repetition: 77
#
# Game 975 Start
#
# Final Board Position:
# . . . . k . . r
# p . . . P p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P . . . P P P
# R . B r . . K .
# Result: Checkmate
#
# Game 975 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 224
#   Draws: 690
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 610
#     Threefold Repetition: 77
#
# Game 976 Start
#
# Final Board Position:
# . . . . r . k .
# . . . . . p . .
# . . b . . . . .
# . . . . P . . .
# . . P . . B p .
# . P . . . . P .
# P . . K . P . P
# . . . . . . . .
#
# Game 976 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 224
#   Draws: 691
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 611
#     Threefold Repetition: 77
#
# Game 977 Start
#
# Final Board Position:
# . . . . . . . .
# p . . k . . . .
# . . . b . p . .
# . . p N . . . .
# . . . . . . P .
# . P . . . P . .
# P . . . . B . .
# r . . . . b K .
#
# Game 977 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 224
#   Draws: 692
#   Unknown: 26
# EOS: 66
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 612
#     Threefold Repetition: 77
#
# Game 978 Start
# Game Over <eos>
# Unknown error
# debug: <bos> e4 Nc6 Nf3 d5 exd5 Nb4 Bb5+ Bd7 Bc4 e6 dxe6 Qe7 O-O Bxe6 Bxe6 Qxe6 Re1 Qe7 Rxe7+ Nxe7 Nc3 O-O-O a3 Nbd5 Nxd5 Rxd5 d4 Kb8 c4 Rd6 Bf4 Ra6 Bxc7+ Kxc7 Ne5 Nf5 Nxf7 Rg8 d5 Bc5 b4 Be7 c5 Bf6 d6+ Kc8 Rc1 g6 Qd5 Bd8 c6 bxc6 Rxc6+ Rxc6 Qxc6+ Kb8 Qb7# Kxb7 Nxd8+ Rxd8 d7 Nd4 <eos>
# An error occurred during the game loop: module 'chess' has no attribute 'IllegalMoveError'
#
# Final Board Position:
# . . . r . . . .
# p k . P . . . p
# . . . . . . p .
# . . . . . . . .
# . P . n . . . .
# P . . . . . . .
# . . . . . P P P
# . . . . . . K .
# UNKnown: <bos> e4 Nc6 Nf3 d5 exd5 Nb4 Bb5+ Bd7 Bc4 e6 dxe6 Qe7 O-O Bxe6 Bxe6 Qxe6 Re1 Qe7 Rxe7+ Nxe7 Nc3 O-O-O a3 Nbd5 Nxd5 Rxd5 d4 Kb8 c4 Rd6 Bf4 Ra6 Bxc7+ Kxc7 Ne5 Nf5 Nxf7 Rg8 d5 Bc5 b4 Be7 c5 Bf6 d6+ Kc8 Rc1 g6 Qd5 Bd8 c6 bxc6 Rxc6+ Rxc6 Qxc6+ Kb8 Qb7# Kxb7 Nxd8+ Rxd8 d7 Nd4 <eos>
#
# Game 978 Result: Unknown Result
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 224
#   Draws: 692
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 612
#     Threefold Repetition: 77
#
# Game 979 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# . p . . . . . .
# p . p . k . . P
# P . P . b p K .
# . P . . . . . .
# . . . . . . P .
# . . . . . . . .
#
# Game 979 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 224
#   Draws: 693
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 613
#     Threefold Repetition: 77
#
# Game 980 Start
#
# Final Board Position:
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . P k .
# . . . . P . . .
# P . . . . . K P
# . P . . . . . .
# . . . . . . . .
#
# Game 980 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 224
#   Draws: 694
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 614
#     Threefold Repetition: 77
#
# Game 981 Start
#
# Final Board Position:
# b . . . . . . .
# . . p . P k . n
# . p . . . . . .
# p . . . . . . .
# . . . . . . . .
# . . . N . . P .
# P P P . . P . .
# . . K . . . . .
#
# Game 981 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 224
#   Draws: 695
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 615
#     Threefold Repetition: 77
#
# Game 982 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . q . k .
# p . . . B . . p
# . p . . . . p .
# . . . Q . . . .
# . . . . . . . P
# P . . . . P P .
# . . . . . . K .
#
# Game 982 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 224
#   Draws: 696
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 616
#     Threefold Repetition: 77
#
# Game 983 Start
#
# Final Board Position:
# . . . . . . . .
# . p . . b . . P
# p . p . . . . .
# . . . . . . . .
# . . . . k . . .
# . K P . . . . .
# P P . . . . . r
# . . . . . . . .
#
# Game 983 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 224
#   Draws: 697
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 617
#     Threefold Repetition: 77
#
# Game 984 Start
#
# Final Board Position:
# . . . . . . . .
# . . N . . . . .
# . . k B . . . .
# p . . . . . p p
# P . . . . . . .
# . P . . . P . .
# . . . . K . P P
# . . . . . . . .
#
# Game 984 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 224
#   Draws: 698
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 618
#     Threefold Repetition: 77
#
# Game 985 Start
#
# Final Board Position:
# r . . . . r . k
# p p R . . . . .
# . . . . . . . .
# . . . P . . . n
# . . . . . . b .
# . . . . P . P .
# P . . . . q . P
# . . R . . K . .
# Result: Checkmate
#
# Game 985 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 225
#   Draws: 698
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 618
#     Threefold Repetition: 77
#
# Game 986 Start
# Result: Draw (Threefold Repetition)
#
# Game 986 Result: Draw (Threefold Repetition)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 225
#   Draws: 699
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 618
#     Threefold Repetition: 78
#
# Game 987 Start
#
# Final Board Position:
# . . r . . . . .
# p . . . . . . .
# . . . . k . . p
# . . . . . p P .
# . . . . . . . .
# . P . . P . P .
# . b . . K . . P
# . . . . . . . .
#
# Game 987 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 225
#   Draws: 700
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 619
#     Threefold Repetition: 78
#
# Game 988 Start
#
# Final Board Position:
# . . . . . b . .
# . . . . p p . p
# . p . . . . . P
# . P . k n . P .
# . . . . . K P .
# . . . . . . . .
# . . . . . . . .
# . . . . . b . .
#
# Game 988 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 225
#   Draws: 701
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 620
#     Threefold Repetition: 78
#
# Game 989 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# p . k . . . . p
# . p . . . . . .
# . . p . K . . p
# P . . . . . . .
# . P . . . r . .
# . . . . . . . .
#
# Game 989 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 225
#   Draws: 702
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 621
#     Threefold Repetition: 78
#
# Game 990 Start
#
# Final Board Position:
# . . r k . . . r
# . p p . n p . .
# p . . P . N p .
# . . . . . . . .
# . . . . . . P .
# . . . . . Q . .
# P P P . . P P q
# R . . . . R K .
# Result: Checkmate
#
# Game 990 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 226
#   Draws: 702
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 621
#     Threefold Repetition: 78
#
# Game 991 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p p . . . k . .
# . . . P . P . .
# . . P K r P . .
# P . . . r . . P
# . . . . . . . .
# Result: Checkmate
#
# Game 991 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 227
#   Draws: 702
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 621
#     Threefold Repetition: 78
#
# Game 992 Start
#
# Final Board Position:
# . . . . . . . .
# p . . . . . . p
# . . . . . . p b
# . . . . k . . .
# . . . . . . . .
# . . . K . . . .
# . P . . . P P P
# . . . . . . . .
#
# Game 992 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 227
#   Draws: 703
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 622
#     Threefold Repetition: 78
#
# Game 993 Start
#
# Final Board Position:
# . . . Q . . k .
# p . B . . p p .
# . p . . r . . .
# . . . . . . . .
# . . P . . . . .
# . . . . . . . .
# P . . . . P P P
# . . . . . . K .
#
# Game 993 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 227
#   Draws: 704
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 623
#     Threefold Repetition: 78
#
# Game 994 Start
#
# Final Board Position:
# . k . . . . . .
# . . R . . . . .
# . . . B . . . .
# . . . . . K . .
# . . . . . . . P
# . . . . . . . .
# b P . . . . . .
# . . . . . . . .
#
# Game 994 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 227
#   Draws: 705
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 624
#     Threefold Repetition: 78
#
# Game 995 Start
#
# Final Board Position:
# . . . . . . k .
# . . . . . . . .
# . . N . . . p .
# . p . p . . . p
# p . . . . . . .
# . . . . . . . .
# P n . . . P P P
# . . . q K . . .
# Result: Checkmate
#
# Game 995 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 228
#   Draws: 705
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 624
#     Threefold Repetition: 78
#
# Game 996 Start
#
# Final Board Position:
# . . . . k . . .
# p . . . . . . .
# b . p . . . . .
# . . . . . . . .
# p . P . . . . .
# . . . . B P . .
# P P . . . K . .
# . . . . R . . .
#
# Game 996 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 228
#   Draws: 706
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 625
#     Threefold Repetition: 78
#
# Game 997 Start
#
# Final Board Position:
# r . . k . . B .
# . . p p . . . .
# . . . b . . . .
# p p . . . . . .
# . . . . . . . .
# . . P . . . . P
# P P . . . . P q
# R N . . . . . K
# Result: Checkmate
#
# Game 997 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 229
#   Draws: 706
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 625
#     Threefold Repetition: 78
#
# Game 998 Start
#
# Final Board Position:
# . . . . . . . r
# . . p . . . . .
# p . . . . k . .
# . p . p . . . P
# . P . n . P P K
# P . . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Game 998 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 229
#   Draws: 707
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 626
#     Threefold Repetition: 78
#
# Game 999 Start
#
# Final Board Position:
# . . . . . . r .
# . . . . b n . .
# . p k . p . . p
# p N p . P . p .
# P . P . K . P .
# . P . . . R B P
# . . . . . . . .
# . . . . . . . .
#
# Game 999 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 229
#   Draws: 708
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 627
#     Threefold Repetition: 78
#
# Game 1000 Start
#
# Final Board Position:
# r . . . . . k .
# . . N n . . . p
# . . . . . . r .
# p . p . . p . .
# P . N . . . . .
# . . . . P . P .
# . P . K . P . .
# . . . . . . . .
#
# Game 1000 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 35
#   Black Wins: 229
#   Draws: 709
#   Unknown: 27
# EOS: 67
#
# Detailed Draw Breakdown:
#     Stalemate: 3
#     Insufficient Material: 0
#     80-move Rule: 628
#     Threefold Repetition: 78
#
# Final Game Statistics:
# Total Games: 973
# White Wins: 35
# Black Wins: 229
# Draws: 709
#   Unknown: 27
#
# Detailed Draw Breakdown:
#   Stalemate: 3
#   Insufficient Material: 0
#   80-move Rule: 628
#   Threefold Repetition: 78
#
# Win Percentage: 3.60%
# Draw Percentage: 72.87%
# Loss Percentage: 23.54%

# %% [markdown]
# #Game analysis

# %%
import chess
import chess.engine
import argparse
import torch

n_positions = 80
dim_model = 768
d_hid = 3072
num_heads = 12
num_layers = 12
dropout_p = 0.1

import argparse
import chess
import chess.engine

# Define thresholds based on the difference from the best move
BEST_MOVE_THRESHOLD = 0       # Executed move is the best move or better
GOOD_MOVE_THRESHOLD = -10     # Executed move is within 10 centipawns of the best move
MISTAKE_THRESHOLD = -50       # Executed move is within 50 centipawns of the best move
BLUNDER_THRESHOLD = -100     # Executed move is worse than 100 centipawns from the best move

def _parse_args():
    parser = argparse.ArgumentParser(
        description='Chessformers inference parser')

    parser.add_argument('--load_model', type=str, default="/content/chessformer_epoch_13.pth",
                        help='model to load and do inference')
    parser.add_argument('--tokenizer', type=str, default="/content/vocabs/kaggle2_vocab.txt",
                        help='location of the tokenizer file')
    parser.add_argument('--engine_path', type=str, default="/content/stockfish-5-linux/Linux/stockfish_14053109_x64",
                        help='Path to the chess engine executable')
    parser.add_argument('--games', type=int, default=100,
                        help='Number of games to simulate')

    args, _ = parser.parse_known_args()
    return args


def analyze_game(board, engine, results, game_number):
    """
    Analyzes the game by replaying the moves from the start on a fresh board.
    Provides evaluation of the position and identifies critical mistakes or blunders.
    """
    print("\nStarting game analysis...")

    # Create a fresh board for analysis
    analysis_board = chess.Board()

    # Initialize move statistics
    white_best_moves = 0
    white_good_moves = 0
    white_mistakes = 0
    white_blunders = 0
    black_best_moves = 0
    black_good_moves = 0
    black_mistakes = 0
    black_blunders = 0

    # Replay the game move by move with engine evaluation
    for move_number, move in enumerate(board.move_stack, start=1):
        analysis_board.push(move)

        try:
            # Use the engine to analyze the current board position
            evaluation = engine.analyse(analysis_board, chess.engine.Limit(depth=1))

            # Check if the score is a mate evaluation
            if evaluation["score"].is_mate():
                # Handle mate in a special way, potentially set to a large + or - value
                score = float('inf') if evaluation["score"].white().score() > 0 else float('-inf')
            else:
                # Use regular centipawn score
                score = evaluation["score"].white().score()  # Ensure you get the correct type here

        except Exception as e:
            # Skip this move if evaluation fails
            print(f"Move {move_number}: {move} - Error during evaluation: {e}")
            score = 0


        # Determine whose turn it was for this move
        is_white_turn = move_number % 2 == 1  # Odd move numbers are White's moves

        # Define thresholds based on relative difference
        if is_white_turn:  # White's turn
            if score <= BLUNDER_THRESHOLD:  # Check Blunder first
                white_blunders += 1
                move_quality = "Blunder"
            elif score <= MISTAKE_THRESHOLD:  # Then Mistake
                white_mistakes += 1
                move_quality = "Mistake"
            elif score >= BEST_MOVE_THRESHOLD:  # Then Best Move
                white_best_moves += 1
                move_quality = "Best Move"
            elif score >= GOOD_MOVE_THRESHOLD:  # Then Good Move
                white_good_moves += 1
                move_quality = "Good Move"
            else:
                move_quality = "Uncategorized"
        else:  # Black's turn
            if score >= BLUNDER_THRESHOLD:  # Assuming BLUNDER_THRESHOLD is negative for Black
                black_blunders += 1
                move_quality = "Blunder"
            elif score >= MISTAKE_THRESHOLD:
                black_mistakes += 1
                move_quality = "Mistake"
            elif score <= BEST_MOVE_THRESHOLD:
                black_best_moves += 1
                move_quality = "Best Move"
            elif score <= GOOD_MOVE_THRESHOLD:
                black_good_moves += 1
                move_quality = "Good Move"
            else:
                move_quality = "Uncategorized"

        # Debugging output for move details
        print(f"Move {move_number}: {move}, Turn: {'White' if is_white_turn else 'Black'}, "
              f"Score: {score}, Quality: {move_quality}")

    # Store the analysis results for the game
    results["White Best Moves"] += white_best_moves
    results["White Good Moves"] += white_good_moves
    results["White Mistakes"] += white_mistakes
    results["White Blunders"] += white_blunders
    results["Black Best Moves"] += black_best_moves
    results["Black Good Moves"] += black_good_moves
    results["Black Mistakes"] += black_mistakes
    results["Black Blunders"] += black_blunders

    # Print individual game analysis
    print(f"Game {game_number} Analysis:")
    print(f"  White Best Moves: {white_best_moves}, White Good Moves: {white_good_moves}, "
          f"White Mistakes: {white_mistakes}, White Blunders: {white_blunders}")
    print(f"  Black Best Moves: {black_best_moves}, Black Good Moves: {black_good_moves}, "
          f"Black Mistakes: {black_mistakes}, Black Blunders:  {black_blunders}")

    print("Game analysis complete.\n")

def play_game(model, tokenizer, engine, results, game_number):
    board = chess.Board()
    input_string = "<bos>"
    print(f"\nGame {game_number} Start")
    engine.configure({"Skill Level": 1})

    while not board.is_game_over() and len(input_string.split(" ")) < n_positions:
        try:
            if board.turn:  # White's turn (Model)
                lastmove = input_string.split(" ")[-1]
                input_string = model.predict(
                    input_string,
                    stop_at_next_move=True,
                    temperature=0.2,
                )

                move = input_string.split(" ")[-1]
                if(move=="<eos>"):
                    if(lastmove==move):
                        if not board.is_game_over():
                            print("Unknown error")
                            print(f"debug: {input_string}")
                            results["Unknown"]["Unknown"] += 1
                            return "Unknown Result"
                        else:
                            print("Result: Checkmate")
                            if board.turn == chess.BLACK:
                                results["White Wins"]["Checkmate"] += 1
                                return "White Wins (Checkmate)"
                            else:
                                results["Black Wins"]["Checkmate"] += 1
                                return "Black Wins (Checkmate)"
                    else:
                        print("Game Over <eos>")
                        results['EOS']['EOS'] += 1
                        move = input_string.split(" ")[-2]
                        if not board.is_game_over():
                            print("Unknown error")
                            print(f"debug: {input_string}")
                        else:
                            print(f"EOS: {input_string}")
                            print("Result: Checkmate")
                            if board.turn == chess.BLACK:
                                results["White Wins"]["Checkmate"] += 1
                                return "White Wins (Checkmate)"
                            else:
                                results["Black Wins"]["Checkmate"] += 1
                                return "Black Wins (Checkmate)"
                try:
                    san_move_obj = board.parse_san(move)
                    if san_move_obj in board.legal_moves:
                        board.push(san_move_obj)
                    else:
                        raise ValueError(f"Illegal move: {move}")
                except (chess.IllegalMoveError, ValueError) as e:
                    print(f"Model predicted an invalid move: {e}")
                    break
            else:  # Black's turn (Engine)
                result = engine.play(board, chess.engine.Limit(time=0.005))
                san_move = board.san(result.move)
                input_string = input_string + " " + san_move
                board.push(result.move)

        except Exception as e:
            print(f"An error occurred during the game loop: {e}")
            break
        if board.is_repetition():
            print("Result: Draw (Threefold Repetition)")
            results["Draw"]["Threefold Repetition"] += 1
            return "Draw (Threefold Repetition)"

    print("\nFinal Board Position:")
    print(board)



    analyze_game(board, engine, results, game_number)

    if(len(input_string.split(" ")) >= n_positions):
        results["Draw"]["80-move Rule"] += 1
        return "Draw (80+ moves)"

    if board.is_checkmate():
        print("Result: Checkmate")
        if board.turn == chess.BLACK:
            results["White Wins"]["Checkmate"] += 1
            return "White Wins (Checkmate)"
        else:
            results["Black Wins"]["Checkmate"] += 1
            return "Black Wins (Checkmate)"
    elif board.is_stalemate():
        print("Result: Stalemate")
        results["Draw"]["Stalemate"] += 1
        return "Draw (Stalemate)"
    elif board.is_insufficient_material():
        print("Result: Draw (Insufficient Material)")
        results["Draw"]["Insufficient Material"] += 1
        return "Draw (Insufficient Material)"
    elif board.is_seventyfive_moves():
        print("Result: Draw (80-move Rule)")
        results["Draw"]["80-move Rule"] += 1
        return "Draw (80-move Rule)"

    results["Unknown"]["Unknown"] += 1
    print(f"Unknown: {input_string}")
    return "Unknown Result"

def main(args):
    tokenizer = Tokenizer(args.tokenizer)
    model = Transformer(
        tokenizer,
        num_tokens=tokenizer.vocab_size(),
        dim_model=dim_model,
        d_hid=d_hid,
        num_heads=num_heads,
        num_layers=num_layers,
        dropout_p=dropout_p,
        n_positions=n_positions,
    )
    model.load_state_dict(torch.load(args.load_model, map_location=torch.device('cpu')))

    results = {
        "White Wins": {"Checkmate": 0},
        "Black Wins": {"Checkmate": 0},
        "Draw": {"Stalemate": 0, "Insufficient Material": 0, "80-move Rule": 0, "Threefold Repetition": 0},
        "Unknown": {"Unknown": 0},
        "EOS": {"EOS": 0},
        "White Best Moves": 0,
        "White Good Moves": 0,
        "White Mistakes": 0,
        "White Blunders": 0,
        "Black Best Moves": 0,
        "Black Good Moves": 0,
        "Black Mistakes": 0,
        "Black Blunders": 0,
    }

    with chess.engine.SimpleEngine.popen_uci(args.engine_path) as engine:
        for game_number in range(1, args.games + 1):
            result = play_game(model, tokenizer, engine, results, game_number)

            print(f"\nGame {game_number} Result: {result}")
            print("\nCumulative Results:")
            print(f"  White Wins: {results['White Wins']['Checkmate']}")
            print(f"  Black Wins: {results['Black Wins']['Checkmate']}")
            print(f"  Draws: {sum(results['Draw'].values())}")
            print(f"  Unknown: {results['Unknown']['Unknown']}")
            print(f"EOS: {results['EOS']['EOS']}")
            print("\nDetailed Draw Breakdown:")
            for reason, count in results["Draw"].items():
                print(f"    {reason}: {count}")

    total_games = sum(
        [results["White Wins"]["Checkmate"], results["Black Wins"]["Checkmate"]] +
        list(results["Draw"].values())
    )
    white_wins = results["White Wins"]["Checkmate"]
    black_wins = results["Black Wins"]["Checkmate"]
    draws = sum(results["Draw"].values())

    print("\nFinal Game Statistics:")
    print(f"Total Games: {total_games}")
    print(f"White Wins: {white_wins}")
    print(f"Black Wins: {black_wins}")
    print(f"Draws: {draws}")
    print(f"  Unknown: {results['Unknown']['Unknown']}")
    print("\nDetailed Draw Breakdown:")
    for reason, count in results["Draw"].items():
        print(f"  {reason}: {count}")

    win_percentage = (white_wins / total_games) * 100
    draw_percentage = (draws / total_games) * 100
    loss_percentage = (black_wins / total_games) * 100

    print(f"\nWin Percentage: {win_percentage:.2f}%")
    print(f"Draw Percentage: {draw_percentage:.2f}%")
    print(f"Loss Percentage: {loss_percentage:.2f}%")

    # Total analysis after all games
    print("\nTotal Analysis After All Games:")
    print(f"Total White Best Moves: {results['White Best Moves']}")
    print(f"Total White Good Moves: {results['White Good Moves']}")
    print(f"Total White Mistakes: {results['White Mistakes']}")
    print(f"Total White Blunders: {results['White Blunders']}")
    print(f"Total Black Best Moves: {results['Black Best Moves']}")
    print(f"Total Black Good Moves: {results['Black Good Moves']}")
    print(f"Total Black Mistakes: {results['Black Mistakes']}")
    print(f"Total Black Blunders: {results['Black Blunders']}")

    White_move_accuracy=(results['White Good Moves']+results['White Best Moves'])/(results['White Good Moves']+results['White Best Moves']+results['White Mistakes']+results['White Blunders'])
    Black_move_accuracy=(results['Black Good Moves']+results['Black Best Moves'])/(results['Black Good Moves']+results['Black Best Moves']+results['Black Mistakes']+results['Black Blunders'])
    print(f"\nWhite Move Accuracy: {White_move_accuracy*100:.2f}%")
    print(f"Black Move Accuracy: {Black_move_accuracy*100:.2f}%")

if __name__ == "__main__":
    args = _parse_args()
    main(args)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# <ipython-input-56-627c8fa30ca9>:259: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(args.load_model, map_location=torch.device('cpu')))
# Game 1 Start
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5849: UserWarning: Support for mismatched src_key_padding_mask and mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# Move 1: d2d4, Turn: White, Score: 30, Quality: Best Move
# Move 2: f7f5, Turn: Black, Score: 117, Quality: Blunder
# Move 3: g2g3, Turn: White, Score: 31, Quality: Best Move
# Move 4: e7e6, Turn: Black, Score: 31, Quality: Blunder
# Move 5: f1g2, Turn: White, Score: 56, Quality: Best Move
# Move 6: g8f6, Turn: Black, Score: 56, Quality: Blunder
# Move 7: c2c4, Turn: White, Score: -21, Quality: Uncategorized
# Move 8: b8c6, Turn: Black, Score: -11, Quality: Blunder
# Move 9: g1f3, Turn: White, Score: 10, Quality: Best Move
# Move 10: f8b4, Turn: Black, Score: 33, Quality: Blunder
# Move 11: c1d2, Turn: White, Score: 9, Quality: Best Move
# Move 12: b4d2, Turn: Black, Score: 53, Quality: Blunder
# Move 13: b1d2, Turn: White, Score: 37, Quality: Best Move
# Move 14: h7h5, Turn: Black, Score: 107, Quality: Blunder
# Move 15: h2h4, Turn: White, Score: 58, Quality: Best Move
# Move 16: b7b6, Turn: Black, Score: 60, Quality: Blunder
# Move 17: e1g1, Turn: White, Score: 60, Quality: Best Move
# Move 18: e8g8, Turn: Black, Score: 61, Quality: Blunder
# Move 19: e2e4, Turn: White, Score: -10, Quality: Good Move
# Move 20: f6e4, Turn: Black, Score: 83, Quality: Blunder
# Move 21: d2e4, Turn: White, Score: 83, Quality: Best Move
# Move 22: f5e4, Turn: Black, Score: 4, Quality: Blunder
# Move 23: f3g5, Turn: White, Score: 133, Quality: Best Move
# Move 24: g7g6, Turn: Black, Score: 113, Quality: Blunder
# Move 25: g2e4, Turn: White, Score: 142, Quality: Best Move
# Move 26: d8f6, Turn: Black, Score: 142, Quality: Blunder
# Move 27: g5h7, Turn: White, Score: -230, Quality: Blunder
# Move 28: g8h7, Turn: Black, Score: -221, Quality: Best Move
# Move 29: d1h5, Turn: White, Score: -221, Quality: Blunder
# Move 30: h7g7, Turn: Black, Score: -221, Quality: Best Move
# Move 31: h5g6, Turn: White, Score: -542, Quality: Blunder
# Move 32: f6g6, Turn: Black, Score: -542, Quality: Best Move
# Move 33: e4g6, Turn: White, Score: -542, Quality: Blunder
# Move 34: g7g6, Turn: Black, Score: -542, Quality: Best Move
# Move 35: d4d5, Turn: White, Score: -542, Quality: Blunder
# Move 36: c6e5, Turn: Black, Score: -537, Quality: Best Move
# Move 37: d5e6, Turn: White, Score: -575, Quality: Blunder
# Move 38: d7e6, Turn: Black, Score: -554, Quality: Best Move
# Move 39: f1e1, Turn: White, Score: -670, Quality: Blunder
# Move 40: e5f3, Turn: Black, Score: -610, Quality: Best Move
# Move 41: g1f1, Turn: White, Score: -681, Quality: Blunder
# Move 42: e6e5, Turn: Black, Score: -504, Quality: Best Move
# Move 43: e1e4, Turn: White, Score: -1102, Quality: Blunder
# Move 44: f3d2, Turn: Black, Score: -1102, Quality: Best Move
# Move 45: f1e2, Turn: White, Score: -1138, Quality: Blunder
# Move 46: d2e4, Turn: Black, Score: -1117, Quality: Best Move
# Move 47: e2e3, Turn: White, Score: -1167, Quality: Blunder
# Move 48: e4d6, Turn: Black, Score: -1081, Quality: Best Move
# Move 49: g3g4, Turn: White, Score: -1280, Quality: Blunder
# Move 50: c8g4, Turn: Black, Score: -1231, Quality: Best Move
# Move 51: a1g1, Turn: White, Score: -1351, Quality: Blunder
# Move 52: f8f4, Turn: Black, Score: -1229, Quality: Best Move
# Move 53: b2b3, Turn: White, Score: -1276, Quality: Blunder
# Move 54: g6f7, Turn: Black, Score: -1214, Quality: Best Move
# Move 55: h4h5, Turn: White, Score: -1343, Quality: Blunder
# Move 56: f4f3, Turn: Black, Score: -1354, Quality: Best Move
# Move 57: e3d2, Turn: White, Score: -1354, Quality: Blunder
# Move 58: g4h5, Turn: Black, Score: -1275, Quality: Best Move
# Move 59: g1g5, Turn: White, Score: -1860, Quality: Blunder
# Move 60: d6e4, Turn: Black, Score: -1774, Quality: Best Move
# Move 61: d2c2, Turn: White, Score: -2010, Quality: Blunder
# Move 62: e4g5, Turn: Black, Score: -1988, Quality: Best Move
# Move 63: c2b2, Turn: White, Score: -2080, Quality: Blunder
# Move 64: g5e4, Turn: Black, Score: -1991, Quality: Best Move
# Move 65: b2a3, Turn: White, Score: -2081, Quality: Blunder
# Move 66: f3f2, Turn: Black, Score: -2038, Quality: Best Move
# Move 67: b3b4, Turn: White, Score: -2147, Quality: Blunder
# Move 68: h5e2, Turn: Black, Score: -2147, Quality: Best Move
# Move 69: c4c5 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 69: c4c5, Turn: White, Score: 0, Quality: Best Move
# Move 70: f7e6, Turn: Black, Score: -2072, Quality: Best Move
# Move 71: c5b6 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 71: c5b6, Turn: White, Score: 0, Quality: Best Move
# Move 72: c7b6, Turn: Black, Score: -2060, Quality: Best Move
# Move 73: b4b5 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 73: b4b5, Turn: White, Score: 0, Quality: Best Move
# Move 74: e2b5, Turn: Black, Score: -5527, Quality: Best Move
# Move 75: a3b4, Turn: White, Score: -5543, Quality: Blunder
# Move 76: f2a2, Turn: Black, Score: -5539, Quality: Best Move
# Move 77: b4b3, Turn: White, Score: -5863, Quality: Blunder
# Move 78: a2d2, Turn: Black, Score: -5863, Quality: Best Move
# Move 79: b3a3, Turn: White, Score: -5863, Quality: Blunder
# Game 53 Analysis:
#   White Best Moves: 14, White Good Moves: 1, White Mistakes: 0, White Blunders: 24
#   Black Best Moves: 26, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  13
# Game analysis complete.
#
#
# Game 53 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 1
#   Black Wins: 9
#   Draws: 42
#   Unknown: 1
# EOS: 2
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 41
#     Threefold Repetition: 1
#
# Game 54 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . B .
# . . . . . . k p
# P . . . . . . .
# P r . . b P . .
# . . N p . . P .
# . . . R . . . P
# . . . . K . . .
#
# Starting game analysis...
# Move 1: d2d4, Turn: White, Score: 30, Quality: Best Move
# Move 2: g8f6, Turn: Black, Score: 40, Quality: Blunder
# Move 3: c2c4, Turn: White, Score: 21, Quality: Best Move
# Move 4: b8c6, Turn: Black, Score: 41, Quality: Blunder
# Move 5: g1f3, Turn: White, Score: 23, Quality: Best Move
# Move 6: e7e6, Turn: Black, Score: 12, Quality: Blunder
# Move 7: b1c3, Turn: White, Score: -2, Quality: Good Move
# Move 8: a7a6, Turn: Black, Score: 64, Quality: Blunder
# Move 9: e2e4, Turn: White, Score: 54, Quality: Best Move
# Move 10: h7h6, Turn: Black, Score: 115, Quality: Blunder
# Move 11: e4e5, Turn: White, Score: 172, Quality: Best Move
# Move 12: f6h5, Turn: Black, Score: 212, Quality: Blunder
# Move 13: d4d5, Turn: White, Score: 312, Quality: Best Move
# Move 14: e6d5, Turn: Black, Score: 167, Quality: Blunder
# Move 15: c4d5, Turn: White, Score: 325, Quality: Best Move
# Move 16: f8c5, Turn: Black, Score: 352, Quality: Blunder
# Move 17: d5c6, Turn: White, Score: 352, Quality: Best Move
# Move 18: b7c6, Turn: Black, Score: 481, Quality: Blunder
# Move 19: f1c4, Turn: White, Score: 315, Quality: Best Move
# Move 20: e8g8, Turn: Black, Score: 366, Quality: Blunder
# Move 21: e1g1, Turn: White, Score: 271, Quality: Best Move
# Move 22: c8b7, Turn: Black, Score: 407, Quality: Blunder
# Move 23: c3e4, Turn: White, Score: 386, Quality: Best Move
# Move 24: d8e7, Turn: Black, Score: 413, Quality: Blunder
# Move 25: e4c5, Turn: White, Score: 404, Quality: Best Move
# Move 26: e7c5, Turn: Black, Score: 404, Quality: Blunder
# Move 27: d1d7, Turn: White, Score: 132, Quality: Best Move
# Move 28: c5c4, Turn: Black, Score: 110, Quality: Blunder
# Move 29: d7c7, Turn: White, Score: 143, Quality: Best Move
# Move 30: a8b8, Turn: Black, Score: 141, Quality: Blunder
# Move 31: b2b3, Turn: White, Score: 141, Quality: Best Move
# Move 32: c4d5, Turn: Black, Score: 142, Quality: Blunder
# Move 33: c1a3, Turn: White, Score: 118, Quality: Best Move
# Move 34: f8c8, Turn: Black, Score: 152, Quality: Blunder
# Move 35: c7e7, Turn: White, Score: 97, Quality: Best Move
# Move 36: h5f4, Turn: Black, Score: 108, Quality: Blunder
# Move 37: f1d1, Turn: White, Score: 53, Quality: Best Move
# Move 38: c8e8, Turn: Black, Score: 106, Quality: Blunder
# Move 39: d1d5, Turn: White, Score: 119, Quality: Best Move
# Move 40: e8e7, Turn: Black, Score: 109, Quality: Blunder
# Move 41: a3e7, Turn: White, Score: 89, Quality: Best Move
# Move 42: c6d5, Turn: Black, Score: 122, Quality: Blunder
# Move 43: e7d6, Turn: White, Score: 77, Quality: Best Move
# Move 44: b8c8, Turn: Black, Score: 102, Quality: Blunder
# Move 45: f3d4, Turn: White, Score: 76, Quality: Best Move
# Move 46: f4e6, Turn: Black, Score: 84, Quality: Blunder
# Move 47: d4f5, Turn: White, Score: 67, Quality: Best Move
# Move 48: g8h7, Turn: Black, Score: 93, Quality: Blunder
# Move 49: g2g3, Turn: White, Score: 37, Quality: Best Move
# Move 50: c8c2, Turn: Black, Score: 77, Quality: Blunder
# Move 51: a2a4, Turn: White, Score: -15, Quality: Uncategorized
# Move 52: d5d4, Turn: Black, Score: 10, Quality: Blunder
# Move 53: b3b4, Turn: White, Score: -34, Quality: Uncategorized
# Move 54: d4d3, Turn: Black, Score: -13, Quality: Blunder
# Move 55: f5e3, Turn: White, Score: -9, Quality: Good Move
# Move 56: h7g6, Turn: Black, Score: 65, Quality: Blunder
# Move 57: a1d1, Turn: White, Score: -22, Quality: Uncategorized
# Move 58: c2c3, Turn: Black, Score: 80, Quality: Blunder
# Move 59: g1f1, Turn: White, Score: -116, Quality: Blunder
# Move 60: c3b3, Turn: Black, Score: 66, Quality: Blunder
# Move 61: f1e1, Turn: White, Score: -11, Quality: Uncategorized
# Move 62: b7f3, Turn: Black, Score: 91, Quality: Blunder
# Move 63: d1d2, Turn: White, Score: -106, Quality: Blunder
# Move 64: b3b1, Turn: Black, Score: -20, Quality: Blunder
# Move 65: e3d1, Turn: White, Score: -103, Quality: Blunder
# Move 66: f3e4, Turn: Black, Score: -20, Quality: Blunder
# Move 67: f2f4, Turn: White, Score: -56, Quality: Mistake
# Move 68: f7f6, Turn: Black, Score: -1, Quality: Blunder
# Move 69: e5f6, Turn: White, Score: -26, Quality: Uncategorized
# Move 70: e6d4, Turn: Black, Score: 31, Quality: Blunder
# Move 71: d6e5, Turn: White, Score: -263, Quality: Blunder
# Move 72: d4e6, Turn: Black, Score: 143, Quality: Blunder
# Move 73: f6g7, Turn: White, Score: 143, Quality: Best Move
# Move 74: e6g7, Turn: Black, Score: 160, Quality: Blunder
# Move 75: e5g7, Turn: White, Score: 160, Quality: Best Move
# Move 76: a6a5, Turn: Black, Score: 333, Quality: Blunder
# Move 77: b4a5, Turn: White, Score: 302, Quality: Best Move
# Move 78: b1b4, Turn: Black, Score: 497, Quality: Blunder
# Move 79: d1c3, Turn: White, Score: 325, Quality: Best Move
# Game 54 Analysis:
#   White Best Moves: 28, White Good Moves: 2, White Mistakes: 1, White Blunders: 4
#   Black Best Moves: 0, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  39
# Game analysis complete.
#
#
# Game 54 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 1
#   Black Wins: 9
#   Draws: 43
#   Unknown: 1
# EOS: 2
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 42
#     Threefold Repetition: 1
#
# Game 55 Start
#
# Final Board Position:
# r . . . . . . .
# . . . . . . k .
# p . . . b . p .
# . . . . . . . .
# . P . . . q . p
# . . . . . . N P
# . . . . . . P .
# . . . . . . K .
#
# Starting game analysis...
# Move 1: e2e4, Turn: White, Score: 32, Quality: Best Move
# Move 2: e7e6, Turn: Black, Score: 65, Quality: Blunder
# Move 3: d2d4, Turn: White, Score: 50, Quality: Best Move
# Move 4: d7d5, Turn: Black, Score: 56, Quality: Blunder
# Move 5: b1d2, Turn: White, Score: 15, Quality: Best Move
# Move 6: g8e7, Turn: Black, Score: 59, Quality: Blunder
# Move 7: g1f3, Turn: White, Score: 41, Quality: Best Move
# Move 8: b8c6, Turn: Black, Score: 39, Quality: Blunder
# Move 9: c2c3, Turn: White, Score: 50, Quality: Best Move
# Move 10: d8d7, Turn: Black, Score: 59, Quality: Blunder
# Move 11: f1d3, Turn: White, Score: 108, Quality: Best Move
# Move 12: a7a6, Turn: Black, Score: 116, Quality: Blunder
# Move 13: e1g1, Turn: White, Score: 121, Quality: Best Move
# Move 14: h7h5, Turn: Black, Score: 121, Quality: Blunder
# Move 15: f1e1, Turn: White, Score: 125, Quality: Best Move
# Move 16: g7g6, Turn: Black, Score: 133, Quality: Blunder
# Move 17: d2f1, Turn: White, Score: 128, Quality: Best Move
# Move 18: f8g7, Turn: Black, Score: 128, Quality: Blunder
# Move 19: c1g5, Turn: White, Score: 101, Quality: Best Move
# Move 20: e8g8, Turn: Black, Score: 122, Quality: Blunder
# Move 21: d1d2, Turn: White, Score: 71, Quality: Best Move
# Move 22: f7f6, Turn: Black, Score: 79, Quality: Blunder
# Move 23: g5h6, Turn: White, Score: 96, Quality: Best Move
# Move 24: e6e5, Turn: Black, Score: 96, Quality: Blunder
# Move 25: h6g7, Turn: White, Score: 96, Quality: Best Move
# Move 26: g8g7, Turn: Black, Score: 125, Quality: Blunder
# Move 27: d4e5, Turn: White, Score: 125, Quality: Best Move
# Move 28: c6e5, Turn: Black, Score: 155, Quality: Blunder
# Move 29: f3e5, Turn: White, Score: 155, Quality: Best Move
# Move 30: f6e5, Turn: Black, Score: 155, Quality: Blunder
# Move 31: e4d5, Turn: White, Score: 90, Quality: Best Move
# Move 32: f8f6, Turn: Black, Score: 231, Quality: Blunder
# Move 33: e1e5, Turn: White, Score: 231, Quality: Best Move
# Move 34: c7c6, Turn: Black, Score: 346, Quality: Blunder
# Move 35: c3c4, Turn: White, Score: 298, Quality: Best Move
# Move 36: c6d5, Turn: Black, Score: 333, Quality: Blunder
# Move 37: c4d5, Turn: White, Score: 272, Quality: Best Move
# Move 38: g7g8, Turn: Black, Score: 272, Quality: Blunder
# Move 39: a1e1, Turn: White, Score: 355, Quality: Best Move
# Move 40: e7d5, Turn: Black, Score: 700, Quality: Blunder
# Move 41: d3c4, Turn: White, Score: 628, Quality: Best Move
# Move 42: f6f7, Turn: Black, Score: 894, Quality: Blunder
# Move 43: e5d5, Turn: White, Score: 908, Quality: Best Move
# Move 44: d7c7, Turn: Black, Score: 1010, Quality: Blunder
# Move 45: d5d8, Turn: White, Score: 1010, Quality: Best Move
# Move 46: g8g7, Turn: Black, Score: 1386, Quality: Blunder
# Move 47: d2d4, Turn: White, Score: 1386, Quality: Best Move
# Move 48: g7h6, Turn: Black, Score: 1373, Quality: Blunder
# Move 49: d8h8, Turn: White, Score: 778, Quality: Best Move
# Move 50: f7h7, Turn: Black, Score: 778, Quality: Blunder
# Move 51: h8h7, Turn: White, Score: 644, Quality: Best Move
# Move 52: h6h7, Turn: Black, Score: 644, Quality: Blunder
# Move 53: e1e7, Turn: White, Score: 13, Quality: Best Move
# Move 54: c7e7, Turn: Black, Score: 13, Quality: Blunder
# Move 55: c4g8, Turn: White, Score: -397, Quality: Blunder
# Move 56: h7g8, Turn: Black, Score: -397, Quality: Best Move
# Move 57: d4d5, Turn: White, Score: -507, Quality: Blunder
# Move 58: c8e6, Turn: Black, Score: -507, Quality: Best Move
# Move 59: d5b7, Turn: White, Score: -1525, Quality: Blunder
# Move 60: e7b7, Turn: Black, Score: -1513, Quality: Best Move
# Move 61: b2b3, Turn: White, Score: -1600, Quality: Blunder
# Move 62: b7e4, Turn: Black, Score: -1519, Quality: Best Move
# Move 63: h2h3, Turn: White, Score: -1543, Quality: Blunder
# Move 64: g8g7, Turn: Black, Score: -1535, Quality: Best Move
# Move 65: f1g3, Turn: White, Score: -1597, Quality: Blunder
# Move 66: e4b1, Turn: Black, Score: -1571, Quality: Best Move
# Move 67: g1h2, Turn: White, Score: -1588, Quality: Blunder
# Move 68: b1a2, Turn: Black, Score: -1577, Quality: Best Move
# Move 69: b3b4, Turn: White, Score: -2078, Quality: Blunder
# Move 70: a2d2, Turn: Black, Score: -1712, Quality: Best Move
# Move 71: g3e4, Turn: White, Score: -1897, Quality: Blunder
# Move 72: d2f4, Turn: Black, Score: -1897, Quality: Best Move
# Move 73: e4g3, Turn: White, Score: -2078, Quality: Blunder
# Move 74: f4f2, Turn: Black, Score: -1739, Quality: Best Move
# Move 75: g3e4, Turn: White, Score: -1756, Quality: Blunder
# Move 76: f2f4, Turn: Black, Score: -1739, Quality: Best Move
# Move 77: e4g3 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 77: e4g3, Turn: White, Score: 0, Quality: Best Move
# Move 78: h5h4 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 78: h5h4, Turn: Black, Score: 0, Quality: Blunder
# Move 79: h2g1 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 79: h2g1, Turn: White, Score: 0, Quality: Best Move
# Game 55 Analysis:
#   White Best Moves: 29, White Good Moves: 0, White Mistakes: 0, White Blunders: 11
#   Black Best Moves: 11, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  28
# Game analysis complete.
#
#
# Game 55 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 1
#   Black Wins: 9
#   Draws: 44
#   Unknown: 1
# EOS: 2
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 43
#     Threefold Repetition: 1
#
# Game 56 Start
#
# Final Board Position:
# . . . . . k . .
# r . . . . . . .
# . . . N . . B .
# p . p . . . B .
# . p . p . P . .
# . . . P . . . .
# P P P . . K P P
# . . . . . . . .
#
# Starting game analysis...
# Move 1: e2e4, Turn: White, Score: 37, Quality: Best Move
# Move 2: e7e5, Turn: Black, Score: 57, Quality: Blunder
# Move 3: g1f3, Turn: White, Score: 37, Quality: Best Move
# Move 4: b8c6, Turn: Black, Score: 73, Quality: Blunder
# Move 5: f1b5, Turn: White, Score: 22, Quality: Best Move
# Move 6: g8f6, Turn: Black, Score: 39, Quality: Blunder
# Move 7: e1g1, Turn: White, Score: 39, Quality: Best Move
# Move 8: f8d6, Turn: Black, Score: 60, Quality: Blunder
# Move 9: f1e1, Turn: White, Score: 0, Quality: Best Move
# Move 10: c6d4, Turn: Black, Score: 312, Quality: Blunder
# Move 11: f3d4, Turn: White, Score: 300, Quality: Best Move
# Move 12: e5d4, Turn: Black, Score: 70, Quality: Blunder
# Move 13: e4e5, Turn: White, Score: 346, Quality: Best Move
# Move 14: d6e7, Turn: Black, Score: 395, Quality: Blunder
# Move 15: e5f6, Turn: White, Score: 429, Quality: Best Move
# Move 16: g7f6, Turn: Black, Score: 413, Quality: Blunder
# Move 17: d1e2, Turn: White, Score: 337, Quality: Best Move
# Move 18: h7h5, Turn: Black, Score: 438, Quality: Blunder
# Move 19: d2d3, Turn: White, Score: 344, Quality: Best Move
# Move 20: c7c6, Turn: Black, Score: 447, Quality: Blunder
# Move 21: b5c4, Turn: White, Score: 322, Quality: Best Move
# Move 22: a7a6, Turn: Black, Score: 547, Quality: Blunder
# Move 23: c1f4, Turn: White, Score: 377, Quality: Best Move
# Move 24: h8h7, Turn: Black, Score: 1639, Quality: Blunder
# Move 25: f4d6, Turn: White, Score: 1639, Quality: Best Move
# Move 26: f6f5, Turn: Black, Score: 2184, Quality: Blunder
# Move 27: e2e7, Turn: White, Score: 1532, Quality: Best Move
# Move 28: d8e7, Turn: Black, Score: 1532, Quality: Blunder
# Move 29: e1e7, Turn: White, Score: 1532, Quality: Best Move
# Move 30: e8f8, Turn: Black, Score: 1553, Quality: Blunder
# Move 31: e7f7, Turn: White, Score: 1553, Quality: Best Move
# Move 32: f8g8, Turn: Black, Score: 1857, Quality: Blunder
# Move 33: f7d7, Turn: White, Score: 1857, Quality: Best Move
# Move 34: g8h8 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 34: g8h8, Turn: Black, Score: 0, Quality: Blunder
# Move 35: d7h7, Turn: White, Score: 982, Quality: Best Move
# Move 36: h8h7, Turn: Black, Score: 982, Quality: Blunder
# Move 37: d6e5, Turn: White, Score: 926, Quality: Best Move
# Move 38: b7b5, Turn: Black, Score: 926, Quality: Blunder
# Move 39: c4b3, Turn: White, Score: 930, Quality: Best Move
# Move 40: c6c5, Turn: Black, Score: 935, Quality: Blunder
# Move 41: b3d5, Turn: White, Score: 889, Quality: Best Move
# Move 42: a8a7, Turn: Black, Score: 936, Quality: Blunder
# Move 43: b1d2, Turn: White, Score: 886, Quality: Best Move
# Move 44: a6a5, Turn: Black, Score: 944, Quality: Blunder
# Move 45: a1e1, Turn: White, Score: 939, Quality: Best Move
# Move 46: a7e7, Turn: Black, Score: 998, Quality: Blunder
# Move 47: d2f3, Turn: White, Score: 944, Quality: Best Move
# Move 48: h7g6, Turn: Black, Score: 982, Quality: Blunder
# Move 49: f3h4, Turn: White, Score: 951, Quality: Best Move
# Move 50: g6g5, Turn: Black, Score: 970, Quality: Blunder
# Move 51: h4f3, Turn: White, Score: 0, Quality: Best Move
# Move 52: g5g6, Turn: Black, Score: 982, Quality: Blunder
# Move 53: f3h4, Turn: White, Score: 0, Quality: Best Move
# Move 54: g6g5, Turn: Black, Score: 970, Quality: Blunder
# Move 55: f2f4, Turn: White, Score: 970, Quality: Best Move
# Move 56: g5h6, Turn: Black, Score: 970, Quality: Blunder
# Move 57: g1f2, Turn: White, Score: 993, Quality: Best Move
# Move 58: c8d7, Turn: Black, Score: 993, Quality: Blunder
# Move 59: h4f3, Turn: White, Score: 929, Quality: Best Move
# Move 60: h6g6, Turn: Black, Score: 933, Quality: Blunder
# Move 61: f3h4, Turn: White, Score: 0, Quality: Best Move
# Move 62: g6h6, Turn: Black, Score: 993, Quality: Blunder
# Move 63: d5f3, Turn: White, Score: 922, Quality: Best Move
# Move 64: b5b4, Turn: Black, Score: 968, Quality: Blunder
# Move 65: e5f6, Turn: White, Score: 922, Quality: Best Move
# Move 66: e7f7, Turn: Black, Score: 1158, Quality: Blunder
# Move 67: f6g5, Turn: White, Score: 1158, Quality: Best Move
# Move 68: h6h7, Turn: Black, Score: 1097, Quality: Blunder
# Move 69: f3h5, Turn: White, Score: 1150, Quality: Best Move
# Move 70: f7g7, Turn: Black, Score: 1150, Quality: Blunder
# Move 71: e1e7, Turn: White, Score: 1084, Quality: Best Move
# Move 72: h7g8, Turn: Black, Score: 1093, Quality: Blunder
# Move 73: e7d7, Turn: White, Score: 944, Quality: Best Move
# Move 74: g7d7, Turn: Black, Score: 936, Quality: Blunder
# Move 75: h4f5, Turn: White, Score: 950, Quality: Best Move
# Move 76: g8f8, Turn: Black, Score: 956, Quality: Blunder
# Move 77: h5g6, Turn: White, Score: 944, Quality: Best Move
# Move 78: d7a7, Turn: Black, Score: 963, Quality: Blunder
# Move 79: f5d6, Turn: White, Score: 928, Quality: Best Move
# Game 56 Analysis:
#   White Best Moves: 40, White Good Moves: 0, White Mistakes: 0, White Blunders: 0
#   Black Best Moves: 0, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  39
# Game analysis complete.
#
#
# Game 56 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 1
#   Black Wins: 9
#   Draws: 45
#   Unknown: 1
# EOS: 2
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 44
#     Threefold Repetition: 1
#
# Game 57 Start
#
# Final Board Position:
# . . . . . . . .
# . p . . . . k .
# p . . . . . . .
# . . P . . . . p
# . P . . . . r .
# . . K . . . . .
# . r . . . . . .
# . . . . . . . .
#
# Starting game analysis...
# Move 1: e2e4, Turn: White, Score: 37, Quality: Best Move
# Move 2: e7e5, Turn: Black, Score: 57, Quality: Blunder
# Move 3: g1f3, Turn: White, Score: 37, Quality: Best Move
# Move 4: g8f6, Turn: Black, Score: 66, Quality: Blunder
# Move 5: f3e5, Turn: White, Score: -4, Quality: Good Move
# Move 6: f8d6, Turn: Black, Score: 66, Quality: Blunder
# Move 7: e5f3, Turn: White, Score: 63, Quality: Best Move
# Move 8: b8c6, Turn: Black, Score: 71, Quality: Blunder
# Move 9: b1c3, Turn: White, Score: 89, Quality: Best Move
# Move 10: d6b4, Turn: Black, Score: 108, Quality: Blunder
# Move 11: f1c4, Turn: White, Score: 81, Quality: Best Move
# Move 12: d7d6, Turn: Black, Score: 105, Quality: Blunder
# Move 13: e1g1, Turn: White, Score: 105, Quality: Best Move
# Move 14: c8e6, Turn: Black, Score: 108, Quality: Blunder
# Move 15: c4e6, Turn: White, Score: 108, Quality: Best Move
# Move 16: f7e6, Turn: Black, Score: 100, Quality: Blunder
# Move 17: d2d3, Turn: White, Score: 96, Quality: Best Move
# Move 18: h7h6, Turn: Black, Score: 113, Quality: Blunder
# Move 19: c1d2, Turn: White, Score: 98, Quality: Best Move
# Move 20: d6d5, Turn: Black, Score: 148, Quality: Blunder
# Move 21: e4d5, Turn: White, Score: 181, Quality: Best Move
# Move 22: f6d5, Turn: Black, Score: 192, Quality: Blunder
# Move 23: c3d5, Turn: White, Score: 163, Quality: Best Move
# Move 24: b4d2, Turn: Black, Score: 169, Quality: Blunder
# Move 25: d1d2, Turn: White, Score: 168, Quality: Best Move
# Move 26: e6d5, Turn: Black, Score: 272, Quality: Blunder
# Move 27: f1e1, Turn: White, Score: 219, Quality: Best Move
# Move 28: e8f8, Turn: Black, Score: 256, Quality: Blunder
# Move 29: d2f4, Turn: White, Score: 230, Quality: Best Move
# Move 30: f8g8, Turn: Black, Score: 226, Quality: Blunder
# Move 31: e1e2, Turn: White, Score: 168, Quality: Best Move
# Move 32: a7a6, Turn: Black, Score: 238, Quality: Blunder
# Move 33: a1e1, Turn: White, Score: 236, Quality: Best Move
# Move 34: d8d7, Turn: Black, Score: 256, Quality: Blunder
# Move 35: f3e5, Turn: White, Score: 256, Quality: Best Move
# Move 36: d7e6, Turn: Black, Score: 352, Quality: Blunder
# Move 37: e5c6, Turn: White, Score: 352, Quality: Best Move
# Move 38: e6c6, Turn: Black, Score: 429, Quality: Blunder
# Move 39: e2e7, Turn: White, Score: 281, Quality: Best Move
# Move 40: c6g6, Turn: Black, Score: 371, Quality: Blunder
# Move 41: e7c7, Turn: White, Score: 310, Quality: Best Move
# Move 42: a8f8, Turn: Black, Score: 315, Quality: Blunder
# Move 43: e1e7, Turn: White, Score: -680, Quality: Blunder
# Move 44: f8f4, Turn: Black, Score: -639, Quality: Best Move
# Move 45: e7g7, Turn: White, Score: -826, Quality: Blunder
# Move 46: g6g7, Turn: Black, Score: -851, Quality: Best Move
# Move 47: c7g7, Turn: White, Score: -851, Quality: Blunder
# Move 48: g8g7, Turn: Black, Score: -772, Quality: Best Move
# Move 49: g2g3, Turn: White, Score: -984, Quality: Blunder
# Move 50: f4b4, Turn: Black, Score: -840, Quality: Best Move
# Move 51: b2b3, Turn: White, Score: -910, Quality: Blunder
# Move 52: b4b6, Turn: Black, Score: -793, Quality: Best Move
# Move 53: g1g2, Turn: White, Score: -941, Quality: Blunder
# Move 54: h8f8, Turn: Black, Score: -807, Quality: Best Move
# Move 55: g2h3, Turn: White, Score: -1111, Quality: Blunder
# Move 56: f8f2, Turn: Black, Score: -1111, Quality: Best Move
# Move 57: h3g4, Turn: White, Score: -1224, Quality: Blunder
# Move 58: f2h2, Turn: Black, Score: -1124, Quality: Best Move
# Move 59: c2c4, Turn: White, Score: -1167, Quality: Blunder
# Move 60: h6h5, Turn: Black, Score: -1110, Quality: Best Move
# Move 61: g4f3, Turn: White, Score: -1129, Quality: Blunder
# Move 62: b6f6, Turn: Black, Score: -1199, Quality: Best Move
# Move 63: f3e3, Turn: White, Score: -1199, Quality: Blunder
# Move 64: d5c4, Turn: Black, Score: -1118, Quality: Best Move
# Move 65: d3c4, Turn: White, Score: -1259, Quality: Blunder
# Move 66: h2a2, Turn: Black, Score: -1259, Quality: Best Move
# Move 67: e3d4, Turn: White, Score: -1310, Quality: Blunder
# Move 68: f6g6, Turn: Black, Score: -1292, Quality: Best Move
# Move 69: c4c5, Turn: White, Score: -1358, Quality: Blunder
# Move 70: g6g4, Turn: Black, Score: -1265, Quality: Best Move
# Move 71: d4e5, Turn: White, Score: -1377, Quality: Blunder
# Move 72: g4g5, Turn: Black, Score: -1217, Quality: Best Move
# Move 73: e5d4, Turn: White, Score: -1359, Quality: Blunder
# Move 74: g5g3, Turn: Black, Score: -1360, Quality: Best Move
# Move 75: b3b4, Turn: White, Score: -1400, Quality: Blunder
# Move 76: a2b2, Turn: Black, Score: -1399, Quality: Best Move
# Move 77: d4c4, Turn: White, Score: -1471, Quality: Blunder
# Move 78: g3g4, Turn: Black, Score: -1417, Quality: Best Move
# Move 79: c4c3, Turn: White, Score: -1417, Quality: Blunder
# Game 57 Analysis:
#   White Best Moves: 20, White Good Moves: 1, White Mistakes: 0, White Blunders: 19
#   Black Best Moves: 18, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  21
# Game analysis complete.
#
#
# Game 57 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 1
#   Black Wins: 9
#   Draws: 46
#   Unknown: 1
# EOS: 2
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 45
#     Threefold Repetition: 1
#
# Game 58 Start
#
# Final Board Position:
# . . . . . . . .
# p . . . . . . .
# . p . . . . . p
# . . . k . P . .
# . r . p N . . .
# . . . K . . N .
# . . . . . . . P
# . . . . . . . .
#
# Starting game analysis...
# Move 1: e2e4, Turn: White, Score: 37, Quality: Best Move
# Move 2: e7e6, Turn: Black, Score: 97, Quality: Blunder
# Move 3: d2d4, Turn: White, Score: 46, Quality: Best Move
# Move 4: b8c6, Turn: Black, Score: 88, Quality: Blunder
# Move 5: g1f3, Turn: White, Score: 31, Quality: Best Move
# Move 6: d7d5, Turn: Black, Score: 48, Quality: Blunder
# Move 7: e4e5, Turn: White, Score: 50, Quality: Best Move
# Move 8: f8e7, Turn: Black, Score: 55, Quality: Blunder
# Move 9: c2c3, Turn: White, Score: 24, Quality: Best Move
# Move 10: g8h6, Turn: Black, Score: 54, Quality: Blunder
# Move 11: f1d3, Turn: White, Score: 31, Quality: Best Move
# Move 12: e8g8, Turn: Black, Score: 150, Quality: Blunder
# Move 13: e1g1, Turn: White, Score: 24, Quality: Best Move
# Move 14: h6f5, Turn: Black, Score: 24, Quality: Blunder
# Move 15: d1c2, Turn: White, Score: 39, Quality: Best Move
# Move 16: c8d7, Turn: Black, Score: -6, Quality: Blunder
# Move 17: g2g4, Turn: White, Score: 102, Quality: Best Move
# Move 18: c6d4, Turn: Black, Score: 202, Quality: Blunder
# Move 19: f3d4, Turn: White, Score: 290, Quality: Best Move
# Move 20: f5h6, Turn: Black, Score: 356, Quality: Blunder
# Move 21: c1h6, Turn: White, Score: 332, Quality: Best Move
# Move 22: g7h6, Turn: Black, Score: 313, Quality: Blunder
# Move 23: d3h7, Turn: White, Score: 313, Quality: Best Move
# Move 24: g8g7, Turn: Black, Score: 313, Quality: Blunder
# Move 25: h7d3, Turn: White, Score: 296, Quality: Best Move
# Move 26: c7c5, Turn: Black, Score: 265, Quality: Blunder
# Move 27: d4f3, Turn: White, Score: 285, Quality: Best Move
# Move 28: e7g5, Turn: Black, Score: 304, Quality: Blunder
# Move 29: b1d2, Turn: White, Score: 313, Quality: Best Move
# Move 30: g5e7, Turn: Black, Score: 350, Quality: Blunder
# Move 31: c3c4, Turn: White, Score: 334, Quality: Best Move
# Move 32: g7g8, Turn: Black, Score: 348, Quality: Blunder
# Move 33: c4d5, Turn: White, Score: 339, Quality: Best Move
# Move 34: e6d5, Turn: Black, Score: 339, Quality: Blunder
# Move 35: d3f5, Turn: White, Score: 329, Quality: Best Move
# Move 36: b7b6, Turn: Black, Score: 332, Quality: Blunder
# Move 37: f5d7, Turn: White, Score: 331, Quality: Best Move
# Move 38: d8d7, Turn: Black, Score: 347, Quality: Blunder
# Move 39: c2f5, Turn: White, Score: 342, Quality: Best Move
# Move 40: d7f5, Turn: Black, Score: 335, Quality: Blunder
# Move 41: g4f5, Turn: White, Score: 335, Quality: Best Move
# Move 42: d5d4, Turn: Black, Score: 368, Quality: Blunder
# Move 43: f5f6, Turn: White, Score: 368, Quality: Best Move
# Move 44: a8e8, Turn: Black, Score: 539, Quality: Blunder
# Move 45: f6e7, Turn: White, Score: 539, Quality: Best Move
# Move 46: e8e7, Turn: Black, Score: 539, Quality: Blunder
# Move 47: f1e1, Turn: White, Score: 507, Quality: Best Move
# Move 48: e7e6, Turn: Black, Score: 566, Quality: Blunder
# Move 49: d2e4, Turn: White, Score: 533, Quality: Best Move
# Move 50: e6g6, Turn: Black, Score: 575, Quality: Blunder
# Move 51: e4g3, Turn: White, Score: 523, Quality: Best Move
# Move 52: f8e8, Turn: Black, Score: 520, Quality: Blunder
# Move 53: f3h4, Turn: White, Score: 532, Quality: Best Move
# Move 54: g6e6, Turn: Black, Score: 578, Quality: Blunder
# Move 55: f2f4, Turn: White, Score: 569, Quality: Best Move
# Move 56: f7f6, Turn: Black, Score: 582, Quality: Blunder
# Move 57: e5f6, Turn: White, Score: -120, Quality: Blunder
# Move 58: e6e1, Turn: Black, Score: -120, Quality: Best Move
# Move 59: a1e1, Turn: White, Score: -120, Quality: Blunder
# Move 60: e8e1, Turn: Black, Score: 4, Quality: Blunder
# Move 61: g1f2, Turn: White, Score: -125, Quality: Blunder
# Move 62: e1a1, Turn: Black, Score: 9, Quality: Blunder
# Move 63: a2a3, Turn: White, Score: -105, Quality: Blunder
# Move 64: g8f7, Turn: Black, Score: -25, Quality: Blunder
# Move 65: h4f5, Turn: White, Score: -39, Quality: Uncategorized
# Move 66: a1b1, Turn: Black, Score: -39, Quality: Blunder
# Move 67: f5d6, Turn: White, Score: -62, Quality: Mistake
# Move 68: f7f6, Turn: Black, Score: -62, Quality: Blunder
# Move 69: d6e4, Turn: White, Score: -132, Quality: Blunder
# Move 70: f6e7, Turn: Black, Score: -74, Quality: Blunder
# Move 71: b2b4, Turn: White, Score: -74, Quality: Mistake
# Move 72: c5b4, Turn: Black, Score: -53, Quality: Blunder
# Move 73: a3b4, Turn: White, Score: -93, Quality: Mistake
# Move 74: e7e6, Turn: Black, Score: -106, Quality: Best Move
# Move 75: f2e2, Turn: White, Score: -106, Quality: Blunder
# Move 76: b1b4, Turn: Black, Score: -81, Quality: Blunder
# Move 77: e2d3, Turn: White, Score: -68, Quality: Mistake
# Move 78: e6d5, Turn: Black, Score: -32, Quality: Blunder
# Move 79: f4f5, Turn: White, Score: -168, Quality: Blunder
# Game 58 Analysis:
#   White Best Moves: 28, White Good Moves: 0, White Mistakes: 4, White Blunders: 7
#   Black Best Moves: 2, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  37
# Game analysis complete.
#
#
# Game 58 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 1
#   Black Wins: 9
#   Draws: 47
#   Unknown: 1
# EOS: 2
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 46
#     Threefold Repetition: 1
#
# Game 59 Start
#
# Final Board Position:
# . k . . . . . r
# p p . . . p . p
# . . . . . . . .
# . . . . . . . .
# . P . . b . . .
# . . . . . . P .
# P . r . . q . P
# . . . . R . K .
#
# Starting game analysis...
# Move 1: d2d4, Turn: White, Score: 30, Quality: Best Move
# Move 2: g8f6, Turn: Black, Score: 39, Quality: Blunder
# Move 3: c2c4, Turn: White, Score: 10, Quality: Best Move
# Move 4: e7e6, Turn: Black, Score: 23, Quality: Blunder
# Move 5: g1f3, Turn: White, Score: -2, Quality: Good Move
# Move 6: d7d5, Turn: Black, Score: 20, Quality: Blunder
# Move 7: b1c3, Turn: White, Score: -15, Quality: Uncategorized
# Move 8: c7c5, Turn: Black, Score: 26, Quality: Blunder
# Move 9: c4d5, Turn: White, Score: 2, Quality: Best Move
# Move 10: e6d5, Turn: Black, Score: 21, Quality: Blunder
# Move 11: g2g3, Turn: White, Score: -15, Quality: Uncategorized
# Move 12: d8b6, Turn: Black, Score: 21, Quality: Blunder
# Move 13: f1g2, Turn: White, Score: -20, Quality: Uncategorized
# Move 14: c8f5, Turn: Black, Score: 68, Quality: Blunder
# Move 15: e1g1, Turn: White, Score: 48, Quality: Best Move
# Move 16: b8c6, Turn: Black, Score: 97, Quality: Blunder
# Move 17: d4c5, Turn: White, Score: 76, Quality: Best Move
# Move 18: b6c5, Turn: Black, Score: 76, Quality: Blunder
# Move 19: c1e3, Turn: White, Score: 94, Quality: Best Move
# Move 20: c5a5, Turn: Black, Score: 96, Quality: Blunder
# Move 21: f3d4, Turn: White, Score: 145, Quality: Best Move
# Move 22: c6d4, Turn: Black, Score: 154, Quality: Blunder
# Move 23: e3d4, Turn: White, Score: 115, Quality: Best Move
# Move 24: a8c8, Turn: Black, Score: 163, Quality: Blunder
# Move 25: d4f6, Turn: White, Score: 163, Quality: Best Move
# Move 26: g7f6, Turn: Black, Score: 132, Quality: Blunder
# Move 27: c3d5, Turn: White, Score: 154, Quality: Best Move
# Move 28: f8g7, Turn: Black, Score: 199, Quality: Blunder
# Move 29: b2b4, Turn: White, Score: 157, Quality: Best Move
# Move 30: a5a6, Turn: Black, Score: 170, Quality: Blunder
# Move 31: e2e4, Turn: White, Score: 178, Quality: Best Move
# Move 32: f5g6, Turn: Black, Score: 182, Quality: Blunder
# Move 33: g2h3, Turn: White, Score: 204, Quality: Best Move
# Move 34: c8c4, Turn: Black, Score: 204, Quality: Blunder
# Move 35: h3d7, Turn: White, Score: 204, Quality: Best Move
# Move 36: e8d7, Turn: Black, Score: 166, Quality: Blunder
# Move 37: d5f6, Turn: White, Score: -290, Quality: Blunder
# Move 38: d7c7, Turn: Black, Score: -275, Quality: Best Move
# Move 39: d1d7, Turn: White, Score: -290, Quality: Blunder
# Move 40: c7b8, Turn: Black, Score: -290, Quality: Best Move
# Move 41: d7d6, Turn: White, Score: -1296, Quality: Blunder
# Move 42: a6d6, Turn: Black, Score: -1296, Quality: Best Move
# Move 43: f6d7, Turn: White, Score: -1610, Quality: Blunder
# Move 44: d6d7, Turn: Black, Score: -1635, Quality: Best Move
# Move 45: a1d1, Turn: White, Score: -1751, Quality: Blunder
# Move 46: g7d4, Turn: Black, Score: -1749, Quality: Best Move
# Move 47: f1e1, Turn: White, Score: -1882, Quality: Blunder
# Move 48: c4c2, Turn: Black, Score: -1882, Quality: Best Move
# Move 49: e1f1 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 49: e1f1, Turn: White, Score: 0, Quality: Best Move
# Move 50: g6e4, Turn: Black, Score: -1917, Quality: Best Move
# Move 51: d1d4, Turn: White, Score: -2406, Quality: Blunder
# Move 52: d7d4, Turn: Black, Score: -2406, Quality: Best Move
# Move 53: f1e1 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 53: f1e1, Turn: White, Score: 0, Quality: Best Move
# Move 54: d4f2 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 54: d4f2, Turn: Black, Score: 0, Quality: Blunder
# Game 59 Analysis:
#   White Best Moves: 16, White Good Moves: 1, White Mistakes: 0, White Blunders: 7
#   Black Best Moves: 8, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  19
# Game analysis complete.
#
# Result: Checkmate
#
# Game 59 Result: Black Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 1
#   Black Wins: 10
#   Draws: 47
#   Unknown: 1
# EOS: 2
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 46
#     Threefold Repetition: 1
#
# Game 60 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . .
# . . . . . . k p
# P R . . . . p .
# . . . . . . . .
# . . P . . . . P
# . P . . . P P K
# . . . . . . . .
#
# Starting game analysis...
# Move 1: e2e4, Turn: White, Score: 37, Quality: Best Move
# Move 2: e7e6, Turn: Black, Score: 53, Quality: Blunder
# Move 3: d2d4, Turn: White, Score: 36, Quality: Best Move
# Move 4: d7d5, Turn: Black, Score: 54, Quality: Blunder
# Move 5: b1c3, Turn: White, Score: 31, Quality: Best Move
# Move 6: f8b4, Turn: Black, Score: 53, Quality: Blunder
# Move 7: e4e5, Turn: White, Score: 10, Quality: Best Move
# Move 8: b8c6, Turn: Black, Score: 65, Quality: Blunder
# Move 9: g1f3, Turn: White, Score: 2, Quality: Best Move
# Move 10: f7f6, Turn: Black, Score: 94, Quality: Blunder
# Move 11: f1b5, Turn: White, Score: 60, Quality: Best Move
# Move 12: e8f7, Turn: Black, Score: 136, Quality: Blunder
# Move 13: e1g1, Turn: White, Score: 116, Quality: Best Move
# Move 14: g8h6, Turn: Black, Score: 151, Quality: Blunder
# Move 15: c3e2, Turn: White, Score: 112, Quality: Best Move
# Move 16: h6g4, Turn: Black, Score: 151, Quality: Blunder
# Move 17: c2c3, Turn: White, Score: 183, Quality: Best Move
# Move 18: b4e7, Turn: Black, Score: 230, Quality: Blunder
# Move 19: b5c6, Turn: White, Score: 230, Quality: Best Move
# Move 20: b7c6, Turn: Black, Score: 230, Quality: Blunder
# Move 21: h2h3, Turn: White, Score: 204, Quality: Best Move
# Move 22: g4e5, Turn: Black, Score: 267, Quality: Blunder
# Move 23: d4e5, Turn: White, Score: 305, Quality: Best Move
# Move 24: c8a6, Turn: Black, Score: 306, Quality: Blunder
# Move 25: f1e1, Turn: White, Score: 255, Quality: Best Move
# Move 26: c6c5, Turn: Black, Score: 290, Quality: Blunder
# Move 27: e2f4, Turn: White, Score: 355, Quality: Best Move
# Move 28: f7g8, Turn: Black, Score: 460, Quality: Blunder
# Move 29: f4e6, Turn: White, Score: 619, Quality: Best Move
# Move 30: d8d7, Turn: Black, Score: 656, Quality: Blunder
# Move 31: e6f4, Turn: White, Score: 453, Quality: Best Move
# Move 32: a8d8, Turn: Black, Score: 469, Quality: Blunder
# Move 33: e5f6, Turn: White, Score: 469, Quality: Best Move
# Move 34: e7f6, Turn: Black, Score: 436, Quality: Blunder
# Move 35: f3e5, Turn: White, Score: 437, Quality: Best Move
# Move 36: d7e8, Turn: Black, Score: 553, Quality: Blunder
# Move 37: e5g4, Turn: White, Score: 553, Quality: Best Move
# Move 38: e8c6, Turn: Black, Score: 755, Quality: Blunder
# Move 39: g4f6, Turn: White, Score: 755, Quality: Best Move
# Move 40: c6f6, Turn: Black, Score: 490, Quality: Blunder
# Move 41: e1e6, Turn: White, Score: 798, Quality: Best Move
# Move 42: f6f8, Turn: Black, Score: 798, Quality: Blunder
# Move 43: e6a6, Turn: White, Score: 887, Quality: Best Move
# Move 44: h7h6, Turn: Black, Score: 899, Quality: Blunder
# Move 45: a6a7, Turn: White, Score: 877, Quality: Best Move
# Move 46: f8e7, Turn: Black, Score: 937, Quality: Blunder
# Move 47: f4g6, Turn: White, Score: 930, Quality: Best Move
# Move 48: e7d6, Turn: Black, Score: 917, Quality: Blunder
# Move 49: g6h8, Turn: White, Score: 917, Quality: Best Move
# Move 50: d8e8, Turn: Black, Score: 1121, Quality: Blunder
# Move 51: h8g6, Turn: White, Score: 1102, Quality: Best Move
# Move 52: d6g6, Turn: Black, Score: 1102, Quality: Blunder
# Move 53: a7c7, Turn: White, Score: 978, Quality: Best Move
# Move 54: g6d6, Turn: Black, Score: 978, Quality: Blunder
# Move 55: c1f4, Turn: White, Score: 831, Quality: Best Move
# Move 56: d6f4, Turn: Black, Score: 891, Quality: Blunder
# Move 57: d1d5, Turn: White, Score: 891, Quality: Best Move
# Move 58: g8h8, Turn: Black, Score: 864, Quality: Blunder
# Move 59: d5c5, Turn: White, Score: 920, Quality: Best Move
# Move 60: e8e2, Turn: Black, Score: 984, Quality: Blunder
# Move 61: c7c8, Turn: White, Score: 984, Quality: Best Move
# Move 62: h8h7, Turn: Black, Score: 984, Quality: Blunder
# Move 63: c8f8, Turn: White, Score: 918, Quality: Best Move
# Move 64: f4e4, Turn: Black, Score: 918, Quality: Blunder
# Move 65: c5c8, Turn: White, Score: 756, Quality: Best Move
# Move 66: e2e1, Turn: Black, Score: 1008, Quality: Blunder
# Move 67: a1e1, Turn: White, Score: 1008, Quality: Best Move
# Move 68: e4e1, Turn: Black, Score: 908, Quality: Blunder
# Move 69: g1h2, Turn: White, Score: 1018, Quality: Best Move
# Move 70: e1b1, Turn: Black, Score: 1074, Quality: Blunder
# Move 71: c8f5, Turn: White, Score: 1068, Quality: Best Move
# Move 72: b1f5, Turn: Black, Score: 995, Quality: Blunder
# Move 73: f8f5, Turn: White, Score: 1081, Quality: Best Move
# Move 74: g7g5, Turn: Black, Score: 1081, Quality: Blunder
# Move 75: a2a4, Turn: White, Score: 1097, Quality: Best Move
# Move 76: h7g7, Turn: Black, Score: 1369, Quality: Blunder
# Move 77: a4a5, Turn: White, Score: 1369, Quality: Best Move
# Move 78: g7g6, Turn: Black, Score: 1369, Quality: Blunder
# Move 79: f5b5, Turn: White, Score: 1141, Quality: Best Move
# Game 60 Analysis:
#   White Best Moves: 40, White Good Moves: 0, White Mistakes: 0, White Blunders: 0
#   Black Best Moves: 0, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  39
# Game analysis complete.
#
#
# Game 60 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 1
#   Black Wins: 10
#   Draws: 48
#   Unknown: 1
# EOS: 2
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 47
#     Threefold Repetition: 1
#
# Game 61 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . . . . P
# . . . . k . . .
# p b P p P p . .
# . . . P . P . .
# . . r . . . . .
# . . . . . . P .
# . . . . . . K .
#
# Starting game analysis...
# Move 1: e2e4, Turn: White, Score: 37, Quality: Best Move
# Move 2: e7e6, Turn: Black, Score: 51, Quality: Blunder
# Move 3: d2d4, Turn: White, Score: 31, Quality: Best Move
# Move 4: g8f6, Turn: Black, Score: 67, Quality: Blunder
# Move 5: b1c3, Turn: White, Score: 68, Quality: Best Move
# Move 6: f8b4, Turn: Black, Score: 66, Quality: Blunder
# Move 7: e4e5, Turn: White, Score: 27, Quality: Best Move
# Move 8: f6e4, Turn: Black, Score: 29, Quality: Blunder
# Move 9: c1d2, Turn: White, Score: 29, Quality: Best Move
# Move 10: b4c3, Turn: Black, Score: 78, Quality: Blunder
# Move 11: b2c3, Turn: White, Score: 11, Quality: Best Move
# Move 12: e8g8, Turn: Black, Score: 37, Quality: Blunder
# Move 13: f1d3, Turn: White, Score: 7, Quality: Best Move
# Move 14: d7d5, Turn: Black, Score: 68, Quality: Blunder
# Move 15: g1f3, Turn: White, Score: 23, Quality: Best Move
# Move 16: e4d2, Turn: Black, Score: 31, Quality: Blunder
# Move 17: d1d2, Turn: White, Score: 31, Quality: Best Move
# Move 18: b8c6, Turn: Black, Score: 50, Quality: Blunder
# Move 19: e1g1, Turn: White, Score: 25, Quality: Best Move
# Move 20: b7b6, Turn: Black, Score: 32, Quality: Blunder
# Move 21: f3g5, Turn: White, Score: 13, Quality: Best Move
# Move 22: h7h6, Turn: Black, Score: 20, Quality: Blunder
# Move 23: g5h7, Turn: White, Score: 82, Quality: Best Move
# Move 24: f8e8, Turn: Black, Score: 82, Quality: Blunder
# Move 25: h7f6, Turn: White, Score: 82, Quality: Best Move
# Move 26: g7f6, Turn: Black, Score: 82, Quality: Blunder
# Move 27: d2h6, Turn: White, Score: -160, Quality: Blunder
# Move 28: f6f5, Turn: Black, Score: -155, Quality: Best Move
# Move 29: d3b5, Turn: White, Score: -203, Quality: Blunder
# Move 30: c8d7, Turn: Black, Score: -188, Quality: Best Move
# Move 31: b5c6, Turn: White, Score: -233, Quality: Blunder
# Move 32: d7c6, Turn: Black, Score: -233, Quality: Best Move
# Move 33: f2f4, Turn: White, Score: 100, Quality: Best Move
# Move 34: d8e7, Turn: Black, Score: -212, Quality: Best Move
# Move 35: f1f3, Turn: White, Score: 909, Quality: Best Move
# Move 36: e7g5 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 36: e7g5, Turn: Black, Score: 0, Quality: Blunder
# Move 37: h6g5 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 37: h6g5, Turn: White, Score: 0, Quality: Best Move
# Move 38: g8f8, Turn: Black, Score: 941, Quality: Blunder
# Move 39: f3h3 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 39: f3h3, Turn: White, Score: 0, Quality: Best Move
# Move 40: f7f6 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 40: f7f6, Turn: Black, Score: 0, Quality: Blunder
# Move 41: h3h8 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 41: h3h8, Turn: White, Score: 0, Quality: Best Move
# Move 42: f8e7 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 42: f8e7, Turn: Black, Score: 0, Quality: Blunder
# Move 43: h8h7 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 43: h8h7, Turn: White, Score: 0, Quality: Best Move
# Move 44: e7d8 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 44: e7d8, Turn: Black, Score: 0, Quality: Blunder
# Move 45: g5f6, Turn: White, Score: 2424, Quality: Best Move
# Move 46: d8c8, Turn: Black, Score: 1121, Quality: Blunder
# Move 47: f6e7, Turn: White, Score: 433, Quality: Best Move
# Move 48: e8e7, Turn: Black, Score: 421, Quality: Blunder
# Move 49: h7e7, Turn: White, Score: 431, Quality: Best Move
# Move 50: a7a5, Turn: Black, Score: 451, Quality: Blunder
# Move 51: e7e6, Turn: White, Score: 479, Quality: Best Move
# Move 52: c8d7, Turn: Black, Score: 479, Quality: Blunder
# Move 53: e6h6, Turn: White, Score: 478, Quality: Best Move
# Move 54: c6a4, Turn: Black, Score: 481, Quality: Blunder
# Move 55: a1c1, Turn: White, Score: 458, Quality: Best Move
# Move 56: a8b8, Turn: Black, Score: 515, Quality: Blunder
# Move 57: h6h7, Turn: White, Score: 515, Quality: Best Move
# Move 58: d7e6, Turn: Black, Score: 474, Quality: Blunder
# Move 59: h7c7, Turn: White, Score: 565, Quality: Best Move
# Move 60: a4b5, Turn: Black, Score: 550, Quality: Blunder
# Move 61: c1b1, Turn: White, Score: 596, Quality: Best Move
# Move 62: b5e8, Turn: Black, Score: 608, Quality: Blunder
# Move 63: c7c6, Turn: White, Score: 0, Quality: Best Move
# Move 64: e8c6, Turn: Black, Score: 0, Quality: Blunder
# Move 65: b1b6, Turn: White, Score: -649, Quality: Blunder
# Move 66: b8b6, Turn: Black, Score: -649, Quality: Best Move
# Move 67: c3c4, Turn: White, Score: -757, Quality: Blunder
# Move 68: b6b4, Turn: Black, Score: -575, Quality: Best Move
# Move 69: c4c5, Turn: White, Score: -757, Quality: Blunder
# Move 70: b4b2, Turn: Black, Score: -580, Quality: Best Move
# Move 71: c2c3, Turn: White, Score: -783, Quality: Blunder
# Move 72: c6b5, Turn: Black, Score: -646, Quality: Best Move
# Move 73: h2h4, Turn: White, Score: -697, Quality: Blunder
# Move 74: b2a2, Turn: Black, Score: -705, Quality: Best Move
# ...
# Move 68: c4d5, Turn: Black, Score: -31, Quality: Blunder
# Move 69: e4f5, Turn: White, Score: -31, Quality: Uncategorized
# Move 70: d5a2, Turn: Black, Score: 1, Quality: Blunder
# Move 71: e3e2, Turn: White, Score: -246, Quality: Blunder
# Move 72: a2b1, Turn: Black, Score: -246, Quality: Best Move
# Move 73: f5g4, Turn: White, Score: -604, Quality: Blunder
# Move 74: d2e2, Turn: Black, Score: -581, Quality: Best Move
# Move 75: h2h4, Turn: White, Score: -667, Quality: Blunder
# Move 76: e2e3, Turn: Black, Score: -506, Quality: Best Move
# Move 77: f4f5, Turn: White, Score: -715, Quality: Blunder
# Move 78: e3e4, Turn: Black, Score: -610, Quality: Best Move
# Move 79: g4f3, Turn: White, Score: -610, Quality: Blunder
# Game 97 Analysis:
#   White Best Moves: 13, White Good Moves: 2, White Mistakes: 9, White Blunders: 8
#   Black Best Moves: 6, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  33
# Game analysis complete.
#
#
# Game 97 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 1
#   Black Wins: 19
#   Draws: 75
#   Unknown: 2
# EOS: 4
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 71
#     Threefold Repetition: 4
#
# Game 98 Start
#
# Final Board Position:
# r . . . . . . .
# p . . . . k . .
# . p p . . . . .
# . . . . B . q .
# . . b P . . . .
# P . . . . P N .
# . . . . . . P .
# R . . . . . K .
#
# Starting game analysis...
# Move 1: d2d4, Turn: White, Score: 30, Quality: Best Move
# Move 2: e7e6, Turn: Black, Score: 36, Quality: Blunder
# Move 3: c2c4, Turn: White, Score: 2, Quality: Best Move
# Move 4: d7d5, Turn: Black, Score: 14, Quality: Blunder
# Move 5: b1c3, Turn: White, Score: 2, Quality: Best Move
# Move 6: b8c6, Turn: Black, Score: 18, Quality: Blunder
# Move 7: g1f3, Turn: White, Score: 12, Quality: Best Move
# Move 8: f8e7, Turn: Black, Score: 44, Quality: Blunder
# Move 9: c1f4, Turn: White, Score: -13, Quality: Uncategorized
# Move 10: e7b4, Turn: Black, Score: 65, Quality: Blunder
# Move 11: e2e3, Turn: White, Score: 50, Quality: Best Move
# Move 12: g8f6, Turn: Black, Score: 44, Quality: Blunder
# Move 13: a2a3, Turn: White, Score: 1, Quality: Best Move
# Move 14: b4c3, Turn: Black, Score: 50, Quality: Blunder
# Move 15: b2c3, Turn: White, Score: 15, Quality: Best Move
# Move 16: f6e4, Turn: Black, Score: 40, Quality: Blunder
# Move 17: d1c2, Turn: White, Score: 49, Quality: Best Move
# Move 18: c8d7, Turn: Black, Score: 86, Quality: Blunder
# Move 19: f1d3, Turn: White, Score: 75, Quality: Best Move
# Move 20: e8g8, Turn: Black, Score: 50, Quality: Blunder
# Move 21: e1g1, Turn: White, Score: 75, Quality: Best Move
# Move 22: e4f6, Turn: Black, Score: 122, Quality: Blunder
# Move 23: c4d5, Turn: White, Score: 122, Quality: Best Move
# Move 24: c6e7, Turn: Black, Score: 213, Quality: Blunder
# Move 25: c3c4, Turn: White, Score: 122, Quality: Best Move
# Move 26: e7g6, Turn: Black, Score: 205, Quality: Blunder
# Move 27: f4g3, Turn: White, Score: 136, Quality: Best Move
# Move 28: d8c8, Turn: Black, Score: 224, Quality: Blunder
# Move 29: e3e4, Turn: White, Score: 229, Quality: Best Move
# Move 30: h7h6, Turn: Black, Score: 240, Quality: Blunder
# Move 31: e4e5, Turn: White, Score: 245, Quality: Best Move
# Move 32: f6e8, Turn: Black, Score: 325, Quality: Blunder
# Move 33: d3g6, Turn: White, Score: 279, Quality: Best Move
# Move 34: f7g6, Turn: Black, Score: 265, Quality: Blunder
# Move 35: c2g6, Turn: White, Score: 239, Quality: Best Move
# Move 36: e6d5, Turn: Black, Score: 321, Quality: Blunder
# Move 37: c4d5, Turn: White, Score: 160, Quality: Best Move
# Move 38: d7f5, Turn: Black, Score: 270, Quality: Blunder
# Move 39: g6h5, Turn: White, Score: 186, Quality: Best Move
# Move 40: c8d8, Turn: Black, Score: 202, Quality: Blunder
# Move 41: f3h4, Turn: White, Score: 202, Quality: Best Move
# Move 42: f5d3, Turn: Black, Score: 220, Quality: Blunder
# Move 43: f1e1, Turn: White, Score: 149, Quality: Best Move
# Move 44: d8d5, Turn: Black, Score: 175, Quality: Blunder
# Move 45: h4g6, Turn: White, Score: 112, Quality: Best Move
# Move 46: d5f7, Turn: Black, Score: 112, Quality: Blunder
# Move 47: g6f8, Turn: White, Score: -278, Quality: Blunder
# Move 48: f7h5, Turn: Black, Score: -285, Quality: Best Move
# Move 49: f8e6, Turn: White, Score: -286, Quality: Blunder
# Move 50: d3c4, Turn: Black, Score: -286, Quality: Best Move
# Move 51: e6c5, Turn: White, Score: -343, Quality: Blunder
# Move 52: h5g4, Turn: Black, Score: -215, Quality: Best Move
# Move 53: e1e4, Turn: White, Score: -294, Quality: Blunder
# Move 54: g4g5, Turn: Black, Score: -280, Quality: Best Move
# Move 55: g3f4, Turn: White, Score: -331, Quality: Blunder
# Move 56: g5h5, Turn: Black, Score: -288, Quality: Best Move
# Move 57: f2f3, Turn: White, Score: -288, Quality: Blunder
# Move 58: c7c6, Turn: Black, Score: -242, Quality: Best Move
# Move 59: e5e6, Turn: White, Score: -333, Quality: Blunder
# Move 60: g7g5, Turn: Black, Score: -236, Quality: Best Move
# Move 61: f4e5, Turn: White, Score: -302, Quality: Blunder
# Move 62: h5g6, Turn: Black, Score: -260, Quality: Best Move
# Move 63: e4g4, Turn: White, Score: -430, Quality: Blunder
# Move 64: b7b6, Turn: Black, Score: -424, Quality: Best Move
# Move 65: c5e4, Turn: White, Score: -433, Quality: Blunder
# Move 66: g6e6, Turn: Black, Score: -424, Quality: Best Move
# Move 67: h2h4, Turn: White, Score: -412, Quality: Blunder
# Move 68: e8g7, Turn: Black, Score: -311, Quality: Best Move
# Move 69: h4g5, Turn: White, Score: -280, Quality: Blunder
# Move 70: h6h5, Turn: Black, Score: -280, Quality: Best Move
# Move 71: e4f6, Turn: White, Score: -280, Quality: Blunder
# Move 72: g8f7, Turn: Black, Score: -280, Quality: Best Move
# Move 73: g4h4, Turn: White, Score: -338, Quality: Blunder
# Move 74: e6f5, Turn: Black, Score: -273, Quality: Best Move
# Move 75: h4h5, Turn: White, Score: -629, Quality: Blunder
# Move 76: g7h5, Turn: Black, Score: -533, Quality: Best Move
# Move 77: f6h5, Turn: White, Score: -533, Quality: Blunder
# Move 78: f5g5, Turn: Black, Score: -533, Quality: Best Move
# Move 79: h5g3, Turn: White, Score: -568, Quality: Blunder
# Game 98 Analysis:
#   White Best Moves: 22, White Good Moves: 0, White Mistakes: 0, White Blunders: 17
#   Black Best Moves: 16, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  23
# Game analysis complete.
#
#
# Game 98 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 1
#   Black Wins: 19
#   Draws: 76
#   Unknown: 2
# EOS: 4
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 72
#     Threefold Repetition: 4
#
# Game 99 Start
#
# Final Board Position:
# . . . . . . . .
# . . . . k . . .
# . . . . p . . .
# . . . . B . . .
# . . . P . . . .
# p . . K P P P .
# . . . . . . P .
# . . . . . . . .
#
# Starting game analysis...
# Move 1: d2d4, Turn: White, Score: 30, Quality: Best Move
# Move 2: g8f6, Turn: Black, Score: 40, Quality: Blunder
# Move 3: c2c4, Turn: White, Score: 2, Quality: Best Move
# Move 4: b8c6, Turn: Black, Score: 41, Quality: Blunder
# Move 5: g1f3, Turn: White, Score: -2, Quality: Good Move
# Move 6: e7e6, Turn: Black, Score: 41, Quality: Blunder
# Move 7: b1c3, Turn: White, Score: -2, Quality: Good Move
# Move 8: d7d5, Turn: Black, Score: 12, Quality: Blunder
# Move 9: c1g5, Turn: White, Score: -39, Quality: Uncategorized
# Move 10: f8e7, Turn: Black, Score: 26, Quality: Blunder
# Move 11: e2e3, Turn: White, Score: -24, Quality: Uncategorized
# Move 12: h7h6, Turn: Black, Score: 17, Quality: Blunder
# Move 13: g5h4, Turn: White, Score: -28, Quality: Uncategorized
# Move 14: a7a6, Turn: Black, Score: 18, Quality: Blunder
# Move 15: a1c1, Turn: White, Score: -50, Quality: Mistake
# Move 16: e7b4, Turn: Black, Score: 18, Quality: Blunder
# Move 17: f1d3, Turn: White, Score: -33, Quality: Uncategorized
# Move 18: g7g5, Turn: Black, Score: 17, Quality: Blunder
# Move 19: h4g3, Turn: White, Score: 26, Quality: Best Move
# Move 20: b4c3, Turn: Black, Score: 72, Quality: Blunder
# Move 21: b2c3, Turn: White, Score: 83, Quality: Best Move
# Move 22: f6e4, Turn: Black, Score: 96, Quality: Blunder
# Move 23: d3e4, Turn: White, Score: 96, Quality: Best Move
# Move 24: d5e4, Turn: Black, Score: 70, Quality: Blunder
# Move 25: f3d2, Turn: White, Score: 110, Quality: Best Move
# Move 26: c8d7, Turn: Black, Score: 130, Quality: Blunder
# Move 27: d2e4, Turn: White, Score: 115, Quality: Best Move
# Move 28: b7b5, Turn: Black, Score: 152, Quality: Blunder
# Move 29: c4c5, Turn: White, Score: 143, Quality: Best Move
# Move 30: h8g8, Turn: Black, Score: 189, Quality: Blunder
# Move 31: e1g1, Turn: White, Score: 217, Quality: Best Move
# Move 32: a6a5, Turn: Black, Score: 253, Quality: Blunder
# Move 33: d1h5, Turn: White, Score: 231, Quality: Best Move
# Move 34: b5b4, Turn: Black, Score: 274, Quality: Blunder
# Move 35: h5h6, Turn: White, Score: 436, Quality: Best Move
# Move 36: a8b8, Turn: Black, Score: 635, Quality: Blunder
# Move 37: c3b4, Turn: White, Score: 538, Quality: Best Move
# Move 38: c6b4, Turn: Black, Score: 530, Quality: Blunder
# Move 39: e4f6, Turn: White, Score: 530, Quality: Best Move
# Move 40: e8e7, Turn: Black, Score: 496, Quality: Blunder
# Move 41: f6g8, Turn: White, Score: 496, Quality: Best Move
# Move 42: d8g8, Turn: Black, Score: 529, Quality: Blunder
# Move 43: g3c7, Turn: White, Score: 510, Quality: Best Move
# Move 44: b4a2, Turn: Black, Score: 955, Quality: Blunder
# Move 45: c7d6, Turn: White, Score: 955, Quality: Best Move
# Move 46: e7d8, Turn: Black, Score: 955, Quality: Blunder
# Move 47: d6b8, Turn: White, Score: 668, Quality: Best Move
# Move 48: a2c1, Turn: Black, Score: 711, Quality: Blunder
# Move 49: f1c1, Turn: White, Score: 694, Quality: Best Move
# Move 50: d7b5, Turn: Black, Score: 745, Quality: Blunder
# Move 51: h6f6, Turn: White, Score: 745, Quality: Best Move
# Move 52: d8c8, Turn: Black, Score: 772, Quality: Blunder
# Move 53: b8e5, Turn: White, Score: 777, Quality: Best Move
# Move 54: a5a4, Turn: Black, Score: 962, Quality: Blunder
# Move 55: c5c6, Turn: White, Score: 829, Quality: Best Move
# Move 56: g8h7, Turn: Black, Score: 1269, Quality: Blunder
# Move 57: c6c7, Turn: White, Score: 2013, Quality: Best Move
# Move 58: h7g8, Turn: Black, Score: 2013, Quality: Blunder
# Move 59: f6d8, Turn: White, Score: 535, Quality: Best Move
# Move 60: g8d8, Turn: Black, Score: 535, Quality: Blunder
# Move 61: c7d8q, Turn: White, Score: 535, Quality: Best Move
# Move 62: c8d8, Turn: Black, Score: 535, Quality: Blunder
# Move 63: c1c7, Turn: White, Score: 507, Quality: Best Move
# Move 64: a4a3, Turn: Black, Score: 530, Quality: Blunder
# Move 65: c7f7, Turn: White, Score: 432, Quality: Best Move
# Move 66: b5d7, Turn: Black, Score: 467, Quality: Blunder
# Move 67: f7f8, Turn: White, Score: 429, Quality: Best Move
# Move 68: d7e8, Turn: Black, Score: 449, Quality: Blunder
# Move 69: f8e8, Turn: White, Score: 449, Quality: Best Move
# Move 70: d8e8, Turn: Black, Score: 449, Quality: Blunder
# Move 71: g1f1, Turn: White, Score: 349, Quality: Best Move
# Move 72: e8f7, Turn: Black, Score: 455, Quality: Blunder
# Move 73: f1e2, Turn: White, Score: 396, Quality: Best Move
# Move 74: f7e7, Turn: Black, Score: 497, Quality: Blunder
# Move 75: e2d3, Turn: White, Score: 404, Quality: Best Move
# Move 76: g5g4, Turn: Black, Score: 675, Quality: Blunder
# Move 77: f2f3, Turn: White, Score: 404, Quality: Best Move
# Move 78: g4g3, Turn: Black, Score: 511, Quality: Blunder
# Move 79: h2g3, Turn: White, Score: 511, Quality: Best Move
# Game 99 Analysis:
#   White Best Moves: 33, White Good Moves: 2, White Mistakes: 1, White Blunders: 0
#   Black Best Moves: 0, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  39
# Game analysis complete.
#
#
# Game 99 Result: Draw (80+ moves)
#
# Cumulative Results:
#   White Wins: 1
#   Black Wins: 19
#   Draws: 77
#   Unknown: 2
# EOS: 4
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 73
#     Threefold Repetition: 4
#
# Game 100 Start
# Game Over <eos>
# Unknown error
# debug: <bos> d4 Nf6 c4 d5 Nc3 e6 Bg5 Nc6 Nf3 a6 e3 Bb4 Qc2 Bd7 Bd3 h6 Bh4 dxc4 Bxc4 b5 Bd3 g5 Bg3 g4 Ne5 O-O Bh4 Bxc3+ bxc3 Nxe5 dxe5 Qe8 Bxf6 g3 hxg3 b4 Rxh6 b3 Rh8# <eos>
#
# Final Board Position:
# r . . . q r k R
# . . p b . p . .
# p . . . p B . .
# . . . . P . . .
# . . . . . . . .
# . p P B P . P .
# P . Q . . P P .
# R . . . K . . .
#
# Starting game analysis...
# Move 1: d2d4, Turn: White, Score: 30, Quality: Best Move
# Move 2: g8f6, Turn: Black, Score: 30, Quality: Blunder
# Move 3: c2c4, Turn: White, Score: 2, Quality: Best Move
# Move 4: d7d5, Turn: Black, Score: -12, Quality: Blunder
# Move 5: b1c3, Turn: White, Score: -9, Quality: Good Move
# Move 6: e7e6, Turn: Black, Score: -9, Quality: Blunder
# Move 7: c1g5, Turn: White, Score: -22, Quality: Uncategorized
# Move 8: b8c6, Turn: Black, Score: -8, Quality: Blunder
# Move 9: g1f3, Turn: White, Score: 0, Quality: Best Move
# Move 10: a7a6, Turn: Black, Score: 29, Quality: Blunder
# Move 11: e2e3, Turn: White, Score: 24, Quality: Best Move
# Move 12: f8b4, Turn: Black, Score: 25, Quality: Blunder
# Move 13: d1c2, Turn: White, Score: -50, Quality: Mistake
# Move 14: c8d7, Turn: Black, Score: 14, Quality: Blunder
# Move 15: f1d3, Turn: White, Score: -12, Quality: Uncategorized
# Move 16: h7h6, Turn: Black, Score: 35, Quality: Blunder
# Move 17: g5h4, Turn: White, Score: -106, Quality: Blunder
# Move 18: d5c4, Turn: Black, Score: -46, Quality: Blunder
# Move 19: d3c4, Turn: White, Score: -54, Quality: Mistake
# Move 20: b7b5, Turn: Black, Score: -23, Quality: Blunder
# Move 21: c4d3, Turn: White, Score: 41, Quality: Best Move
# Move 22: g7g5, Turn: Black, Score: 17, Quality: Blunder
# Move 23: h4g3, Turn: White, Score: 66, Quality: Best Move
# Move 24: g5g4, Turn: Black, Score: 81, Quality: Blunder
# Move 25: f3e5, Turn: White, Score: 72, Quality: Best Move
# Move 26: e8g8, Turn: Black, Score: 72, Quality: Blunder
# Move 27: g3h4, Turn: White, Score: 98, Quality: Best Move
# Move 28: b4c3, Turn: Black, Score: 125, Quality: Blunder
# Move 29: b2c3, Turn: White, Score: 2, Quality: Best Move
# Move 30: c6e5, Turn: Black, Score: 2, Quality: Blunder
# Move 31: d4e5, Turn: White, Score: 413, Quality: Best Move
# Move 32: d8e8, Turn: Black, Score: 418, Quality: Blunder
# Move 33: h4f6 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 33: h4f6, Turn: White, Score: 0, Quality: Best Move
# Move 34: g4g3 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 34: g4g3, Turn: Black, Score: 0, Quality: Blunder
# Move 35: h2g3 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 35: h2g3, Turn: White, Score: 0, Quality: Best Move
# Move 36: b5b4 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 36: b5b4, Turn: Black, Score: 0, Quality: Blunder
# Move 37: h1h6 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 37: h1h6, Turn: White, Score: 0, Quality: Best Move
# Move 38: b4b3 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 38: b4b3, Turn: Black, Score: 0, Quality: Blunder
# Move 39: h6h8 - Error during evaluation: '>' not supported between instances of 'NoneType' and 'int'
# Move 39: h6h8, Turn: White, Score: 0, Quality: Best Move
# Game 100 Analysis:
#   White Best Moves: 14, White Good Moves: 1, White Mistakes: 2, White Blunders: 1
#   Black Best Moves: 0, Black Good Moves: 0, Black Mistakes: 0, Black Blunders:  19
# Game analysis complete.
#
# Result: Checkmate
#
# Game 100 Result: White Wins (Checkmate)
#
# Cumulative Results:
#   White Wins: 2
#   Black Wins: 19
#   Draws: 77
#   Unknown: 2
# EOS: 5
#
# Detailed Draw Breakdown:
#     Stalemate: 0
#     Insufficient Material: 0
#     80-move Rule: 73
#     Threefold Repetition: 4
#
# Final Game Statistics:
# Total Games: 98
# White Wins: 2
# Black Wins: 19
# Draws: 77
#   Unknown: 2
#
# Detailed Draw Breakdown:
#   Stalemate: 0
#   Insufficient Material: 0
#   80-move Rule: 73
#   Threefold Repetition: 4
#
# Win Percentage: 2.04%
# Draw Percentage: 78.57%
# Loss Percentage: 19.39%
#
# Total Analysis After All Games:
# Total White Best Moves: 2662
# Total White Good Moves: 39
# Total White Mistakes: 84
# Total White Blunders: 663
# Total Black Best Moves: 619
# Total Black Good Moves: 0
# Total Black Mistakes: 0
# Total Black Blunders: 2876
#
# White Move Accuracy: 78.34%
# Black Move Accuracy: 17.71%

# %% [markdown]
# #Model description

# %%
n_positions = 80
dim_model = 768
d_hid = 3072
num_heads = 12
num_layers = 12
dropout_p = 0.1
tokenizer = Tokenizer("/content/vocabs/kaggle2_vocab.txt")
model = Transformer(
    tokenizer,
    num_tokens=tokenizer.vocab_size(),
    dim_model=dim_model,
    d_hid=d_hid,
    num_heads=num_heads,
    num_layers=num_layers,
    dropout_p=dropout_p,
    n_positions=n_positions,
)
model.load_state_dict(torch.load("/content/chessformer_epoch_13.pth", map_location=torch.device('cpu')))
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# <ipython-input-12-4c972002e311>:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/content/chessformer_epoch_13.pth", map_location=torch.device('cpu')))
# <All keys matched successfully>

# %%
model
# Out:
# Transformer(
#   (positional_encoder): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (embedding): Embedding(10049, 768, padding_idx=0)
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-11): 12 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=3072, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=3072, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (out): Linear(in_features=768, out_features=10049, bias=True)
# )

# %%
import torch

# Total and trainable parameters
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
# Out:
# Total parameters: 100499777
# Trainable parameters: 100499777
